# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from regions import CircleSkyRegion
from gammapy.spectrum import (
    SpectrumDatasetOnOff,
    SpectrumDataset,
    SpectrumDatasetMaker,
)
from gammapy.modeling import Fit, Parameter
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SpectralModel,
    SkyModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis
from itertools import combinations

# %%
livetime = [20,10,8,5,4,2,1] * u.h
n_obs = [50,100,125,200,250,500,1000]
pointing = SkyCoord(0, 0, unit="deg", frame="galactic")
offset = 0.5 * u.deg
# Reconstructed and true energy axis
energy_axis = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 10), unit="TeV", name="energy", interp="log"
)
energy_axis_true = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 31), unit="TeV", name="energy", interp="log"
)

on_region_radius = Angle("0.11 deg")
on_region = CircleSkyRegion(center=pointing, radius=on_region_radius)

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
model = []
for i in range(7):
    model_simu = ExpCutoffPowerLawSpectralModel(
        index=2.22,
        amplitude=1.289e-12 * u.Unit("cm-2 s-1 TeV-1"),
        reference=1 * u.TeV,
        lambda_=2 * u.Unit("TeV-1"),
        alpha = 1,
    )
    print(model_simu) 
    mod = SkyModel(spectral_model=model_simu)
    model.append(mod)
# Out:
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)

# %%
obs = []
for i in range(len(model)):
    obs.append(Observation.create(pointing=pointing, livetime=livetime[i], irfs=irfs))
    print(obs[i])
# Out:
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 72000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 36000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 28800.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 18000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 14400.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 7200.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 3600.0 s
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]

# %%
dataset = []
for i in range(len(model)):
    dataset_empty = SpectrumDataset.create(
        e_reco=energy_axis.edges, e_true=energy_axis_true.edges, region=on_region
    )
    maker = SpectrumDatasetMaker(selection=["aeff", "edisp", "background"])
    dataset.append(maker.run(dataset_empty, obs[i]))

# %%
data = []
for i in range(len(model)):
    dataset[i].model = model[i]
    dataset[i].fake(random_state=42)
    print(dataset[i])
    data.append(dataset[i])
# Out:
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 8444
#     Total predicted counts          : nan
#     Total background counts         : 8462.25
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 7.20e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 4219
#     Total predicted counts          : nan
#     Total background counts         : 4231.13
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 3.60e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 3375
#     Total predicted counts          : nan
#     Total background counts         : 3384.90
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.88e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 2108
#     Total predicted counts          : nan
#     Total background counts         : 2115.56
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.80e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 1685
#     Total predicted counts          : nan
#     Total background counts         : 1692.45
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.44e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 836
#     Total predicted counts          : nan
#     Total background counts         : 846.23
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 7.20e+03 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 412
#     Total predicted counts          : nan
#     Total background counts         : 423.11
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 3.60e+03 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0

# %%
data_onoff = []
for i in range(len(model)):
    dataset_onoff = SpectrumDatasetOnOff(
        aeff=data[i].aeff,
        edisp=data[i].edisp,
        models=model[i],
        livetime=livetime[i],
        acceptance=1,
        acceptance_off=5,
    )
    dataset_onoff.fake(background_model=data[i].background)
    print(dataset_onoff)
    data_onoff.append(dataset_onoff)
# Out:
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 12343
#     Total predicted counts          : 12309.25
#     Total off counts                : 42255.00
#
#     Total background counts         : 8451.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.00e+01 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.58
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 6193
#     Total predicted counts          : 6133.72
#     Total off counts                : 21023.00
#
#     Total background counts         : 4204.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.00e+01 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.23
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 4994
#     Total predicted counts          : 4880.90
#     Total off counts                : 16688.00
#
#     Total background counts         : 3337.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.47
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 3125
#     Total predicted counts          : 3047.36
#     Total off counts                : 10414.00
#
#     Total background counts         : 2082.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 5.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 11.23
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 2592
#     Total predicted counts          : 2458.25
#     Total off counts                : 8433.00
#
#     Total background counts         : 1686.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 4.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 14.80
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 1224
#     Total predicted counts          : 1250.22
#     Total off counts                : 4322.00
#
#     Total background counts         : 864.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 610
#     Total predicted counts          : 625.51
#     Total off counts                : 2163.00
#
#     Total background counts         : 432.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
# %%time
datas = []
for i in range(len(model)):
    datasets = []
    for idx in range(n_obs[i]):
        data_onoff[i].fake(random_state=idx, background_model=data[i].background)
        data_onoff[i].name = f"obs_{idx}"
        datasets.append(data_onoff[i].copy())
    datas.append(datasets)
# Out:
# CPU times: user 13.2 s, sys: 93.9 ms, total: 13.3 s
# Wall time: 13.8 s

# %%
len(datas)
print(*datas[2], sep = "\n")
# Out:
# SpectrumDatasetOnOff
#
#     Name                            : obs_0
#
#     Total counts                    : 4869
#     Total predicted counts          : 4878.50
#     Total off counts                : 16676.00
#
#     Total background counts         : 3335.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.15
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_1
#
#     Total counts                    : 4795
#     Total predicted counts          : 4904.30
#     Total off counts                : 16805.00
#
#     Total background counts         : 3361.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.46
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_2
#
#     Total counts                    : 4913
#     Total predicted counts          : 4942.30
#     Total off counts                : 16995.00
#
#     Total background counts         : 3399.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.82
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_3
#
#     Total counts                    : 4874
#     Total predicted counts          : 4921.90
#     Total off counts                : 16893.00
#
#     Total background counts         : 3378.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.01
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_4
#
#     Total counts                    : 5030
#     Total predicted counts          : 4936.70
#     Total off counts                : 16967.00
#
#     Total background counts         : 3393.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_5
#
#     Total counts                    : 4949
#     Total predicted counts          : 4946.70
#     Total off counts                : 17017.00
#
#     Total background counts         : 3403.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.71
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_6
#
#     Total counts                    : 5027
#     Total predicted counts          : 4927.10
#     Total off counts                : 16919.00
#
#     Total background counts         : 3383.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.64
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_7
#
#     Total counts                    : 4898
#     Total predicted counts          : 4926.50
#     Total off counts                : 16916.00
#
#     Total background counts         : 3383.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.36
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_8
#
#     Total counts                    : 4844
#     Total predicted counts          : 4915.30
#     Total off counts                : 16860.00
#
#     Total background counts         : 3372.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.63
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_9
#
#     Total counts                    : 4922
#     Total predicted counts          : 4959.90
#     Total off counts                : 17083.00
#
#     Total background counts         : 3416.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.15
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_10
#
#     Total counts                    : 5038
#     Total predicted counts          : 4969.90
#     Total off counts                : 17133.00
#
#     Total background counts         : 3426.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.12
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_11
#
#     Total counts                    : 4826
#     Total predicted counts          : 4914.30
#     Total off counts                : 16855.00
#
#     Total background counts         : 3371.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.53
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_12
#
#     Total counts                    : 4886
#     Total predicted counts          : 4886.10
#     Total off counts                : 16714.00
#
#     Total background counts         : 3342.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.29
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_13
#
#     Total counts                    : 4853
#     Total predicted counts          : 4935.90
#     Total off counts                : 16963.00
#
#     Total background counts         : 3392.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 14.77
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_14
#
#     Total counts                    : 5048
#     Total predicted counts          : 4933.90
#     Total off counts                : 16953.00
#
#     Total background counts         : 3390.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.03
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_15
#
#     Total counts                    : 4775
#     Total predicted counts          : 4859.70
#     Total off counts                : 16582.00
#
#     Total background counts         : 3316.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.14
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_16
#
#     Total counts                    : 4887
#     Total predicted counts          : 4941.90
#     Total off counts                : 16993.00
#
#     Total background counts         : 3398.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.13
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_17
#
#     Total counts                    : 4911
#     Total predicted counts          : 4950.10
#     Total off counts                : 17034.00
#
#     Total background counts         : 3406.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_18
#
#     Total counts                    : 4971
#     Total predicted counts          : 4899.10
#     Total off counts                : 16779.00
#
#     Total background counts         : 3355.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.15
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_19
#
#     Total counts                    : 4802
#     Total predicted counts          : 4921.10
#     Total off counts                : 16889.00
#
#     Total background counts         : 3377.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.98
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_20
#
#     Total counts                    : 4888
#     Total predicted counts          : 4922.90
#     Total off counts                : 16898.00
#
#     Total background counts         : 3379.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.75
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_21
#
#     Total counts                    : 4880
#     Total predicted counts          : 4979.50
#     Total off counts                : 17181.00
#
#     Total background counts         : 3436.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.18
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_22
#
#     Total counts                    : 4852
#     Total predicted counts          : 4919.30
#     Total off counts                : 16880.00
#
#     Total background counts         : 3376.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.96
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_23
#
#     Total counts                    : 4962
#     Total predicted counts          : 4938.30
#     Total off counts                : 16975.00
#
#     Total background counts         : 3395.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.88
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_24
#
#     Total counts                    : 4989
#     Total predicted counts          : 4972.70
#     Total off counts                : 17147.00
#
#     Total background counts         : 3429.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.97
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_25
#
#     Total counts                    : 4873
#     Total predicted counts          : 4949.50
#     Total off counts                : 17031.00
#
#     Total background counts         : 3406.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.46
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_26
#
#     Total counts                    : 4942
#     Total predicted counts          : 4944.90
#     Total off counts                : 17008.00
#
#     Total background counts         : 3401.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.61
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_27
#
#     Total counts                    : 4927
#     Total predicted counts          : 4959.30
#     Total off counts                : 17080.00
#
#     Total background counts         : 3416.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.77
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_28
#
#     Total counts                    : 4911
#     Total predicted counts          : 4879.50
#     Total off counts                : 16681.00
#
#     Total background counts         : 3336.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.85
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_29
#
#     Total counts                    : 4941
#     Total predicted counts          : 4999.90
#     Total off counts                : 17283.00
#
#     Total background counts         : 3456.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.00
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_30
#
#     Total counts                    : 4987
#     Total predicted counts          : 4923.30
#     Total off counts                : 16900.00
#
#     Total background counts         : 3380.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.21
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_31
#
#     Total counts                    : 4839
#     Total predicted counts          : 4920.90
#     Total off counts                : 16888.00
#
#     Total background counts         : 3377.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.65
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_32
#
#     Total counts                    : 5017
#     Total predicted counts          : 4920.10
#     Total off counts                : 16884.00
#
#     Total background counts         : 3376.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 15.86
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_33
#
#     Total counts                    : 5002
#     Total predicted counts          : 4915.90
#     Total off counts                : 16863.00
#
#     Total background counts         : 3372.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.18
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_34
#
#     Total counts                    : 4970
#     Total predicted counts          : 4924.90
#     Total off counts                : 16908.00
#
#     Total background counts         : 3381.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.14
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_35
#
#     Total counts                    : 4921
#     Total predicted counts          : 4931.70
#     Total off counts                : 16942.00
#
#     Total background counts         : 3388.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.10
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_36
#
#     Total counts                    : 4966
#     Total predicted counts          : 4908.10
#     Total off counts                : 16824.00
#
#     Total background counts         : 3364.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.28
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_37
#
#     Total counts                    : 5008
#     Total predicted counts          : 4961.10
#     Total off counts                : 17089.00
#
#     Total background counts         : 3417.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 14.34
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_38
#
#     Total counts                    : 4951
#     Total predicted counts          : 4933.30
#     Total off counts                : 16950.00
#
#     Total background counts         : 3390.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.48
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_39
#
#     Total counts                    : 5057
#     Total predicted counts          : 4899.30
#     Total off counts                : 16780.00
#
#     Total background counts         : 3356.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.23
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_40
#
#     Total counts                    : 4956
#     Total predicted counts          : 4895.90
#     Total off counts                : 16763.00
#
#     Total background counts         : 3352.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_41
#
#     Total counts                    : 4919
#     Total predicted counts          : 4927.70
#     Total off counts                : 16922.00
#
#     Total background counts         : 3384.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.16
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_42
#
#     Total counts                    : 4904
#     Total predicted counts          : 4915.70
#     Total off counts                : 16862.00
#
#     Total background counts         : 3372.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.63
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_43
#
#     Total counts                    : 4779
#     Total predicted counts          : 4920.10
#     Total off counts                : 16884.00
#
#     Total background counts         : 3376.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 15.94
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_44
#
#     Total counts                    : 4985
#     Total predicted counts          : 4971.30
#     Total off counts                : 17140.00
#
#     Total background counts         : 3428.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 12.52
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_45
#
#     Total counts                    : 4772
#     Total predicted counts          : 4925.30
#     Total off counts                : 16910.00
#
#     Total background counts         : 3382.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.97
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_46
#
#     Total counts                    : 4891
#     Total predicted counts          : 4926.30
#     Total off counts                : 16915.00
#
#     Total background counts         : 3383.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 21.53
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_47
#
#     Total counts                    : 4931
#     Total predicted counts          : 4921.70
#     Total off counts                : 16892.00
#
#     Total background counts         : 3378.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.40
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_48
#
#     Total counts                    : 4865
#     Total predicted counts          : 4967.10
#     Total off counts                : 17119.00
#
#     Total background counts         : 3423.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.74
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_49
#
#     Total counts                    : 5107
#     Total predicted counts          : 4906.10
#     Total off counts                : 16814.00
#
#     Total background counts         : 3362.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 13.25
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_50
#
#     Total counts                    : 4922
#     Total predicted counts          : 4969.10
#     Total off counts                : 17129.00
#
#     Total background counts         : 3425.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.96
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_51
#
#     Total counts                    : 4896
#     Total predicted counts          : 4958.10
#     Total off counts                : 17074.00
#
#     Total background counts         : 3414.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.34
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_52
#
#     Total counts                    : 4876
#     Total predicted counts          : 4919.10
#     Total off counts                : 16879.00
#
#     Total background counts         : 3375.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.64
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_53
#
#     Total counts                    : 4993
#     Total predicted counts          : 4953.50
#     Total off counts                : 17051.00
#
#     Total background counts         : 3410.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.50
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_54
#
#     Total counts                    : 4862
#     Total predicted counts          : 4911.90
#     Total off counts                : 16843.00
#
#     Total background counts         : 3368.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.42
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_55
#
#     Total counts                    : 4984
#     Total predicted counts          : 4926.10
#     Total off counts                : 16914.00
#
#     Total background counts         : 3382.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.28
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_56
#
#     Total counts                    : 4962
#     Total predicted counts          : 4888.10
#     Total off counts                : 16724.00
#
#     Total background counts         : 3344.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.15
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_57
#
#     Total counts                    : 4975
#     Total predicted counts          : 4928.50
#     Total off counts                : 16926.00
#
#     Total background counts         : 3385.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.72
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_58
#
#     Total counts                    : 4895
#     Total predicted counts          : 4934.30
#     Total off counts                : 16955.00
#
#     Total background counts         : 3391.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.58
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_59
#
#     Total counts                    : 4911
#     Total predicted counts          : 4926.50
#     Total off counts                : 16916.00
#
#     Total background counts         : 3383.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.53
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_60
#
#     Total counts                    : 4821
#     Total predicted counts          : 4910.70
#     Total off counts                : 16837.00
#
#     Total background counts         : 3367.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.72
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_61
#
#     Total counts                    : 5070
#     Total predicted counts          : 4936.30
#     Total off counts                : 16965.00
#
#     Total background counts         : 3393.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.68
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_62
#
#     Total counts                    : 5009
#     Total predicted counts          : 4967.10
#     Total off counts                : 17119.00
#
#     Total background counts         : 3423.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.26
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_63
#
#     Total counts                    : 4934
#     Total predicted counts          : 4929.30
#     Total off counts                : 16930.00
#
#     Total background counts         : 3386.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.01
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_64
#
#     Total counts                    : 4884
# ...
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.50
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_104
#
#     Total counts                    : 4839
#     Total predicted counts          : 4883.50
#     Total off counts                : 16701.00
#
#     Total background counts         : 3340.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.60
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_105
#
#     Total counts                    : 4953
#     Total predicted counts          : 4935.70
#     Total off counts                : 16962.00
#
#     Total background counts         : 3392.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.26
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_106
#
#     Total counts                    : 4947
#     Total predicted counts          : 4917.70
#     Total off counts                : 16872.00
#
#     Total background counts         : 3374.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.95
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_107
#
#     Total counts                    : 4916
#     Total predicted counts          : 4916.10
#     Total off counts                : 16864.00
#
#     Total background counts         : 3372.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.17
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_108
#
#     Total counts                    : 4944
#     Total predicted counts          : 4979.10
#     Total off counts                : 17179.00
#
#     Total background counts         : 3435.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.36
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_109
#
#     Total counts                    : 4960
#     Total predicted counts          : 4961.50
#     Total off counts                : 17091.00
#
#     Total background counts         : 3418.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.06
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_110
#
#     Total counts                    : 4793
#     Total predicted counts          : 4935.10
#     Total off counts                : 16959.00
#
#     Total background counts         : 3391.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.79
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_111
#
#     Total counts                    : 4858
#     Total predicted counts          : 4912.70
#     Total off counts                : 16847.00
#
#     Total background counts         : 3369.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.56
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_112
#
#     Total counts                    : 4992
#     Total predicted counts          : 4930.90
#     Total off counts                : 16938.00
#
#     Total background counts         : 3387.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.51
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_113
#
#     Total counts                    : 4973
#     Total predicted counts          : 4903.90
#     Total off counts                : 16803.00
#
#     Total background counts         : 3360.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.97
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_114
#
#     Total counts                    : 4901
#     Total predicted counts          : 4925.90
#     Total off counts                : 16913.00
#
#     Total background counts         : 3382.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.79
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_115
#
#     Total counts                    : 4910
#     Total predicted counts          : 4937.50
#     Total off counts                : 16971.00
#
#     Total background counts         : 3394.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.28
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_116
#
#     Total counts                    : 4964
#     Total predicted counts          : 4897.90
#     Total off counts                : 16773.00
#
#     Total background counts         : 3354.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 11.42
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_117
#
#     Total counts                    : 4844
#     Total predicted counts          : 4943.50
#     Total off counts                : 17001.00
#
#     Total background counts         : 3400.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.67
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_118
#
#     Total counts                    : 4981
#     Total predicted counts          : 4894.90
#     Total off counts                : 16758.00
#
#     Total background counts         : 3351.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.42
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_119
#
#     Total counts                    : 4904
#     Total predicted counts          : 4889.50
#     Total off counts                : 16731.00
#
#     Total background counts         : 3346.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.50
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_120
#
#     Total counts                    : 4914
#     Total predicted counts          : 4905.50
#     Total off counts                : 16811.00
#
#     Total background counts         : 3362.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.25
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_121
#
#     Total counts                    : 4871
#     Total predicted counts          : 4875.30
#     Total off counts                : 16660.00
#
#     Total background counts         : 3332.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 11.08
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_122
#
#     Total counts                    : 4906
#     Total predicted counts          : 4923.10
#     Total off counts                : 16899.00
#
#     Total background counts         : 3379.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.68
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_123
#
#     Total counts                    : 4900
#     Total predicted counts          : 4953.90
#     Total off counts                : 17053.00
#
#     Total background counts         : 3410.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.15
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_124
#
#     Total counts                    : 4903
#     Total predicted counts          : 4960.70
#     Total off counts                : 17087.00
#
#     Total background counts         : 3417.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.45
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
for i in range(7):
    n_on = [dataset.counts.data.sum() for dataset in datas[i]]
    n_off = [dataset.counts_off.data.sum() for dataset in datas[i]]
    excess = [dataset.excess.data.sum() for dataset in datas[i]]
    
    fix, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].hist(n_on)
    axes[0].set_xlabel("no. of counts\nn_on")
    axes[0].set_ylabel("No. of observations")
    axes[1].hist(n_off)
    axes[1].set_xlabel("no. of counts\nn_off")
    axes[1].set_ylabel("No. of observations")
    axes[2].hist(excess)
    axes[2].set_xlabel("no. of counts\nexcess");
    axes[2].set_ylabel("No. of observations")

# %%
# %%time
res = []
for i in range(7):
    results = []
    for dataset in datas[i]:
        dataset.models = model[i].copy()
        fit = Fit([dataset])
        result = fit.optimize()
        results.append(
            {
                "index": result.parameters["index"].value,
                "amplitude": result.parameters["amplitude"].value,
                "lambda_": result.parameters["lambda_"].value,
                "reference":result.parameters["reference"].value,
                "alpha":result.parameters["alpha"].value,
            }
        )
        print(result.parameters.to_table())
    res.append(results)
# Out:
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.243e+00   nan                nan nan  False
# amplitude 1.151e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.624e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.207e+00   nan                nan nan  False
# amplitude 1.243e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.974e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.216e+00   nan                nan nan  False
# amplitude 1.378e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.459e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.169e+00   nan                nan nan  False
# amplitude 1.521e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.359e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.233e+00   nan                nan nan  False
# amplitude 1.325e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.034e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.170e+00   nan                nan nan  False
# amplitude 1.483e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.260e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.368e+00   nan                nan nan  False
# amplitude 9.081e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.628e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.129e+00   nan                nan nan  False
# amplitude 1.625e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.258e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.221e+00   nan                nan nan  False
# amplitude 1.264e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.908e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.142e+00   nan                nan nan  False
# amplitude 1.671e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.560e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.235e+00   nan                nan nan  False
# amplitude 1.382e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.231e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.201e+00   nan                nan nan  False
# amplitude 1.383e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.235e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.185e+00   nan                nan nan  False
# amplitude 1.430e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.018e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.453e+00   nan                nan nan  False
# amplitude 7.273e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.467e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.214e+00   nan                nan nan  False
# amplitude 1.335e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.119e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.275e+00   nan                nan nan  False
# amplitude 1.029e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.670e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.188e+00   nan                nan nan  False
# amplitude 1.381e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.965e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.187e+00   nan                nan nan  False
# amplitude 1.359e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.067e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.322e+00   nan                nan nan  False
# amplitude 1.007e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.525e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.177e+00   nan                nan nan  False
# amplitude 1.334e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.936e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.150e+00   nan                nan nan  False
# amplitude 1.579e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.227e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.189e+00   nan                nan nan  False
# amplitude 1.373e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.138e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.089e+00   nan                nan nan  False
# amplitude 1.795e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.509e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.241e+00   nan                nan nan  False
# amplitude 1.285e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.116e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.221e+00   nan                nan nan  False
# amplitude 1.252e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.990e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.233e+00   nan                nan nan  False
# amplitude 1.190e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.892e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.183e+00   nan                nan nan  False
# amplitude 1.427e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.094e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.271e+00   nan                nan nan  False
# amplitude 1.117e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.825e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.123e+00   nan                nan nan  False
# amplitude 1.719e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.454e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.250e+00   nan                nan nan  False
# amplitude 1.154e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.809e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.096e+00   nan                nan nan  False
# amplitude 1.843e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.335e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.950e+00   nan                nan nan  False
# amplitude 2.810e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.211e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.290e+00   nan                nan nan  False
# amplitude 1.117e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.762e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.243e+00   nan                nan nan  False
# amplitude 1.222e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.801e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.150e+00   nan                nan nan  False
# amplitude 1.593e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.232e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.182e+00   nan                nan nan  False
# amplitude 1.402e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.098e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.163e+00   nan                nan nan  False
# amplitude 1.538e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.175e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.063e+00   nan                nan nan  False
# amplitude 2.051e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.858e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.231e+00   nan                nan nan  False
# amplitude 1.302e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.056e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.296e+00   nan                nan nan  False
# amplitude 1.051e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.603e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.326e+00   nan                nan nan  False
# amplitude 9.832e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.641e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.263e+00   nan                nan nan  False
# amplitude 1.172e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.915e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.261e+00   nan                nan nan  False
# amplitude 1.184e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.997e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.129e+00   nan                nan nan  False
# amplitude 1.540e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.354e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.365e+00   nan                nan nan  False
# amplitude 8.968e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.598e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.316e+00   nan                nan nan  False
# amplitude 9.915e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.854e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.338e+00   nan                nan nan  False
# amplitude 9.592e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.941e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.116e+00   nan                nan nan  False
# amplitude 1.609e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.058e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.122e+00   nan                nan nan  False
# amplitude 1.671e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.519e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.291e+00   nan                nan nan  False
# amplitude 1.104e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.667e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.248e+00   nan                nan nan  False
# amplitude 1.123e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.540e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.195e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.135e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.041e+00   nan                nan nan  False
# amplitude 2.204e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.871e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.080e+00   nan                nan nan  False
# amplitude 1.828e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.489e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.259e+00   nan                nan nan  False
# amplitude 1.240e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.923e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.031e+00   nan                nan nan  False
# amplitude 2.250e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.978e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.405e+00   nan                nan nan  False
# amplitude 8.254e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.513e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.156e+00   nan                nan nan  False
# amplitude 1.528e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.224e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.377e+00   nan                nan nan  False
# amplitude 7.830e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.417e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.426e+00   nan                nan nan  False
# amplitude 6.754e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.461e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.088e+00   nan                nan nan  False
# amplitude 2.053e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.717e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.047e+00   nan                nan nan  False
# amplitude 1.835e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.275e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.240e+00   nan                nan nan  False
# amplitude 1.192e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.785e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.252e+00   nan                nan nan  False
# amplitude 1.091e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.699e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.225e+00   nan                nan nan  False
# amplitude 1.286e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.090e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.350e+00   nan                nan nan  False
# amplitude 7.773e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.253e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.253e+00   nan                nan nan  False
# amplitude 1.141e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.734e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.177e+00   nan                nan nan  False
# amplitude 1.374e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.964e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.023e+00   nan                nan nan  False
# amplitude 2.271e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.715e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.126e+00   nan                nan nan  False
# amplitude 1.463e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.009e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.119e+00   nan                nan nan  False
# amplitude 1.610e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.154e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.218e+00   nan                nan nan  False
# amplitude 1.300e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.079e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.143e+00   nan                nan nan  False
# amplitude 1.559e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.285e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.177e+00   nan                nan nan  False
# amplitude 1.558e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.413e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.199e+00   nan                nan nan  False
# amplitude 1.430e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.133e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.255e+00   nan                nan nan  False
# amplitude 1.095e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.774e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.994e+00   nan                nan nan  False
# amplitude 2.431e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.869e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.194e+00   nan                nan nan  False
# amplitude 1.349e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.068e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.097e+00   nan                nan nan  False
# amplitude 1.842e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.698e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.282e+00   nan                nan nan  False
# amplitude 1.040e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.615e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.012e+00   nan                nan nan  False
# amplitude 2.272e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.524e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.086e+00   nan                nan nan  False
# amplitude 1.994e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.006e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.116e+00   nan                nan nan  False
# amplitude 1.804e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.373e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.315e+00   nan                nan nan  False
# amplitude 1.040e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.578e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.125e+00   nan                nan nan  False
# amplitude 1.718e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.304e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.101e+00   nan                nan nan  False
# amplitude 1.625e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.178e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.097e+00   nan                nan nan  False
# amplitude 1.891e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.495e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.047e+00   nan                nan nan  False
# amplitude 2.192e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.021e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.153e+00   nan                nan nan  False
# amplitude 1.650e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.384e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.276e+00   nan                nan nan  False
# amplitude 1.186e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.922e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.366e+00   nan                nan nan  False
# amplitude 8.881e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.509e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.203e+00   nan                nan nan  False
# amplitude 1.378e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.136e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.177e+00   nan                nan nan  False
# amplitude 1.476e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.294e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.181e+00   nan                nan nan  False
# amplitude 1.270e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.952e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.445e+00   nan                nan nan  False
# amplitude 7.318e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.228e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.342e+00   nan                nan nan  False
# amplitude 8.977e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.812e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.358e+00   nan                nan nan  False
# amplitude 9.283e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.865e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.065e+00   nan                nan nan  False
# amplitude 1.805e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.133e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.063e+00   nan                nan nan  False
# amplitude 1.960e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.813e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.364e+00   nan                nan nan  False
# amplitude 9.394e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.467e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.137e+00   nan                nan nan  False
# amplitude 1.491e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.020e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.244e+00   nan                nan nan  False
# amplitude 1.214e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.955e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.319e+00   nan                nan nan  False
# amplitude 9.502e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.553e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.192e+00   nan                nan nan  False
# amplitude 1.439e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.086e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.191e+00   nan                nan nan  False
# amplitude 1.286e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.892e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.235e+00   nan                nan nan  False
# amplitude 1.211e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.894e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.124e+00   nan                nan nan  False
# amplitude 1.679e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.383e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.860e+00   nan                nan nan  False
# amplitude 3.700e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.648e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.283e+00   nan                nan nan  False
# amplitude 1.074e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.836e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.226e+00   nan                nan nan  False
# amplitude 1.258e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.082e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.085e+00   nan                nan nan  False
# amplitude 1.721e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.349e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.989e+00   nan                nan nan  False
# amplitude 2.420e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.517e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.400e+00   nan                nan nan  False
# amplitude 8.198e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.387e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.276e+00   nan                nan nan  False
# amplitude 1.114e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.796e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.245e+00   nan                nan nan  False
# amplitude 1.167e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.801e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.279e+00   nan                nan nan  False
# amplitude 1.099e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.810e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.270e+00   nan                nan nan  False
# amplitude 1.170e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.971e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.359e+00   nan                nan nan  False
# amplitude 8.490e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.471e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.292e+00   nan                nan nan  False
# amplitude 9.940e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.407e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.207e+00   nan                nan nan  False
# amplitude 1.378e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.242e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.282e+00   nan                nan nan  False
# amplitude 1.137e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.926e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.139e+00   nan                nan nan  False
# amplitude 1.722e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.543e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.123e+00   nan                nan nan  False
# ...
# amplitude 2.877e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.952e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.704e+00   nan                nan nan  False
# amplitude 8.005e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.642e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.167e+00   nan                nan nan  False
# amplitude 1.531e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.987e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.286e+00   nan                nan nan  False
# amplitude 9.742e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.079e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 8.917e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.314e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.714e+00   nan                nan nan  False
# amplitude 6.942e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.633e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.193e+00   nan                nan nan  False
# amplitude 1.507e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.683e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.838e+00   nan                nan nan  False
# amplitude 3.506e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.584e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.580e+00   nan                nan nan  False
# amplitude 4.680e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.686e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.876e+00   nan                nan nan  False
# amplitude 3.623e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.899e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.104e+00   nan                nan nan  False
# amplitude 1.427e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.984e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.557e+00   nan                nan nan  False
# amplitude 3.331e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.262e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.606e+00   nan                nan nan  False
# amplitude 4.690e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.889e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.678e+00   nan                nan nan  False
# amplitude 5.732e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.385e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.160e+00   nan                nan nan  False
# amplitude 1.861e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.248e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.036e+00   nan                nan nan  False
# amplitude 2.161e-11   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.852e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.997e+00   nan                nan nan  False
# amplitude 3.062e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 4.008e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.286e+00   nan                nan nan  False
# amplitude 1.303e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.253e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 6.122e-01   nan                nan nan  False
# amplitude 3.805e-11   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.227e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.534e+00   nan                nan nan  False
# amplitude 1.454e-11   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.177e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.763e+00   nan                nan nan  False
# amplitude 4.158e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.765e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.336e+00   nan                nan nan  False
# amplitude 1.101e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.862e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.216e+00   nan                nan nan  False
# amplitude 1.625e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.140e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.831e+00   nan                nan nan  False
# amplitude 2.909e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.277e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.066e+00   nan                nan nan  False
# amplitude 2.576e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.235e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.577e+00   nan                nan nan  False
# amplitude 5.719e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 4.147e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.925e+00   nan                nan nan  False
# amplitude 3.582e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 4.439e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.389e+00   nan                nan nan  False
# amplitude 9.945e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.945e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.060e+00   nan                nan nan  False
# amplitude 2.374e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.779e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.078e+00   nan                nan nan  False
# amplitude 2.187e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.430e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.505e+00   nan                nan nan  False
# amplitude 5.192e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.176e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 9.143e-01   nan                nan nan  False
# amplitude 5.472e-11   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.887e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.074e+00   nan                nan nan  False
# amplitude 2.634e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.349e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.117e+00   nan                nan nan  False
# amplitude 1.526e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.067e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.482e+00   nan                nan nan  False
# amplitude 8.965e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.357e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.860e+00   nan                nan nan  False
# amplitude 3.749e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.813e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.567e+00   nan                nan nan  False
# amplitude 4.292e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.130e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.427e+00   nan                nan nan  False
# amplitude 9.814e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.650e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.293e+00   nan                nan nan  False
# amplitude 8.847e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.656e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.975e+00   nan                nan nan  False
# amplitude 3.522e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 4.345e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.856e+00   nan                nan nan  False
# amplitude 2.427e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.015e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# CPU times: user 15min 55s, sys: 1.16 s, total: 15min 56s
# Wall time: 16min 19s

# %%
import scipy.stats as stats
import math

# %%
index = []
amplitude = []
lambda_ = []
reference = []
alpha = []
covar = []
for i in range(7):
    a = np.array([_["index"] for _ in res[i]])
    b = np.array([_["amplitude"] for _ in res[i]])
    c = np.array([_["reference"] for _ in res[i]])
    d = np.array([_["lambda_"] for _ in res[i]])
    e = np.array([_["alpha"] for _ in res[i]])
    index.append(a)
    amplitude.append(b)
    reference.append(c)
    lambda_.append(d)
    alpha.append(e)
    
mu = [0,0,0,0,0,0,0]
sigma = [0,0,0,0,0,0,0]
np_hist = [0,0,0,0,0,0,0]
for i in range(7):
    x = np.array([index[i], amplitude[i], reference[i], lambda_[i], alpha[i]])
    covar.append(np.cov(x))

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(index[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["index"].value, color="red")
    plt.xlabel("Index")
    plt.ylabel("Number of observations")
    print(f"index: {index[n].mean()} += {index[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = index[n].mean()
    sigma[n] = index[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('Index')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(index[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["index"].value, color="green")
    plt.xlabel('Index')
    plt.ylabel('Number of observations')
    

plt.show()
# Out:
# index: 2.2135175170665473 += 0.08703082711414678
# index: 2.198654229018978 += 0.1251834417467993
# index: 2.184231118886255 += 0.1325498526648501
# index: 2.2015660637591457 += 0.1717012601260155
# index: 2.2037241150115086 += 0.19715054022232315
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# index: nan += nan
# index: nan += nan
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in greater_equal
#   return (a <= x) & (x <= b)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in less_equal
#   return (a <= x) & (x <= b)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6743: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6744: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-780bc3c65858> in <module>
#      27     ax = fig.add_subplot(gs3[n])
#      28     np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
# ---> 29     plt.hist(x=np_hist[n], bins=10, alpha=0.5)
#      30     plt.axvline(x=np_hist[n].mean(), color="red")
#      31     plt.xlabel('Index')
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6773             # this will automatically overwrite bins,
#    6774             # so that each histogram uses the same bins
# -> 6775             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6776             m = m.astype(float)  # causes problems later if it's an int
#    6777             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     783     a, weights = _ravel_and_check_weights(a, weights)
#     784
# --> 785     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     786
#     787     # Histogram is an integer or a float array depending on the weights.
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     417             raise ValueError('`bins` must be positive, when an integer')
#     418
# --> 419         first_edge, last_edge = _get_outer_edges(a, range)
#     420
#     421     elif np.ndim(bins) == 1:
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     315         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     316             raise ValueError(
# --> 317                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     318
#     319     # expand empty range to avoid divide by zero
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('index_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('index_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(amplitude[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
    plt.xlabel("amplitude")
    plt.ylabel("Number of observations")
    print(f"amplitude: {amplitude[n].mean()} += {amplitude[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = amplitude[n].mean()
    sigma[n] = amplitude[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('amplitude')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(amplitude[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["amplitude"].value, color="green")
    plt.xlabel('amplitude')
    plt.ylabel('Number of observations')
    

plt.show()

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('amplitude_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('amplitude_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(lambda_[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["lambda_"].value, color="red")
    plt.xlabel("lambda_")
    plt.ylabel("Number of observations")
    print(f"lambda_: {lambda_[n].mean()} += {lambda_[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = lambda_[n].mean()
    sigma[n] = lambda_[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('lambda_')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])    
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(lambda_[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["lambda_"].value, color="green")
    plt.xlabel('lambda_')
    plt.ylabel('Number of observations')
    

plt.show()

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('lambda_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('lambda_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
sim = [] 
for i in range(7):
    s = ExpCutoffPowerLawSpectralModel(
        index=index[i].mean(),
        amplitude=amplitude[i].mean() * u.Unit("cm-2 s-1 TeV-1"),
        reference=1 * u.TeV,
        lambda_=lambda_[i].mean() * u.Unit("TeV-1"),
        alpha = 1,
    )
    print(s)
    sim.append(s)

# %%
plt.figure(figsize=[16,8])
energy_range = [0.03, 100] * u.TeV
for i in range(7):
    sim[i].plot(energy_range)
plt.show

# %%
def evaluate_err(self, covar, energy, epsilon=1e-4):

        p_cov = covar
        eps = np.sqrt(np.diag(covar)) * epsilon

        df_dp = self._evaluate_gradient(energy, eps)
        f_cov = df_dp.T @ p_cov @ df_dp
        f_err = np.sqrt(np.diagonal(f_cov))

        q = self(energy)
        return u.Quantity([q.value, f_err], unit=q.unit)

# %%
def plot_error(
        self,
        covar,
        energy_range,
        ax=None,
        energy_unit="TeV",
        flux_unit="cm-2 s-1 TeV-1",
        energy_power=0,
        n_points=100,
        **kwargs,
    ):
        
        ax = plt.gca() if ax is None else ax

        kwargs.setdefault("facecolor", "black")
        kwargs.setdefault("alpha", 0.2)
        kwargs.setdefault("linewidth", 0)

        emin, emax = energy_range
        energy = MapAxis.from_energy_bounds(emin, emax, n_points, energy_unit).edges

        flux, flux_err = evaluate_err(self,covar,energy).to(flux_unit)

        y_lo = self._plot_scale_flux(energy, flux - flux_err, energy_power)
        y_hi = self._plot_scale_flux(energy, flux + flux_err, energy_power)

        where = (energy >= energy_range[0]) & (energy <= energy_range[1])
        ax.fill_between(energy.value, y_lo.value, y_hi.value, where=where, **kwargs)

        self._plot_format_ax(ax, energy, y_lo, energy_power)
        return ax

# %%
fig = plt.figure(figsize=[16,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(2):
    ax = fig.add_subplot(gs1[n])
    sim[n].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n], covar=covar[n],energy_range=energy_range, energy_power=2)

gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    sim[n+2].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n+2], covar=covar[n+2],energy_range=energy_range, energy_power=2)

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(2):
    ax = fig.add_subplot(gs3[n])
    sim[n+5].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n+5], covar=covar[n+5],energy_range=energy_range, energy_power=2)
    

plt.show()
