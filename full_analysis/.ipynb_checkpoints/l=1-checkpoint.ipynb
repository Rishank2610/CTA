# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from regions import CircleSkyRegion
from gammapy.spectrum import (
    SpectrumDatasetOnOff,
    SpectrumDataset,
    SpectrumDatasetMaker,
)
from gammapy.modeling import Fit, Parameter
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SpectralModel,
    SkyModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis
from itertools import combinations

# %%
livetime = [20,10,8,5,4,2,1] * u.h
n_obs = [50,100,125,200,250,500,1000]
pointing = SkyCoord(0, 0, unit="deg", frame="galactic")
offset = 0.5 * u.deg
# Reconstructed and true energy axis
energy_axis = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 10), unit="TeV", name="energy", interp="log"
)
energy_axis_true = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 31), unit="TeV", name="energy", interp="log"
)

on_region_radius = Angle("0.11 deg")
on_region = CircleSkyRegion(center=pointing, radius=on_region_radius)

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
model = []
for i in range(7):
    model_simu = ExpCutoffPowerLawSpectralModel(
        index=2.22,
        amplitude=1.289e-12 * u.Unit("cm-2 s-1 TeV-1"),
        reference=1 * u.TeV,
        lambda_=1 * u.Unit("TeV-1"),
        alpha = 1,
    )
    print(model_simu) 
    mod = SkyModel(spectral_model=model_simu)
    model.append(mod)
# Out:
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# ExpCutoffPowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.000e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)

# %%
obs = []
for i in range(len(model)):
    obs.append(Observation.create(pointing=pointing, livetime=livetime[i], irfs=irfs))
    print(obs[i])
# Out:
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 72000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 36000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 28800.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 18000.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 14400.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 7200.0 s
#
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 3600.0 s
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]

# %%
dataset = []
for i in range(len(model)):
    dataset_empty = SpectrumDataset.create(
        e_reco=energy_axis.edges, e_true=energy_axis_true.edges, region=on_region
    )
    maker = SpectrumDatasetMaker(selection=["aeff", "edisp", "background"])
    dataset.append(maker.run(dataset_empty, obs[i]))

# %%
data = []
for i in range(len(model)):
    dataset[i].model = model[i]
    dataset[i].fake(random_state=42)
    print(dataset[i])
    data.append(dataset[i])
# Out:
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 8444
#     Total predicted counts          : nan
#     Total background counts         : 8462.25
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 7.20e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 4219
#     Total predicted counts          : nan
#     Total background counts         : 4231.13
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 3.60e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 3375
#     Total predicted counts          : nan
#     Total background counts         : 3384.90
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.88e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 2108
#     Total predicted counts          : nan
#     Total background counts         : 2115.56
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.80e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 1685
#     Total predicted counts          : nan
#     Total background counts         : 1692.45
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.44e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 836
#     Total predicted counts          : nan
#     Total background counts         : 846.23
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 7.20e+03 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0
#
#
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 412
#     Total predicted counts          : nan
#     Total background counts         : 423.11
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 3.60e+03 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0

# %%
data_onoff = []
for i in range(len(model)):
    dataset_onoff = SpectrumDatasetOnOff(
        aeff=data[i].aeff,
        edisp=data[i].edisp,
        models=model[i],
        livetime=livetime[i],
        acceptance=1,
        acceptance_off=5,
    )
    dataset_onoff.fake(background_model=data[i].background)
    print(dataset_onoff)
    data_onoff.append(dataset_onoff)
# Out:
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 13091
#     Total predicted counts          : 13220.82
#     Total off counts                : 42638.00
#
#     Total background counts         : 8527.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.00e+01 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.79
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 6470
#     Total predicted counts          : 6564.61
#     Total off counts                : 21090.00
#
#     Total background counts         : 4218.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.00e+01 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.96
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 5324
#     Total predicted counts          : 5246.29
#     Total off counts                : 16845.00
#
#     Total background counts         : 3369.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.77
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 3292
#     Total predicted counts          : 3281.90
#     Total off counts                : 10543.00
#
#     Total background counts         : 2108.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 5.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.23
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 2610
#     Total predicted counts          : 2620.24
#     Total off counts                : 8408.00
#
#     Total background counts         : 1681.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 4.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.44
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 1270
#     Total predicted counts          : 1317.52
#     Total off counts                : 4241.00
#
#     Total background counts         : 848.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.74
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 653
#     Total predicted counts          : 658.06
#     Total off counts                : 2117.00
#
#     Total background counts         : 423.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 1.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 11.67
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
# %%time
datas = []
for i in range(len(model)):
    datasets = []
    for idx in range(n_obs[i]):
        data_onoff[i].fake(random_state=idx, background_model=data[i].background)
        data_onoff[i].name = f"obs_{idx}"
        datasets.append(data_onoff[i].copy())
    datas.append(datasets)
# Out:
# CPU times: user 11.1 s, sys: 81.6 ms, total: 11.2 s
# Wall time: 11.7 s

# %%
len(datas)
print(*datas[2], sep = "\n")
# Out:
# SpectrumDatasetOnOff
#
#     Name                            : obs_0
#
#     Total counts                    : 5379
#     Total predicted counts          : 5255.49
#     Total off counts                : 16891.00
#
#     Total background counts         : 3378.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.40
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_1
#
#     Total counts                    : 5126
#     Total predicted counts          : 5238.29
#     Total off counts                : 16805.00
#
#     Total background counts         : 3361.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.24
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_2
#
#     Total counts                    : 5277
#     Total predicted counts          : 5292.89
#     Total off counts                : 17078.00
#
#     Total background counts         : 3415.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.94
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_3
#
#     Total counts                    : 5257
#     Total predicted counts          : 5244.89
#     Total off counts                : 16838.00
#
#     Total background counts         : 3367.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.81
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_4
#
#     Total counts                    : 5362
#     Total predicted counts          : 5270.69
#     Total off counts                : 16967.00
#
#     Total background counts         : 3393.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.60
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_5
#
#     Total counts                    : 5174
#     Total predicted counts          : 5287.69
#     Total off counts                : 17052.00
#
#     Total background counts         : 3410.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.76
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_6
#
#     Total counts                    : 5321
#     Total predicted counts          : 5234.89
#     Total off counts                : 16788.00
#
#     Total background counts         : 3357.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.83
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_7
#
#     Total counts                    : 5304
#     Total predicted counts          : 5264.09
#     Total off counts                : 16934.00
#
#     Total background counts         : 3386.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 1.26
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_8
#
#     Total counts                    : 5157
#     Total predicted counts          : 5249.29
#     Total off counts                : 16860.00
#
#     Total background counts         : 3372.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.45
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_9
#
#     Total counts                    : 5252
#     Total predicted counts          : 5293.89
#     Total off counts                : 17083.00
#
#     Total background counts         : 3416.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.03
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_10
#
#     Total counts                    : 5348
#     Total predicted counts          : 5295.69
#     Total off counts                : 17092.00
#
#     Total background counts         : 3418.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.46
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_11
#
#     Total counts                    : 5234
#     Total predicted counts          : 5252.89
#     Total off counts                : 16878.00
#
#     Total background counts         : 3375.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.28
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_12
#
#     Total counts                    : 5312
#     Total predicted counts          : 5220.09
#     Total off counts                : 16714.00
#
#     Total background counts         : 3342.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.85
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_13
#
#     Total counts                    : 5156
#     Total predicted counts          : 5269.89
#     Total off counts                : 16963.00
#
#     Total background counts         : 3392.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 17.58
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_14
#
#     Total counts                    : 5278
#     Total predicted counts          : 5234.49
#     Total off counts                : 16786.00
#
#     Total background counts         : 3357.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.49
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_15
#
#     Total counts                    : 5203
#     Total predicted counts          : 5208.09
#     Total off counts                : 16654.00
#
#     Total background counts         : 3330.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 13.18
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_16
#
#     Total counts                    : 5290
#     Total predicted counts          : 5249.49
#     Total off counts                : 16861.00
#
#     Total background counts         : 3372.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.24
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_17
#
#     Total counts                    : 5210
#     Total predicted counts          : 5302.89
#     Total off counts                : 17128.00
#
#     Total background counts         : 3425.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.31
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_18
#
#     Total counts                    : 5306
#     Total predicted counts          : 5233.09
#     Total off counts                : 16779.00
#
#     Total background counts         : 3355.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.91
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_19
#
#     Total counts                    : 5178
#     Total predicted counts          : 5251.89
#     Total off counts                : 16873.00
#
#     Total background counts         : 3374.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.16
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_20
#
#     Total counts                    : 5337
#     Total predicted counts          : 5256.69
#     Total off counts                : 16897.00
#
#     Total background counts         : 3379.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.08
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_21
#
#     Total counts                    : 5223
#     Total predicted counts          : 5313.49
#     Total off counts                : 17181.00
#
#     Total background counts         : 3436.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.05
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_22
#
#     Total counts                    : 5172
#     Total predicted counts          : 5253.29
#     Total off counts                : 16880.00
#
#     Total background counts         : 3376.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.76
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_23
#
#     Total counts                    : 5288
#     Total predicted counts          : 5272.29
#     Total off counts                : 16975.00
#
#     Total background counts         : 3395.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.97
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_24
#
#     Total counts                    : 5273
#     Total predicted counts          : 5268.89
#     Total off counts                : 16958.00
#
#     Total background counts         : 3391.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.83
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_25
#
#     Total counts                    : 5348
#     Total predicted counts          : 5214.09
#     Total off counts                : 16684.00
#
#     Total background counts         : 3336.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.92
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_26
#
#     Total counts                    : 5335
#     Total predicted counts          : 5265.29
#     Total off counts                : 16940.00
#
#     Total background counts         : 3388.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.80
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_27
#
#     Total counts                    : 5200
#     Total predicted counts          : 5305.09
#     Total off counts                : 17139.00
#
#     Total background counts         : 3427.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.95
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_28
#
#     Total counts                    : 5203
#     Total predicted counts          : 5304.49
#     Total off counts                : 17136.00
#
#     Total background counts         : 3427.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.17
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_29
#
#     Total counts                    : 5270
#     Total predicted counts          : 5312.89
#     Total off counts                : 17178.00
#
#     Total background counts         : 3435.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.09
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_30
#
#     Total counts                    : 5338
#     Total predicted counts          : 5289.29
#     Total off counts                : 17060.00
#
#     Total background counts         : 3412.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.72
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_31
#
#     Total counts                    : 5158
#     Total predicted counts          : 5254.89
#     Total off counts                : 16888.00
#
#     Total background counts         : 3377.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 12.73
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_32
#
#     Total counts                    : 5246
#     Total predicted counts          : 5266.29
#     Total off counts                : 16945.00
#
#     Total background counts         : 3389.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.21
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_33
#
#     Total counts                    : 5302
#     Total predicted counts          : 5248.29
#     Total off counts                : 16855.00
#
#     Total background counts         : 3371.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 15.32
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_34
#
#     Total counts                    : 5130
#     Total predicted counts          : 5258.89
#     Total off counts                : 16908.00
#
#     Total background counts         : 3381.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.20
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_35
#
#     Total counts                    : 5201
#     Total predicted counts          : 5265.69
#     Total off counts                : 16942.00
#
#     Total background counts         : 3388.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.86
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_36
#
#     Total counts                    : 5271
#     Total predicted counts          : 5260.49
#     Total off counts                : 16916.00
#
#     Total background counts         : 3383.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.91
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_37
#
#     Total counts                    : 5208
#     Total predicted counts          : 5270.69
#     Total off counts                : 16967.00
#
#     Total background counts         : 3393.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.22
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_38
#
#     Total counts                    : 5290
#     Total predicted counts          : 5267.29
#     Total off counts                : 16950.00
#
#     Total background counts         : 3390.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.49
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_39
#
#     Total counts                    : 5317
#     Total predicted counts          : 5226.69
#     Total off counts                : 16747.00
#
#     Total background counts         : 3349.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.64
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_40
#
#     Total counts                    : 5317
#     Total predicted counts          : 5229.89
#     Total off counts                : 16763.00
#
#     Total background counts         : 3352.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.10
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_41
#
#     Total counts                    : 5198
#     Total predicted counts          : 5266.69
#     Total off counts                : 16947.00
#
#     Total background counts         : 3389.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.56
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_42
#
#     Total counts                    : 5243
#     Total predicted counts          : 5291.49
#     Total off counts                : 17071.00
#
#     Total background counts         : 3414.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.30
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_43
#
#     Total counts                    : 5242
#     Total predicted counts          : 5254.09
#     Total off counts                : 16884.00
#
#     Total background counts         : 3376.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.63
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_44
#
#     Total counts                    : 5325
#     Total predicted counts          : 5305.29
#     Total off counts                : 17140.00
#
#     Total background counts         : 3428.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.41
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_45
#
#     Total counts                    : 5133
#     Total predicted counts          : 5259.29
#     Total off counts                : 16910.00
#
#     Total background counts         : 3382.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 11.35
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_46
#
#     Total counts                    : 5270
#     Total predicted counts          : 5177.89
#     Total off counts                : 16503.00
#
#     Total background counts         : 3300.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.40
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_47
#
#     Total counts                    : 5279
#     Total predicted counts          : 5255.69
#     Total off counts                : 16892.00
#
#     Total background counts         : 3378.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 15.88
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_48
#
#     Total counts                    : 5140
#     Total predicted counts          : 5294.29
#     Total off counts                : 17085.00
#
#     Total background counts         : 3417.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 12.92
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_49
#
#     Total counts                    : 5336
#     Total predicted counts          : 5251.29
#     Total off counts                : 16870.00
#
#     Total background counts         : 3374.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.35
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_50
#
#     Total counts                    : 5363
#     Total predicted counts          : 5267.69
#     Total off counts                : 16952.00
#
#     Total background counts         : 3390.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.67
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_51
#
#     Total counts                    : 5166
#     Total predicted counts          : 5292.09
#     Total off counts                : 17074.00
#
#     Total background counts         : 3414.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.18
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_52
#
#     Total counts                    : 5303
#     Total predicted counts          : 5251.29
#     Total off counts                : 16870.00
#
#     Total background counts         : 3374.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.54
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_53
#
#     Total counts                    : 5367
#     Total predicted counts          : 5277.89
#     Total off counts                : 17003.00
#
#     Total background counts         : 3400.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.98
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_54
#
#     Total counts                    : 5163
#     Total predicted counts          : 5272.49
#     Total off counts                : 16976.00
#
#     Total background counts         : 3395.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.35
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_55
#
#     Total counts                    : 5358
#     Total predicted counts          : 5244.09
#     Total off counts                : 16834.00
#
#     Total background counts         : 3366.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 10.32
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_56
#
#     Total counts                    : 5280
#     Total predicted counts          : 5238.89
#     Total off counts                : 16808.00
#
#     Total background counts         : 3361.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.76
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_57
#
#     Total counts                    : 5207
#     Total predicted counts          : 5279.49
#     Total off counts                : 17011.00
#
#     Total background counts         : 3402.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.67
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_58
#
#     Total counts                    : 5183
#     Total predicted counts          : 5292.69
#     Total off counts                : 17077.00
#
#     Total background counts         : 3415.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.50
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_59
#
#     Total counts                    : 5269
#     Total predicted counts          : 5260.49
#     Total off counts                : 16916.00
#
#     Total background counts         : 3383.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.99
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_60
#
#     Total counts                    : 5221
#     Total predicted counts          : 5274.69
#     Total off counts                : 16987.00
#
#     Total background counts         : 3397.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.59
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_61
#
#     Total counts                    : 5419
#     Total predicted counts          : 5237.69
#     Total off counts                : 16802.00
#
#     Total background counts         : 3360.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 18.99
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_62
#
#     Total counts                    : 5314
#     Total predicted counts          : 5257.69
#     Total off counts                : 16902.00
#
#     Total background counts         : 3380.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.35
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_63
#
#     Total counts                    : 5267
#     Total predicted counts          : 5274.09
#     Total off counts                : 16984.00
#
#     Total background counts         : 3396.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 1.71
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_64
#
#     Total counts                    : 5216
# ...
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.12
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_104
#
#     Total counts                    : 5179
#     Total predicted counts          : 5252.69
#     Total off counts                : 16877.00
#
#     Total background counts         : 3375.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.40
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_105
#
#     Total counts                    : 5239
#     Total predicted counts          : 5255.09
#     Total off counts                : 16889.00
#
#     Total background counts         : 3377.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.98
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_106
#
#     Total counts                    : 5257
#     Total predicted counts          : 5251.69
#     Total off counts                : 16872.00
#
#     Total background counts         : 3374.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.80
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_107
#
#     Total counts                    : 5313
#     Total predicted counts          : 5259.49
#     Total off counts                : 16911.00
#
#     Total background counts         : 3382.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.16
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_108
#
#     Total counts                    : 5285
#     Total predicted counts          : 5313.09
#     Total off counts                : 17179.00
#
#     Total background counts         : 3435.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.67
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_109
#
#     Total counts                    : 5379
#     Total predicted counts          : 5272.69
#     Total off counts                : 16977.00
#
#     Total background counts         : 3395.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.99
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_110
#
#     Total counts                    : 5275
#     Total predicted counts          : 5269.09
#     Total off counts                : 16959.00
#
#     Total background counts         : 3391.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.82
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_111
#
#     Total counts                    : 5292
#     Total predicted counts          : 5177.29
#     Total off counts                : 16500.00
#
#     Total background counts         : 3300.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 16.75
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_112
#
#     Total counts                    : 5342
#     Total predicted counts          : 5264.89
#     Total off counts                : 16938.00
#
#     Total background counts         : 3387.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 6.73
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_113
#
#     Total counts                    : 5245
#     Total predicted counts          : 5288.29
#     Total off counts                : 17055.00
#
#     Total background counts         : 3411.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.42
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_114
#
#     Total counts                    : 5222
#     Total predicted counts          : 5259.89
#     Total off counts                : 16913.00
#
#     Total background counts         : 3382.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.27
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_115
#
#     Total counts                    : 5380
#     Total predicted counts          : 5271.49
#     Total off counts                : 16971.00
#
#     Total background counts         : 3394.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 4.13
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_116
#
#     Total counts                    : 5245
#     Total predicted counts          : 5283.69
#     Total off counts                : 17032.00
#
#     Total background counts         : 3406.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 13.99
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
# SpectrumDatasetOnOff
#
#     Name                            : obs_117
#
#     Total counts                    : 5167
#     Total predicted counts          : 5277.49
#     Total off counts                : 17001.00
#
#     Total background counts         : 3400.20
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.89
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_118
#
#     Total counts                    : 5259
#     Total predicted counts          : 5249.09
#     Total off counts                : 16859.00
#
#     Total background counts         : 3371.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.11
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_119
#
#     Total counts                    : 5276
#     Total predicted counts          : 5262.09
#     Total off counts                : 16924.00
#
#     Total background counts         : 3384.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 12.74
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_120
#
#     Total counts                    : 5253
#     Total predicted counts          : 5250.09
#     Total off counts                : 16864.00
#
#     Total background counts         : 3372.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 3.65
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_121
#
#     Total counts                    : 5227
#     Total predicted counts          : 5243.89
#     Total off counts                : 16833.00
#
#     Total background counts         : 3366.60
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 8.80
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_122
#
#     Total counts                    : 5200
#     Total predicted counts          : 5252.09
#     Total off counts                : 16874.00
#
#     Total background counts         : 3374.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 7.39
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_123
#
#     Total counts                    : 5293
#     Total predicted counts          : 5264.69
#     Total off counts                : 16937.00
#
#     Total background counts         : 3387.40
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.19
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0
#
# SpectrumDatasetOnOff
#
#     Name                            : obs_124
#
#     Total counts                    : 5240
#     Total predicted counts          : 5308.09
#     Total off counts                : 17154.00
#
#     Total background counts         : 3430.80
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 2.58
#
#     Number of parameters            : 5
#     Number of free parameters       : 3
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
for i in range(7):
    n_on = [dataset.counts.data.sum() for dataset in datas[i]]
    n_off = [dataset.counts_off.data.sum() for dataset in datas[i]]
    excess = [dataset.excess.data.sum() for dataset in datas[i]]
    
    fix, axes = plt.subplots(1, 3, figsize=(12, 4))
    axes[0].hist(n_on)
    axes[0].set_xlabel("no. of counts\nn_on")
    axes[0].set_ylabel("No. of observations")
    axes[1].hist(n_off)
    axes[1].set_xlabel("no. of counts\nn_off")
    axes[1].set_ylabel("No. of observations")
    axes[2].hist(excess)
    axes[2].set_xlabel("no. of counts\nexcess");
    axes[2].set_ylabel("No. of observations")

# %%
# %%time
res = []
for i in range(7):
    results = []
    for dataset in datas[i]:
        dataset.models = model[i].copy()
        fit = Fit([dataset])
        result = fit.optimize()
        results.append(
            {
                "index": result.parameters["index"].value,
                "amplitude": result.parameters["amplitude"].value,
                "lambda_": result.parameters["lambda_"].value,
                "reference":result.parameters["reference"].value,
                "alpha":result.parameters["alpha"].value,
            }
        )
        print(result.parameters.to_table())
    res.append(results)
# Out:
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.239e+00   nan                nan nan  False
# amplitude 1.186e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.815e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.295e+00   nan                nan nan  False
# amplitude 1.072e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.538e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.281e+00   nan                nan nan  False
# amplitude 1.122e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.918e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.197e+00   nan                nan nan  False
# amplitude 1.409e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.183e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.230e+00   nan                nan nan  False
# amplitude 1.334e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.084e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.157e+00   nan                nan nan  False
# amplitude 1.516e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.293e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.269e+00   nan                nan nan  False
# amplitude 1.171e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.822e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.231e+00   nan                nan nan  False
# amplitude 1.263e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.734e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.197e+00   nan                nan nan  False
# amplitude 1.356e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.036e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.300e+00   nan                nan nan  False
# amplitude 1.063e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.465e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.241e+00   nan                nan nan  False
# amplitude 1.228e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.025e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.188e+00   nan                nan nan  False
# amplitude 1.374e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.029e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.163e+00   nan                nan nan  False
# amplitude 1.432e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.992e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.255e+00   nan                nan nan  False
# amplitude 1.179e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.974e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.254e+00   nan                nan nan  False
# amplitude 1.192e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.293e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.233e+00   nan                nan nan  False
# amplitude 1.173e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.035e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.155e+00   nan                nan nan  False
# amplitude 1.486e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.160e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.141e+00   nan                nan nan  False
# amplitude 1.596e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.259e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.265e+00   nan                nan nan  False
# amplitude 1.195e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.614e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.149e+00   nan                nan nan  False
# amplitude 1.528e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.130e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.235e+00   nan                nan nan  False
# amplitude 1.287e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.953e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.172e+00   nan                nan nan  False
# amplitude 1.425e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.179e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.202e+00   nan                nan nan  False
# amplitude 1.338e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.094e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.213e+00   nan                nan nan  False
# amplitude 1.262e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.997e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.219e+00   nan                nan nan  False
# amplitude 1.256e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.752e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.217e+00   nan                nan nan  False
# amplitude 1.301e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.921e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.282e+00   nan                nan nan  False
# amplitude 1.131e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.551e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.208e+00   nan                nan nan  False
# amplitude 1.286e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.526e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.253e+00   nan                nan nan  False
# amplitude 1.182e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.927e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.184e+00   nan                nan nan  False
# amplitude 1.369e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.784e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.158e+00   nan                nan nan  False
# amplitude 1.572e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.223e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.318e+00   nan                nan nan  False
# amplitude 1.061e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.023e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.290e+00   nan                nan nan  False
# amplitude 1.070e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.549e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.178e+00   nan                nan nan  False
# amplitude 1.423e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.083e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.233e+00   nan                nan nan  False
# amplitude 1.194e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.194e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.195e+00   nan                nan nan  False
# amplitude 1.350e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.032e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.237e+00   nan                nan nan  False
# amplitude 1.272e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.961e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.245e+00   nan                nan nan  False
# amplitude 1.212e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.838e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.217e+00   nan                nan nan  False
# amplitude 1.370e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.084e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.215e+00   nan                nan nan  False
# amplitude 1.311e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.737e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.187e+00   nan                nan nan  False
# amplitude 1.383e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.039e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.213e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.144e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.186e+00   nan                nan nan  False
# amplitude 1.338e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.035e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.113e+00   nan                nan nan  False
# amplitude 1.612e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.182e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.303e+00   nan                nan nan  False
# amplitude 1.071e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.450e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.290e+00   nan                nan nan  False
# amplitude 1.017e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.509e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.286e+00   nan                nan nan  False
# amplitude 1.083e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.638e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.203e+00   nan                nan nan  False
# amplitude 1.421e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.108e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.216e+00   nan                nan nan  False
# amplitude 1.295e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.077e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.119e+00   nan                nan nan  False
# amplitude 1.625e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.192e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.278e+00   nan                nan nan  False
# amplitude 1.132e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.365e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.104e+00   nan                nan nan  False
# amplitude 1.605e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.299e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.256e+00   nan                nan nan  False
# amplitude 1.231e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.118e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.128e+00   nan                nan nan  False
# amplitude 1.683e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.415e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.265e+00   nan                nan nan  False
# amplitude 1.220e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.014e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.168e+00   nan                nan nan  False
# amplitude 1.408e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.231e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.343e+00   nan                nan nan  False
# amplitude 9.574e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.922e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.149e+00   nan                nan nan  False
# amplitude 1.480e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.112e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.205e+00   nan                nan nan  False
# amplitude 1.303e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.873e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.361e+00   nan                nan nan  False
# amplitude 9.248e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.955e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.265e+00   nan                nan nan  False
# amplitude 1.299e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.108e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.154e+00   nan                nan nan  False
# amplitude 1.486e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.122e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.158e+00   nan                nan nan  False
# amplitude 1.498e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.115e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.212e+00   nan                nan nan  False
# amplitude 1.398e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.167e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.240e+00   nan                nan nan  False
# amplitude 1.230e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.824e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.347e+00   nan                nan nan  False
# amplitude 9.507e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.604e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.245e+00   nan                nan nan  False
# amplitude 1.239e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.971e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.179e+00   nan                nan nan  False
# amplitude 1.316e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.068e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.116e+00   nan                nan nan  False
# amplitude 1.734e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.306e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.089e+00   nan                nan nan  False
# amplitude 1.818e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.479e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.224e+00   nan                nan nan  False
# amplitude 1.357e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.073e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.159e+00   nan                nan nan  False
# amplitude 1.507e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.299e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.275e+00   nan                nan nan  False
# amplitude 1.159e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.388e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.262e+00   nan                nan nan  False
# amplitude 1.208e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.810e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.221e+00   nan                nan nan  False
# amplitude 1.229e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.248e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.211e+00   nan                nan nan  False
# amplitude 1.288e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.013e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.229e+00   nan                nan nan  False
# amplitude 1.277e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.378e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.273e+00   nan                nan nan  False
# amplitude 1.084e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.094e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.240e+00   nan                nan nan  False
# amplitude 1.234e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.878e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.197e+00   nan                nan nan  False
# amplitude 1.408e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.706e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.160e+00   nan                nan nan  False
# amplitude 1.672e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.258e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.245e+00   nan                nan nan  False
# amplitude 1.242e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.096e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.092e+00   nan                nan nan  False
# amplitude 1.791e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.352e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.242e+00   nan                nan nan  False
# amplitude 1.227e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.079e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.161e+00   nan                nan nan  False
# amplitude 1.304e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.882e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.108e+00   nan                nan nan  False
# amplitude 1.602e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.177e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.188e+00   nan                nan nan  False
# amplitude 1.438e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.154e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.299e+00   nan                nan nan  False
# amplitude 1.037e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.224e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.272e+00   nan                nan nan  False
# amplitude 1.224e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.895e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.241e+00   nan                nan nan  False
# amplitude 1.267e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.967e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.174e+00   nan                nan nan  False
# amplitude 1.457e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.035e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.278e+00   nan                nan nan  False
# amplitude 1.115e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.075e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.216e+00   nan                nan nan  False
# amplitude 1.242e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.642e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.182e+00   nan                nan nan  False
# amplitude 1.473e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.116e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.305e+00   nan                nan nan  False
# amplitude 1.088e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.792e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.269e+00   nan                nan nan  False
# amplitude 1.089e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.840e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.354e+00   nan                nan nan  False
# amplitude 8.998e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.162e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.044e+00   nan                nan nan  False
# amplitude 1.863e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.223e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.074e+00   nan                nan nan  False
# amplitude 1.846e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.413e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.269e+00   nan                nan nan  False
# amplitude 1.209e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.438e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.181e+00   nan                nan nan  False
# amplitude 1.359e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.487e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.254e+00   nan                nan nan  False
# amplitude 1.182e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.716e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.286e+00   nan                nan nan  False
# amplitude 1.098e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.955e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.243e+00   nan                nan nan  False
# amplitude 1.278e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.028e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.153e+00   nan                nan nan  False
# amplitude 1.439e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.147e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.119e+00   nan                nan nan  False
# amplitude 1.581e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.169e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.102e+00   nan                nan nan  False
# amplitude 1.546e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.128e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.116e+00   nan                nan nan  False
# amplitude 1.519e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.141e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.268e+00   nan                nan nan  False
# amplitude 1.149e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.479e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.158e+00   nan                nan nan  False
# amplitude 1.584e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.255e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.267e+00   nan                nan nan  False
# amplitude 1.135e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.314e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.038e+00   nan                nan nan  False
# amplitude 2.000e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.321e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.176e+00   nan                nan nan  False
# amplitude 1.466e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.119e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.202e+00   nan                nan nan  False
# amplitude 1.280e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.003e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.198e+00   nan                nan nan  False
# amplitude 1.340e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.036e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.180e+00   nan                nan nan  False
# amplitude 1.359e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.030e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.132e+00   nan                nan nan  False
# amplitude 1.626e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.255e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.241e+00   nan                nan nan  False
# amplitude 1.192e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.993e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.285e+00   nan                nan nan  False
# amplitude 1.123e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.846e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.207e+00   nan                nan nan  False
# amplitude 1.293e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.958e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.265e+00   nan                nan nan  False
# amplitude 1.182e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.873e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.175e+00   nan                nan nan  False
# amplitude 1.455e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.179e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.118e+00   nan                nan nan  False
# ...
# amplitude 1.158e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.239e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.285e+00   nan                nan nan  False
# amplitude 1.352e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.099e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.154e+00   nan                nan nan  False
# amplitude 1.862e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.406e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.240e+00   nan                nan nan  False
# amplitude 1.145e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.533e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.128e+00   nan                nan nan  False
# amplitude 1.301e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.268e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.062e+00   nan                nan nan  False
# amplitude 1.653e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.541e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.899e+00   nan                nan nan  False
# amplitude 3.208e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.022e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.203e+00   nan                nan nan  False
# amplitude 1.632e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.283e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.750e+00   nan                nan nan  False
# amplitude 3.368e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.101e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.191e+00   nan                nan nan  False
# amplitude 1.347e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.166e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.877e+00   nan                nan nan  False
# amplitude 2.210e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.614e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.095e+00   nan                nan nan  False
# amplitude 1.293e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.503e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.740e+00   nan                nan nan  False
# amplitude 3.034e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.409e-02   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.493e+00   nan                nan nan  False
# amplitude 8.630e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.727e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.318e+00   nan                nan nan  False
# amplitude 1.044e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.857e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.291e+00   nan                nan nan  False
# amplitude 1.204e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.478e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.900e+00   nan                nan nan  False
# amplitude 2.723e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.056e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.453e+00   nan                nan nan  False
# amplitude 6.997e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.793e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.775e+00   nan                nan nan  False
# amplitude 3.017e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.162e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.547e+00   nan                nan nan  False
# amplitude 4.665e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.034e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.112e+00   nan                nan nan  False
# amplitude 1.799e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 8.995e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.561e+00   nan                nan nan  False
# amplitude 6.297e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.099e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.146e+00   nan                nan nan  False
# amplitude 1.732e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.209e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.497e+00   nan                nan nan  False
# amplitude 5.855e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.972e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.374e+00   nan                nan nan  False
# amplitude 7.443e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.381e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.800e+00   nan                nan nan  False
# amplitude 4.059e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.323e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.270e+00   nan                nan nan  False
# amplitude 1.001e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 9.524e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.937e+00   nan                nan nan  False
# amplitude 2.188e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.643e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.295e+00   nan                nan nan  False
# amplitude 1.063e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.766e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.318e+00   nan                nan nan  False
# amplitude 9.850e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.309e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.129e+00   nan                nan nan  False
# amplitude 1.232e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 7.115e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.503e+00   nan                nan nan  False
# amplitude 6.160e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 5.046e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.051e+00   nan                nan nan  False
# amplitude 2.118e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.358e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.065e+00   nan                nan nan  False
# amplitude 1.803e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.299e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.991e+00   nan                nan nan  False
# amplitude 2.306e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 2.243e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 1.349e+00   nan                nan nan  False
# amplitude 9.167e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 3.107e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.427e+00   nan                nan nan  False
# amplitude 7.147e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 6.252e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.118e+00   nan                nan nan  False
# amplitude 1.570e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.089e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.273e+00   nan                nan nan  False
# amplitude 1.071e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.033e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.115e+00   nan                nan nan  False
# amplitude 1.718e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.458e+00   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.566e+00   nan                nan nan  False
# amplitude 5.238e-13   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True
#   lambda_ 1.964e-01   nan          TeV-1 nan nan  False
#     alpha 1.000e+00   nan                nan nan   True
# CPU times: user 12min 28s, sys: 713 ms, total: 12min 28s
# Wall time: 13min 1s

# %%
import scipy.stats as stats
import math

# %%
index = []
amplitude = []
lambda_ = []
reference = []
alpha = []
covar = []
for i in range(7):
    a = np.array([_["index"] for _ in res[i]])
    b = np.array([_["amplitude"] for _ in res[i]])
    c = np.array([_["reference"] for _ in res[i]])
    d = np.array([_["lambda_"] for _ in res[i]])
    e = np.array([_["alpha"] for _ in res[i]])
    index.append(a)
    amplitude.append(b)
    reference.append(c)
    lambda_.append(d)
    alpha.append(e)
    
mu = [0,0,0,0,0,0,0]
sigma = [0,0,0,0,0,0,0]
np_hist = [0,0,0,0,0,0,0]
for i in range(7):
    x = np.array([index[i], amplitude[i], reference[i], lambda_[i], alpha[i]])
    covar.append(np.cov(x))

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(index[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["index"].value, color="red")
    plt.xlabel("Index")
    plt.ylabel("Number of observations")
    print(f"index: {index[n].mean()} += {index[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = index[n].mean()
    sigma[n] = index[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('Index')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(index[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["index"].value, color="green")
    plt.xlabel('Index')
    plt.ylabel('Number of observations')
    

plt.show()
# Out:
# index: 2.2206951519964524 += 0.04894175706857251
# index: 2.2040231730841047 += 0.06969954946848614
# index: 2.2092145628352955 += 0.08626525475290187
# index: 2.2097280007318507 += 0.0971659597036551
# index: 2.2013710385038174 += 0.11282996230265589
# index: 2.1859807599959016 += 0.17151467036598664
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# index: nan += nan
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in greater_equal
#   return (a <= x) & (x <= b)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in less_equal
#   return (a <= x) & (x <= b)
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6743: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/rishank/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6744: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-780bc3c65858> in <module>
#      27     ax = fig.add_subplot(gs3[n])
#      28     np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
# ---> 29     plt.hist(x=np_hist[n], bins=10, alpha=0.5)
#      30     plt.axvline(x=np_hist[n].mean(), color="red")
#      31     plt.xlabel('Index')
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6773             # this will automatically overwrite bins,
#    6774             # so that each histogram uses the same bins
# -> 6775             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6776             m = m.astype(float)  # causes problems later if it's an int
#    6777             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     783     a, weights = _ravel_and_check_weights(a, weights)
#     784
# --> 785     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     786
#     787     # Histogram is an integer or a float array depending on the weights.
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     417             raise ValueError('`bins` must be positive, when an integer')
#     418
# --> 419         first_edge, last_edge = _get_outer_edges(a, range)
#     420
#     421     elif np.ndim(bins) == 1:
#
# ~/anaconda2/envs/gammapy-0.15/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     315         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     316             raise ValueError(
# --> 317                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     318
#     319     # expand empty range to avoid divide by zero
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('index_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('index_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(amplitude[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
    plt.xlabel("amplitude")
    plt.ylabel("Number of observations")
    print(f"amplitude: {amplitude[n].mean()} += {amplitude[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = amplitude[n].mean()
    sigma[n] = amplitude[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('amplitude')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(amplitude[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["amplitude"].value, color="green")
    plt.xlabel('amplitude')
    plt.ylabel('Number of observations')
    

plt.show()

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('amplitude_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('amplitude_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
fig = plt.figure(figsize=[16,30],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 4, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[0])
for n in range(7):
    ax = fig.add_subplot(gs1[n])
    plt.hist(lambda_[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["lambda_"].value, color="red")
    plt.xlabel("lambda_")
    plt.ylabel("Number of observations")
    print(f"lambda_: {lambda_[n].mean()} += {lambda_[n].std()}")
    
gs2 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[1])
for n in range(7):
    ax = fig.add_subplot(gs2[n])
    mu[n] = lambda_[n].mean()
    sigma[n] = lambda_[n].std()
    x = np.linspace(mu[n] - 3*sigma[n], mu[n] + 3*sigma[n], n_obs[n])
    plt.plot(x, stats.norm.pdf(x, mu[n], sigma[n]))
    plt.axvline(x=mu[n], color="red")

gs3 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[2])
for n in range(7):
    ax = fig.add_subplot(gs3[n])
    np_hist[n] = np.random.normal(loc=mu[n], scale=sigma[n], size=n_obs[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.axvline(x=np_hist[n].mean(), color="red")
    plt.xlabel('lambda_')
    plt.ylabel('Number of observations')
    
gs4 = gridspec.GridSpecFromSubplotSpec(7, 1, subplot_spec=gs0[3])    
for n in range(7):
    ax = fig.add_subplot(gs4[n])
    plt.hist(x=np_hist[n], bins=10, alpha=0.5)
    plt.hist(lambda_[n], bins=10, alpha=0.5)
    plt.axvline(x=model_simu.parameters["lambda_"].value, color="green")
    plt.xlabel('lambda_')
    plt.ylabel('Number of observations')
    

plt.show()

# %%
plt.scatter(np.log10(n_obs), mu, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs')
plt.ylabel('lambda_mean')
plt.ylim(min(mu),max(mu))
plt.show()

# %%
plt.scatter(np.log10(n_obs), sigma, label= "stars", color= "green",  
            marker= "*", s=30)    
plt.xlabel('n_obs') 
plt.ylabel('lambda_std') 
plt.ylim(min(sigma),max(sigma))
plt.show()

# %%
sim = [] 
for i in range(7):
    s = ExpCutoffPowerLawSpectralModel(
        index=index[i].mean(),
        amplitude=amplitude[i].mean() * u.Unit("cm-2 s-1 TeV-1"),
        reference=1 * u.TeV,
        lambda_=lambda_[i].mean() * u.Unit("TeV-1"),
        alpha = 1,
    )
    print(s)
    sim.append(s)

# %%
plt.figure(figsize=[16,8])
energy_range = [0.03, 100] * u.TeV
for i in range(7):
    sim[i].plot(energy_range)
plt.show

# %%
def evaluate_err(self, covar, energy, epsilon=1e-4):

        p_cov = covar
        eps = np.sqrt(np.diag(covar)) * epsilon

        df_dp = self._evaluate_gradient(energy, eps)
        f_cov = df_dp.T @ p_cov @ df_dp
        f_err = np.sqrt(np.diagonal(f_cov))

        q = self(energy)
        return u.Quantity([q.value, f_err], unit=q.unit)

# %%
def plot_error(
        self,
        covar,
        energy_range,
        ax=None,
        energy_unit="TeV",
        flux_unit="cm-2 s-1 TeV-1",
        energy_power=0,
        n_points=100,
        **kwargs,
    ):
        
        ax = plt.gca() if ax is None else ax

        kwargs.setdefault("facecolor", "black")
        kwargs.setdefault("alpha", 0.2)
        kwargs.setdefault("linewidth", 0)

        emin, emax = energy_range
        energy = MapAxis.from_energy_bounds(emin, emax, n_points, energy_unit).edges

        flux, flux_err = evaluate_err(self,covar,energy).to(flux_unit)

        y_lo = self._plot_scale_flux(energy, flux - flux_err, energy_power)
        y_hi = self._plot_scale_flux(energy, flux + flux_err, energy_power)

        where = (energy >= energy_range[0]) & (energy <= energy_range[1])
        ax.fill_between(energy.value, y_lo.value, y_hi.value, where=where, **kwargs)

        self._plot_format_ax(ax, energy, y_lo, energy_power)
        return ax

# %%
fig = plt.figure(figsize=[16,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(2):
    ax = fig.add_subplot(gs1[n])
    sim[n].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n], covar=covar[n],energy_range=energy_range, energy_power=2)

gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    sim[n+2].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n+2], covar=covar[n+2],energy_range=energy_range, energy_power=2)

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(2):
    ax = fig.add_subplot(gs3[n])
    sim[n+5].plot(energy_range=energy_range, energy_power=2)
    plot_error(self=sim[n+5], covar=covar[n+5],energy_range=energy_range, energy_power=2)
    

plt.show()
