# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from astropy.convolution import Gaussian2DKernel
from regions import CircleSkyRegion
from gammapy.spectrum import (
    SpectrumDatasetOnOff,
    SpectrumDataset,
    SpectrumDatasetMaker,
    FluxPointsEstimator,
    FluxPointsDataset,
    ReflectedRegionsBackgroundMaker,
    plot_spectrum_datasets_off_regions,
)
from gammapy.modeling import Fit, Parameter, Datasets
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SpectralModel,
    SkyModel,
    GaussianSpatialModel,
    PointSpatialModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis
from itertools import combinations
from gammapy.maps import MapAxis, WcsNDMap, WcsGeom
from gammapy.cube import MapDatasetMaker, MapDataset, SafeMaskMaker
from gammapy.detect import TSMapEstimator, find_peaks

# %%
import scipy.stats as stats
import math
import statistics

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 10.0 * u.hr
l = 0.5
pointing = SkyCoord(0, 0, unit="deg", frame="galactic")

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 40), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(0, 0), binsz=0.02, width=(6, 6), coordsys="GAL", axes=[energy_reco]
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 200), unit="TeV", name="energy", interp="log"
)

# %%
# Define sky model to used simulate the data.
# Here we use a Gaussian spatial model and a Power Law spectral model.
spatial_model = GaussianSpatialModel(
    lon_0="0.2 deg", lat_0="0.1 deg", sigma="0.5 deg", frame="galactic"
)
spectral_model = PowerLawSpectralModel(index=3, amplitude=1e-11 * u.Unit("cm-2 s-1 TeV-1"), reference=1 * u.TeV)

model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model_simu",
)
print(model_simu)
# Out:
# SkyModel
#
#    name     value   error      unit         min        max    frozen
# --------- --------- ----- -------------- ---------- --------- ------
#     lon_0 2.000e-01   nan            deg        nan       nan  False
#     lat_0 1.000e-01   nan            deg -9.000e+01 9.000e+01  False
#     sigma 5.000e-01   nan            deg  0.000e+00       nan  False
#         e 0.000e+00   nan                 0.000e+00 1.000e+00   True
#       phi 0.000e+00   nan            deg        nan       nan   True
#     index 3.000e+00   nan                       nan       nan  False
# amplitude 1.000e-11   nan cm-2 s-1 TeV-1        nan       nan  False
# reference 1.000e+00   nan            TeV        nan       nan   True

# %%
# Create an in-memory observation
obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
print(obs)
# Make the MapDataset
empty = MapDataset.create(geom)
maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=4.0 * u.deg)
dataset = maker.run(empty, obs)
dataset = maker_safe_mask.run(dataset, obs)
print(dataset)
# Out:
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 36000.0 s
#
# MapDataset
#
#     Name                            : obs_1
#
#     Total counts                    : nan
#     Total predicted counts          : 1736545.85
#     Total background counts         : 1736545.85
#
#     Exposure min                    : 0.00e+00 m2 s
#     Exposure max                    : 1.95e+11 m2 s
#
#     Number of total bins            : 0
#     Number of fit bins              : 3486132
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of models                : 1
#     Number of parameters            : 3
#     Number of free parameters       : 1
#
#     Component 0:
#         Name                        : background
#         Type                        : BackgroundModel
#         Parameters:
#             norm                    : 1.000
#             tilt         (frozen)   : 0.000
#             reference    (frozen)   : 1.000  TeV

# %%
# Add the model on the dataset and Poission fluctuate
dataset.models = model_simu
dataset.fake(random_state=42)
# Do a print on the dataset - there is now a counts maps
print(dataset)
# Out:
# MapDataset
#
#     Name                            : obs_1
#
#     Total counts                    : 1838134
#     Total predicted counts          : 1837256.07
#     Total background counts         : 1736545.85
#
#     Exposure min                    : 0.00e+00 m2 s
#     Exposure max                    : 1.95e+11 m2 s
#
#     Number of total bins            : 3510000
#     Number of fit bins              : 3486132
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : 1248718.91
#
#     Number of models                : 2
#     Number of parameters            : 11
#     Number of free parameters       : 6
#
#     Component 0:
#         Name                        : model_simu
#         Type                        : SkyModel
#         Spatial  model type         : GaussianSpatialModel
#         Spectral model type         : PowerLawSpectralModel
#         Parameters:
#             lon_0                   : 0.200  deg
#             lat_0                   : 0.100  deg
#             sigma                   : 0.500  deg
#             e            (frozen)   : 0.000
#             phi          (frozen)   : 0.000  deg
#             index                   : 3.000
#             amplitude               : 1.00e-11  1 / (cm2 s TeV)
#             reference    (frozen)   : 1.000  TeV
#
#     Component 1:
#         Name                        : background
#         Type                        : BackgroundModel
#         Parameters:
#             norm                    : 1.000
#             tilt         (frozen)   : 0.000
#             reference    (frozen)   : 1.000  TeV

# %%
# To plot, eg, counts:
dataset.counts.smooth(0.05 * u.deg).plot_interactive(
    add_cbar=True, stretch="linear"
)
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Select energy:', layout=Layout(wid…

# %%
dataset.background_model.map.plot_interactive(add_cbar=True)
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Select energy:', layout=Layout(wid…

# %%
kernel = Gaussian2DKernel(1, mode="oversample").array
plt.imshow(kernel);

# %%
images = {
    "counts": dataset.counts.get_image_by_idx((0,)),
    "exposure": dataset.exposure.get_image_by_idx((0,)),
    "background": dataset.background_model.map.get_image_by_idx((0,)),
}

images["excess"] = images["counts"] - images["background"]

# %%
# %%time
ts_image_estimator = TSMapEstimator()
images_ts = ts_image_estimator.run(images, kernel)
print(images_ts.keys())
# Out:
# dict_keys(['ts', 'sqrt_ts', 'flux', 'flux_err', 'flux_ul', 'niter'])
# CPU times: user 11.4 s, sys: 268 ms, total: 11.7 s
# Wall time: 14.4 s

# %%
sources = find_peaks(images_ts["sqrt_ts"], threshold=5)
sources
# Out:
# <Table length=12>
#  value    x     y       ra       dec
#                        deg       deg
# float64 int64 int64  float64   float64
# ------- ----- ----- --------- ---------
#  6.8014   142   160 266.28974 -28.69868
#  6.2676   142   147 266.54292 -28.83413
#  6.2445   138   165 266.24014 -28.57825
#  6.0266   146   134 266.74934 -29.03751
#   5.608   144   154 266.38273 -28.79539
#  5.4825   138   174 266.06549 -28.48414
#  5.4204   138   142 266.68789 -28.81772
#  5.3842   128   156 266.53366 -28.50136
#  5.3813   154   137 266.59561 -29.14312
#  5.3689   124   152 266.65873 -28.47458
#  5.2815   142   167 266.15369 -28.62555
#  5.1207   139   146 266.59802 -28.79327

# %%
source_pos = SkyCoord(sources["ra"], sources["dec"])
source_pos
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(266.28974217, -28.69868214), (266.54292055, -28.83412821),
#      (266.24014316, -28.57824582), (266.74934182, -29.03751164),
#      (266.38273074, -28.79539407), (266.06549371, -28.48413779),
#      (266.68789141, -28.81772326), (266.53366313, -28.50136115),
#      (266.59561223, -29.1431189 ), (266.65872889, -28.47458354),
#      (266.15368711, -28.62555472), (266.5980177 , -28.79326922)]>

# %%
# Plot sources on top of significance sky image
images_ts["sqrt_ts"].plot(add_cbar=True)

plt.gca().scatter(
    source_pos.ra.deg,
    source_pos.dec.deg,
    transform=plt.gca().get_transform("icrs"),
    color="none",
    edgecolor="white",
    marker="o",
    s=200,
    lw=1.5,
);
