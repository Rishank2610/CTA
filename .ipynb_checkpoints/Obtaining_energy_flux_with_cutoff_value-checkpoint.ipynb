# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from regions import CircleSkyRegion
from gammapy.spectrum import (
    SpectrumDatasetOnOff,
    SpectrumDataset,
    SpectrumDatasetMaker,
    FluxPointsEstimator,
    FluxPointsDataset,
    ReflectedRegionsBackgroundMaker,
    plot_spectrum_datasets_off_regions,
)
from gammapy.modeling import Fit, Parameter
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SpectralModel,
    SkyModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis
from itertools import combinations

# %%
import scipy.stats as stats
import math
import statistics

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)

# %%
livetime = 8 * u.h
n_obs = 125
pointing = SkyCoord(0, 0, unit="deg", frame="galactic")
offset = 0.5 * u.deg
# Reconstructed and true energy axis
energy_axis = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 10), unit="TeV", name="energy", interp="log"
)
energy_axis_true = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 31), unit="TeV", name="energy", interp="log"
)

on_region_radius = Angle("0.11 deg")
on_region = CircleSkyRegion(center=pointing, radius=on_region_radius)

# %%
# Define spectral model - a simple Power Law in this case
model_simu = PowerLawSpectralModel(
    index=2.22,
    amplitude=1.289e-12 * u.Unit("cm-2 s-1 TeV-1"),
    reference=1 * u.TeV,
)
print(model_simu)
# we set the sky model used in the dataset
model = SkyModel(spectral_model=model_simu)
# Out:
# PowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True

# %%
obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
print(obs)
# Out:
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 28800.0 s
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]

# %%
# Make the SpectrumDataset
dataset_empty = SpectrumDataset.create(
    e_reco=energy_axis.edges, e_true=energy_axis_true.edges, region=on_region
)
maker = SpectrumDatasetMaker(selection=["aeff", "edisp", "background"])
dataset = maker.run(dataset_empty, obs)

# %%
# Set the model on the dataset, and fake
dataset.model = model
dataset.fake(random_state=42)
print(dataset)
# Out:
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 3375
#     Total predicted counts          : nan
#     Total background counts         : 3384.90
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 2.88e+04 s
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0

# %%
dataset_onoff = SpectrumDatasetOnOff(
    aeff=dataset.aeff,
    edisp=dataset.edisp,
    models=model,
    livetime=livetime,
    acceptance=1,
    acceptance_off=5,
)
dataset_onoff.fake(background_model=dataset.background)
print(dataset_onoff)
# Out:
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 6156
#     Total predicted counts          : 6194.99
#     Total off counts                : 16870.00
#
#     Total background counts         : 3374.00
#
#     Effective area min              : 3.44e+04 m2
#     Effective area max              : 5.41e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 9
#     Number of fit bins              : 9
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 5.57
#
#     Number of parameters            : 3
#     Number of free parameters       : 2
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
# %%time

datasets = []

for idx in range(n_obs):
    dataset_onoff.fake(random_state=idx, background_model=dataset.background)
    dataset_onoff.name = f"obs_{idx}"
    datasets.append(dataset_onoff.copy())
# Out:
# CPU times: user 377 ms, sys: 204 µs, total: 377 ms
# Wall time: 376 ms

# %%
n_on = [dataset.counts.data.sum() for dataset in datasets]
n_off = [dataset.counts_off.data.sum() for dataset in datasets]
excess = [dataset.excess.data.sum() for dataset in datasets]

fix, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].hist(n_on)
axes[0].set_xlabel("no. of counts\nn_on")
axes[0].set_ylabel("No. of observations")
axes[1].hist(n_off)
axes[1].set_xlabel("no. of counts\nn_off")
axes[1].set_ylabel("No. of observations")
axes[2].hist(excess)
axes[2].set_xlabel("no. of counts\nexcess");
axes[2].set_ylabel("No. of observations")
# Out:
# Text(0, 0.5, 'No. of observations')

# %%
# %%time
e_edges = np.logspace(-1.5, 2.0, 10) * u.TeV
results = []
fpes = []
model_best_joints = []
for dataset in datasets:
    dataset.models = model.copy()
    fit = Fit([dataset])
    result = fit.run()
    results.append(
        {
            "index": result.parameters["index"].value,
            "amplitude": result.parameters["amplitude"].value,
            "reference":result.parameters["reference"].value,
        }
    )
    print(result.parameters.to_table())
    fpe = FluxPointsEstimator(datasets=[dataset], e_edges=e_edges)
    flux_points = fpe.run()
    print(flux_points.table_formatted)
    fpes.append(flux_points)
    model_best_joint = model.copy()
    model_best_joint.spectral_model.parameters.covariance = (result.parameters.covariance)
    model_best_joints.append(model_best_joint)
# Out:
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.201e+00 1.589e-02                nan nan  False
# amplitude 1.325e-12 3.470e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.840e-11       8.852e-11       8.829e-11
#  0.121  0.077   0.190 ...       7.892e-12       7.931e-12       7.854e-12
#  0.297  0.190   0.464 ...       1.055e-12       1.065e-12       1.044e-12
#  0.726  0.464   1.136 ...       1.560e-13       1.586e-13       1.535e-13
#  1.778  1.136   2.783 ...       2.441e-14       2.487e-14       2.396e-14
#  4.354  2.783   6.813 ...       3.904e-15       4.001e-15       3.809e-15
# 10.661  6.813  16.681 ...       8.213e-16       8.577e-16       7.861e-16
# 26.102 16.681  40.842 ...       1.479e-16       1.605e-16       1.359e-16
# 63.908 40.842 100.000 ...       3.549e-17       3.896e-17       3.218e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.221e+00 1.680e-02                nan nan  False
# amplitude 1.223e-12 3.376e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.030e-11       9.095e-11       8.965e-11
#  0.121  0.077   0.190 ...       7.771e-12       7.823e-12       7.718e-12
#  0.297  0.190   0.464 ...       1.030e-12       1.040e-12       1.020e-12
#  0.726  0.464   1.136 ...       1.545e-13       1.569e-13       1.521e-13
#  1.778  1.136   2.783 ...       2.302e-14       2.346e-14       2.259e-14
#  4.354  2.783   6.813 ...       3.655e-15       3.747e-15       3.563e-15
# 10.661  6.813  16.681 ...       7.982e-16       8.314e-16       7.658e-16
# 26.102 16.681  40.842 ...       1.609e-16       1.735e-16       1.488e-16
# 63.908 40.842 100.000 ...       3.229e-17       3.575e-17       2.900e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.231e+00 1.656e-02                nan nan  False
# amplitude 1.247e-12 3.414e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.026e-11       9.016e-11       9.037e-11
#  0.121  0.077   0.190 ...       7.969e-12       8.017e-12       7.920e-12
#  0.297  0.190   0.464 ...       1.050e-12       1.062e-12       1.040e-12
#  0.726  0.464   1.136 ...       1.526e-13       1.551e-13       1.501e-13
#  1.778  1.136   2.783 ...       2.221e-14       2.266e-14       2.176e-14
#  4.354  2.783   6.813 ...       3.822e-15       3.914e-15       3.731e-15
# 10.661  6.813  16.681 ...       7.585e-16       7.902e-16       7.276e-16
# 26.102 16.681  40.842 ...       1.650e-16       1.773e-16       1.530e-16
# 63.908 40.842 100.000 ...       4.203e-17       4.549e-17       3.870e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.232e+00 1.645e-02                nan nan  False
# amplitude 1.251e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.943e-11       8.982e-11       8.904e-11
#  0.121  0.077   0.190 ...       7.928e-12       7.965e-12       7.891e-12
#  0.297  0.190   0.464 ...       1.070e-12       1.082e-12       1.059e-12
#  0.726  0.464   1.136 ...       1.526e-13       1.552e-13       1.501e-13
#  1.778  1.136   2.783 ...       2.160e-14       2.204e-14       2.118e-14
#  4.354  2.783   6.813 ...       3.813e-15       3.905e-15       3.723e-15
# 10.661  6.813  16.681 ...       8.332e-16       8.653e-16       8.019e-16
# 26.102 16.681  40.842 ...       1.690e-16       1.815e-16       1.570e-16
# 63.908 40.842 100.000 ...       3.223e-17       3.570e-17       2.894e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.251e+00 1.603e-02                nan nan  False
# amplitude 1.301e-12 3.491e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.021e-11       9.065e-11       8.976e-11
#  0.121  0.077   0.190 ...       8.180e-12       8.244e-12       8.116e-12
#  0.297  0.190   0.464 ...       1.045e-12       1.056e-12       1.034e-12
#  0.726  0.464   1.136 ...       1.589e-13       1.614e-13       1.565e-13
#  1.778  1.136   2.783 ...       2.207e-14       2.268e-14       2.148e-14
#  4.354  2.783   6.813 ...       3.751e-15       3.848e-15       3.656e-15
# 10.661  6.813  16.681 ...       8.653e-16       8.985e-16       8.329e-16
# 26.102 16.681  40.842 ...       1.605e-16       1.727e-16       1.487e-16
# 63.908 40.842 100.000 ...       3.662e-17       4.013e-17       3.329e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.221e+00 1.648e-02                nan nan  False
# amplitude 1.254e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.937e-11       8.968e-11       8.905e-11
#  0.121  0.077   0.190 ...       7.926e-12       7.969e-12       7.883e-12
#  0.297  0.190   0.464 ...       1.051e-12       1.060e-12       1.041e-12
#  0.726  0.464   1.136 ...       1.600e-13       1.626e-13       1.574e-13
#  1.778  1.136   2.783 ...       2.282e-14       2.333e-14       2.232e-14
#  4.354  2.783   6.813 ...       3.486e-15       3.573e-15       3.400e-15
# 10.661  6.813  16.681 ...       7.994e-16       8.315e-16       7.680e-16
# 26.102 16.681  40.842 ...       2.088e-16       2.214e-16       1.966e-16
# 63.908 40.842 100.000 ...       3.382e-17       3.757e-17       3.034e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.212e+00 1.630e-02                nan nan  False
# amplitude 1.287e-12 3.450e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.900e-11       8.923e-11       8.879e-11
#  0.121  0.077   0.190 ...       8.000e-12       8.059e-12       7.941e-12
#  0.297  0.190   0.464 ...       1.027e-12       1.038e-12       1.016e-12
#  0.726  0.464   1.136 ...       1.589e-13       1.614e-13       1.565e-13
#  1.778  1.136   2.783 ...       2.281e-14       2.325e-14       2.237e-14
#  4.354  2.783   6.813 ...       3.758e-15       3.853e-15       3.664e-15
# 10.661  6.813  16.681 ...       8.219e-16       8.538e-16       7.907e-16
# 26.102 16.681  40.842 ...       2.023e-16       2.152e-16       1.899e-16
# 63.908 40.842 100.000 ...       3.959e-17       4.312e-17       3.623e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.215e+00 1.608e-02                nan nan  False
# amplitude 1.293e-12 3.452e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.894e-11       8.869e-11       8.921e-11
#  0.121  0.077   0.190 ...       7.890e-12       7.904e-12       7.875e-12
#  0.297  0.190   0.464 ...       1.072e-12       1.084e-12       1.061e-12
#  0.726  0.464   1.136 ...       1.558e-13       1.583e-13       1.533e-13
#  1.778  1.136   2.783 ...       2.322e-14       2.371e-14       2.273e-14
#  4.354  2.783   6.813 ...       3.736e-15       3.835e-15       3.639e-15
# 10.661  6.813  16.681 ...       7.869e-16       8.187e-16       7.557e-16
# 26.102 16.681  40.842 ...       1.652e-16       1.778e-16       1.531e-16
# 63.908 40.842 100.000 ...       4.455e-17       4.803e-17       4.121e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.204e+00 1.615e-02                nan nan  False
# amplitude 1.294e-12 3.445e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.859e-11       8.834e-11       8.888e-11
#  0.121  0.077   0.190 ...       7.888e-12       7.921e-12       7.855e-12
#  0.297  0.190   0.464 ...       1.049e-12       1.060e-12       1.038e-12
#  0.726  0.464   1.136 ...       1.575e-13       1.600e-13       1.551e-13
#  1.778  1.136   2.783 ...       2.320e-14       2.370e-14       2.272e-14
#  4.354  2.783   6.813 ...       3.868e-15       3.964e-15       3.774e-15
# 10.661  6.813  16.681 ...       8.437e-16       8.768e-16       8.115e-16
# 26.102 16.681  40.842 ...       1.735e-16       1.857e-16       1.616e-16
# 63.908 40.842 100.000 ...       2.896e-17       3.247e-17       2.565e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.191e+00 1.606e-02                nan nan  False
# amplitude 1.323e-12 3.469e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.915e-11       8.920e-11       8.912e-11
#  0.121  0.077   0.190 ...       7.956e-12       7.980e-12       7.931e-12
#  0.297  0.190   0.464 ...       1.074e-12       1.086e-12       1.063e-12
#  0.726  0.464   1.136 ...       1.519e-13       1.551e-13       1.488e-13
#  1.778  1.136   2.783 ...       2.215e-14       2.257e-14       2.172e-14
#  4.354  2.783   6.813 ...       4.093e-15       4.188e-15       3.999e-15
# 10.661  6.813  16.681 ...       8.493e-16       8.814e-16       8.179e-16
# 26.102 16.681  40.842 ...       2.126e-16       2.255e-16       2.001e-16
# 63.908 40.842 100.000 ...       3.694e-17       4.077e-17       3.338e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.200e+00 1.622e-02                nan nan  False
# amplitude 1.303e-12 3.451e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.945e-11       8.976e-11       8.914e-11
#  0.121  0.077   0.190 ...       7.976e-12       7.995e-12       7.956e-12
#  0.297  0.190   0.464 ...       1.062e-12       1.073e-12       1.051e-12
#  0.726  0.464   1.136 ...       1.553e-13       1.579e-13       1.529e-13
#  1.778  1.136   2.783 ...       2.222e-14       2.266e-14       2.179e-14
#  4.354  2.783   6.813 ...       3.884e-15       3.986e-15       3.784e-15
# 10.661  6.813  16.681 ...       8.491e-16       8.820e-16       8.170e-16
# 26.102 16.681  40.842 ...       2.125e-16       2.250e-16       2.003e-16
# 63.908 40.842 100.000 ...       3.693e-17       4.049e-17       3.355e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.201e+00 1.603e-02                nan nan  False
# amplitude 1.306e-12 3.459e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.799e-11       8.843e-11       8.756e-11
#  0.121  0.077   0.190 ...       8.001e-12       8.035e-12       7.965e-12
#  0.297  0.190   0.464 ...       1.032e-12       1.043e-12       1.021e-12
#  0.726  0.464   1.136 ...       1.645e-13       1.676e-13       1.614e-13
#  1.778  1.136   2.783 ...       2.332e-14       2.381e-14       2.284e-14
#  4.354  2.783   6.813 ...       3.959e-15       4.051e-15       3.867e-15
# 10.661  6.813  16.681 ...       7.541e-16       7.828e-16       7.256e-16
# 26.102 16.681  40.842 ...       1.735e-16       1.856e-16       1.618e-16
# 63.908 40.842 100.000 ...       3.398e-17       3.747e-17       3.065e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.210e+00 1.574e-02                nan nan  False
# amplitude 1.329e-12 3.489e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.864e-11       8.907e-11       8.821e-11
#  0.121  0.077   0.190 ...       7.904e-12       7.932e-12       7.875e-12
#  0.297  0.190   0.464 ...       1.072e-12       1.081e-12       1.064e-12
#  0.726  0.464   1.136 ...       1.667e-13       1.691e-13       1.642e-13
#  1.778  1.136   2.783 ...       2.230e-14       2.273e-14       2.188e-14
#  4.354  2.783   6.813 ...       3.795e-15       3.894e-15       3.699e-15
# 10.661  6.813  16.681 ...       8.437e-16       8.759e-16       8.122e-16
# 26.102 16.681  40.842 ...       1.990e-16       2.116e-16       1.868e-16
# 63.908 40.842 100.000 ...       2.893e-17       3.244e-17       2.563e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.232e+00 1.607e-02                nan nan  False
# amplitude 1.303e-12 3.472e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.004e-11       9.054e-11       8.954e-11
#  0.121  0.077   0.190 ...       7.977e-12       7.967e-12       7.989e-12
#  0.297  0.190   0.464 ...       1.069e-12       1.079e-12       1.058e-12
#  0.726  0.464   1.136 ...       1.553e-13       1.578e-13       1.528e-13
#  1.778  1.136   2.783 ...       2.259e-14       2.305e-14       2.214e-14
#  4.354  2.783   6.813 ...       4.049e-15       4.151e-15       3.949e-15
# 10.661  6.813  16.681 ...       7.832e-16       8.148e-16       7.523e-16
# 26.102 16.681  40.842 ...       1.166e-16       1.293e-16       1.046e-16
# 63.908 40.842 100.000 ...       4.077e-17       4.423e-17       3.744e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.215e+00 1.580e-02                nan nan  False
# amplitude 1.350e-12 3.502e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.988e-11       8.956e-11       9.023e-11
#  0.121  0.077   0.190 ...       8.120e-12       8.182e-12       8.058e-12
#  0.297  0.190   0.464 ...       1.042e-12       1.053e-12       1.031e-12
#  0.726  0.464   1.136 ...       1.588e-13       1.613e-13       1.563e-13
#  1.778  1.136   2.783 ...       2.292e-14       2.340e-14       2.246e-14
#  4.354  2.783   6.813 ...       3.871e-15       3.965e-15       3.779e-15
# 10.661  6.813  16.681 ...       8.383e-16       8.701e-16       8.070e-16
# 26.102 16.681  40.842 ...       1.953e-16       2.087e-16       1.826e-16
# 63.908 40.842 100.000 ...       4.455e-17       4.803e-17       4.120e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.202e+00 1.646e-02                nan nan  False
# amplitude 1.264e-12 3.413e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.795e-11       8.822e-11       8.768e-11
#  0.121  0.077   0.190 ...       7.871e-12       7.871e-12       7.873e-12
#  0.297  0.190   0.464 ...       1.048e-12       1.059e-12       1.037e-12
#  0.726  0.464   1.136 ...       1.537e-13       1.562e-13       1.512e-13
#  1.778  1.136   2.783 ...       2.164e-14       2.207e-14       2.122e-14
#  4.354  2.783   6.813 ...       4.013e-15       4.107e-15       3.920e-15
# 10.661  6.813  16.681 ...       8.325e-16       8.654e-16       8.003e-16
# 26.102 16.681  40.842 ...       2.025e-16       2.153e-16       1.902e-16
# 63.908 40.842 100.000 ...       2.897e-17       3.248e-17       2.566e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.210e+00 1.636e-02                nan nan  False
# amplitude 1.264e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.855e-11       8.899e-11       8.812e-11
#  0.121  0.077   0.190 ...       7.870e-12       7.916e-12       7.824e-12
#  0.297  0.190   0.464 ...       1.052e-12       1.061e-12       1.043e-12
#  0.726  0.464   1.136 ...       1.588e-13       1.614e-13       1.562e-13
#  1.778  1.136   2.783 ...       2.172e-14       2.215e-14       2.129e-14
#  4.354  2.783   6.813 ...       3.788e-15       3.881e-15       3.697e-15
# 10.661  6.813  16.681 ...       8.491e-16       8.888e-16       8.113e-16
# 26.102 16.681  40.842 ...       1.694e-16       1.816e-16       1.576e-16
# 63.908 40.842 100.000 ...       3.827e-17       4.176e-17       3.493e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.192e+00 1.638e-02                nan nan  False
# amplitude 1.281e-12 3.436e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.870e-11       8.913e-11       8.828e-11
#  0.121  0.077   0.190 ...       7.885e-12       7.933e-12       7.837e-12
#  0.297  0.190   0.464 ...       1.069e-12       1.080e-12       1.057e-12
#  0.726  0.464   1.136 ...       1.577e-13       1.602e-13       1.553e-13
#  1.778  1.136   2.783 ...       2.115e-14       2.155e-14       2.075e-14
#  4.354  2.783   6.813 ...       4.040e-15       4.135e-15       3.948e-15
# 10.661  6.813  16.681 ...       8.744e-16       9.068e-16       8.426e-16
# 26.102 16.681  40.842 ...       1.887e-16       2.017e-16       1.762e-16
# 63.908 40.842 100.000 ...       3.554e-17       3.902e-17       3.222e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.245e+00 1.616e-02                nan nan  False
# amplitude 1.286e-12 3.469e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.023e-11       9.072e-11       8.974e-11
#  0.121  0.077   0.190 ...       8.034e-12       8.089e-12       7.979e-12
#  0.297  0.190   0.464 ...       1.064e-12       1.074e-12       1.054e-12
#  0.726  0.464   1.136 ...       1.544e-13       1.570e-13       1.518e-13
#  1.778  1.136   2.783 ...       2.295e-14       2.343e-14       2.247e-14
#  4.354  2.783   6.813 ...       3.840e-15       3.932e-15       3.750e-15
# 10.661  6.813  16.681 ...       7.463e-16       7.777e-16       7.156e-16
# 26.102 16.681  40.842 ...       1.647e-16       1.771e-16       1.528e-16
# 63.908 40.842 100.000 ...       3.938e-17       4.285e-17       3.607e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.242e+00 1.651e-02                nan nan  False
# amplitude 1.231e-12 3.422e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.865e-11       8.907e-11       8.826e-11
#  0.121  0.077   0.190 ...       7.962e-12       7.985e-12       7.938e-12
#  0.297  0.190   0.464 ...       1.053e-12       1.064e-12       1.043e-12
#  0.726  0.464   1.136 ...       1.589e-13       1.613e-13       1.565e-13
#  1.778  1.136   2.783 ...       2.207e-14       2.254e-14       2.161e-14
#  4.354  2.783   6.813 ...       3.772e-15       3.864e-15       3.682e-15
# 10.661  6.813  16.681 ...       7.456e-16       7.774e-16       7.145e-16
# 26.102 16.681  40.842 ...       1.606e-16       1.730e-16       1.487e-16
# 63.908 40.842 100.000 ...       3.375e-17       3.723e-17       3.044e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.235e+00 1.600e-02                nan nan  False
# amplitude 1.306e-12 3.484e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.970e-11       8.975e-11       8.965e-11
#  0.121  0.077   0.190 ...       8.102e-12       8.089e-12       8.116e-12
#  0.297  0.190   0.464 ...       1.055e-12       1.061e-12       1.049e-12
#  0.726  0.464   1.136 ...       1.591e-13       1.615e-13       1.566e-13
#  1.778  1.136   2.783 ...       2.243e-14       2.294e-14       2.194e-14
#  4.354  2.783   6.813 ...       3.861e-15       3.985e-15       3.741e-15
# 10.661  6.813  16.681 ...       8.597e-16       8.922e-16       8.280e-16
# 26.102 16.681  40.842 ...       1.564e-16       1.690e-16       1.444e-16
# 63.908 40.842 100.000 ...       3.056e-17       3.405e-17       2.726e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.220e+00 1.636e-02                nan nan  False
# amplitude 1.260e-12 3.423e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.823e-11       8.866e-11       8.780e-11
#  0.121  0.077   0.190 ...       8.103e-12       8.194e-12       8.014e-12
#  0.297  0.190   0.464 ...       1.044e-12       1.053e-12       1.034e-12
#  0.726  0.464   1.136 ...       1.550e-13       1.574e-13       1.525e-13
#  1.778  1.136   2.783 ...       2.234e-14       2.281e-14       2.187e-14
#  4.354  2.783   6.813 ...       3.641e-15       3.750e-15       3.535e-15
# 10.661  6.813  16.681 ...       8.382e-16       8.702e-16       8.068e-16
# 26.102 16.681  40.842 ...       1.988e-16       2.117e-16       1.863e-16
# 63.908 40.842 100.000 ...       3.381e-17       3.762e-17       3.029e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.211e+00 1.630e-02                nan nan  False
# amplitude 1.275e-12 3.432e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.892e-11       8.927e-11       8.856e-11
#  0.121  0.077   0.190 ...       7.921e-12       7.909e-12       7.935e-12
#  0.297  0.190   0.464 ...       1.047e-12       1.058e-12       1.036e-12
#  0.726  0.464   1.136 ...       1.566e-13       1.591e-13       1.542e-13
#  1.778  1.136   2.783 ...       2.243e-14       2.289e-14       2.198e-14
#  4.354  2.783   6.813 ...       3.874e-15       3.996e-15       3.757e-15
# 10.661  6.813  16.681 ...       7.603e-16       7.908e-16       7.303e-16
# 26.102 16.681  40.842 ...       1.955e-16       2.081e-16       1.833e-16
# 63.908 40.842 100.000 ...       3.960e-17       4.313e-17       3.623e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.205e+00 1.596e-02                nan nan  False
# amplitude 1.326e-12 3.487e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.846e-11       8.890e-11       8.803e-11
#  0.121  0.077   0.190 ...       8.145e-12       8.225e-12       8.064e-12
#  0.297  0.190   0.464 ...       1.041e-12       1.047e-12       1.035e-12
#  0.726  0.464   1.136 ...       1.562e-13       1.588e-13       1.537e-13
#  1.778  1.136   2.783 ...       2.317e-14       2.361e-14       2.274e-14
#  4.354  2.783   6.813 ...       3.928e-15       4.025e-15       3.833e-15
# 10.661  6.813  16.681 ...       8.641e-16       9.031e-16       8.268e-16
# 26.102 16.681  40.842 ...       1.735e-16       1.855e-16       1.617e-16
# 63.908 40.842 100.000 ...       4.094e-17       4.448e-17       3.756e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.207e+00 1.608e-02                nan nan  False
# amplitude 1.327e-12 3.488e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.058e-11       9.102e-11       9.014e-11
#  0.121  0.077   0.190 ...       7.903e-12       7.957e-12       7.849e-12
#  0.297  0.190   0.464 ...       1.050e-12       1.056e-12       1.043e-12
#  0.726  0.464   1.136 ...       1.619e-13       1.644e-13       1.594e-13
#  1.778  1.136   2.783 ...       2.296e-14       2.340e-14       2.253e-14
#  4.354  2.783   6.813 ...       3.843e-15       3.941e-15       3.746e-15
# 10.661  6.813  16.681 ...       8.438e-16       8.758e-16       8.124e-16
# 26.102 16.681  40.842 ...       2.058e-16       2.185e-16       1.934e-16
# 63.908 40.842 100.000 ...       3.828e-17       4.184e-17       3.490e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.225e+00 1.628e-02                nan nan  False
# amplitude 1.275e-12 3.446e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.970e-11       9.011e-11       8.929e-11
#  0.121  0.077   0.190 ...       7.918e-12       7.972e-12       7.864e-12
#  0.297  0.190   0.464 ...       1.053e-12       1.064e-12       1.042e-12
#  0.726  0.464   1.136 ...       1.594e-13       1.619e-13       1.570e-13
#  1.778  1.136   2.783 ...       2.298e-14       2.348e-14       2.250e-14
#  4.354  2.783   6.813 ...       3.764e-15       3.858e-15       3.672e-15
# 10.661  6.813  16.681 ...       8.059e-16       8.381e-16       7.744e-16
# 26.102 16.681  40.842 ...       1.609e-16       1.734e-16       1.488e-16
# 63.908 40.842 100.000 ...       3.228e-17       3.571e-17       2.900e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.242e+00 1.588e-02                nan nan  False
# amplitude 1.301e-12 3.475e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.973e-11       9.016e-11       8.929e-11
#  0.121  0.077   0.190 ...       8.048e-12       8.092e-12       8.003e-12
#  0.297  0.190   0.464 ...       1.076e-12       1.082e-12       1.071e-12
#  0.726  0.464   1.136 ...       1.576e-13       1.600e-13       1.552e-13
#  1.778  1.136   2.783 ...       2.306e-14       2.364e-14       2.250e-14
#  4.354  2.783   6.813 ...       3.604e-15       3.728e-15       3.485e-15
# 10.661  6.813  16.681 ...       7.892e-16       8.245e-16       7.552e-16
# 26.102 16.681  40.842 ...       1.689e-16       1.813e-16       1.569e-16
# 63.908 40.842 100.000 ...       3.668e-17       4.017e-17       3.336e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.200e+00 1.609e-02                nan nan  False
# amplitude 1.310e-12 3.473e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.840e-11       8.884e-11       8.796e-11
#  0.121  0.077   0.190 ...       7.895e-12       7.880e-12       7.911e-12
#  0.297  0.190   0.464 ...       1.062e-12       1.073e-12       1.052e-12
#  0.726  0.464   1.136 ...       1.602e-13       1.626e-13       1.577e-13
#  1.778  1.136   2.783 ...       2.301e-14       2.345e-14       2.258e-14
#  4.354  2.783   6.813 ...       3.973e-15       4.065e-15       3.883e-15
# 10.661  6.813  16.681 ...       8.507e-16       8.825e-16       8.196e-16
# 26.102 16.681  40.842 ...       1.654e-16       1.780e-16       1.533e-16
# 63.908 40.842 100.000 ...       3.398e-17       3.748e-17       3.066e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.220e+00 1.663e-02                nan nan  False
# amplitude 1.244e-12 3.410e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.937e-11       8.963e-11       8.911e-11
#  0.121  0.077   0.190 ...       7.936e-12       7.990e-12       7.882e-12
#  0.297  0.190   0.464 ...       1.052e-12       1.063e-12       1.041e-12
#  0.726  0.464   1.136 ...       1.563e-13       1.588e-13       1.539e-13
#  1.778  1.136   2.783 ...       2.238e-14       2.282e-14       2.194e-14
#  4.354  2.783   6.813 ...       3.675e-15       3.771e-15       3.582e-15
# 10.661  6.813  16.681 ...       8.058e-16       8.376e-16       7.746e-16
# 26.102 16.681  40.842 ...       1.732e-16       1.857e-16       1.611e-16
# 63.908 40.842 100.000 ...       4.085e-17       4.432e-17       3.752e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.230e+00 1.625e-02                nan nan  False
# amplitude 1.276e-12 3.443e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.080e-11       9.126e-11       9.033e-11
#  0.121  0.077   0.190 ...       7.850e-12       7.884e-12       7.816e-12
#  0.297  0.190   0.464 ...       1.061e-12       1.069e-12       1.053e-12
#  0.726  0.464   1.136 ...       1.618e-13       1.644e-13       1.592e-13
#  1.778  1.136   2.783 ...       2.302e-14       2.346e-14       2.258e-14
#  4.354  2.783   6.813 ...       3.684e-15       3.782e-15       3.588e-15
# 10.661  6.813  16.681 ...       7.180e-16       7.466e-16       6.897e-16
# 26.102 16.681  40.842 ...       1.916e-16       2.043e-16       1.795e-16
# 63.908 40.842 100.000 ...       3.225e-17       3.570e-17       2.896e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.233e+00 1.568e-02                nan nan  False
# amplitude 1.338e-12 3.522e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.012e-11       9.042e-11       8.980e-11
#  0.121  0.077   0.190 ...       8.081e-12       8.092e-12       8.070e-12
#  0.297  0.190   0.464 ...       1.096e-12       1.098e-12       1.094e-12
#  0.726  0.464   1.136 ...       1.604e-13       1.629e-13       1.580e-13
#  1.778  1.136   2.783 ...       2.194e-14       2.237e-14       2.152e-14
#  4.354  2.783   6.813 ...       3.776e-15       3.872e-15       3.682e-15
# 10.661  6.813  16.681 ...       8.992e-16       9.312e-16       8.677e-16
# 26.102 16.681  40.842 ...       1.690e-16       1.813e-16       1.571e-16
# 63.908 40.842 100.000 ...       3.812e-17       4.162e-17       3.478e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.242e+00 1.681e-02                nan nan  False
# amplitude 1.207e-12 3.371e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.902e-11       8.869e-11       8.939e-11
#  0.121  0.077   0.190 ...       8.063e-12       8.123e-12       8.003e-12
#  0.297  0.190   0.464 ...       1.019e-12       1.030e-12       1.009e-12
#  0.726  0.464   1.136 ...       1.532e-13       1.556e-13       1.507e-13
#  1.778  1.136   2.783 ...       2.304e-14       2.349e-14       2.259e-14
#  4.354  2.783   6.813 ...       3.383e-15       3.471e-15       3.296e-15
# 10.661  6.813  16.681 ...       7.939e-16       8.289e-16       7.600e-16
# 26.102 16.681  40.842 ...       1.728e-16       1.853e-16       1.607e-16
# 63.908 40.842 100.000 ...       3.215e-17       3.575e-17       2.878e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.250e+00 1.622e-02                nan nan  False
# amplitude 1.273e-12 3.461e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.012e-11       9.056e-11       8.967e-11
#  0.121  0.077   0.190 ...       8.073e-12       8.113e-12       8.031e-12
#  0.297  0.190   0.464 ...       1.081e-12       1.092e-12       1.070e-12
#  0.726  0.464   1.136 ...       1.507e-13       1.537e-13       1.479e-13
#  1.778  1.136   2.783 ...       2.276e-14       2.322e-14       2.230e-14
#  4.354  2.783   6.813 ...       3.505e-15       3.594e-15       3.417e-15
# 10.661  6.813  16.681 ...       8.428e-16       8.760e-16       8.105e-16
# 26.102 16.681  40.842 ...       1.877e-16       2.004e-16       1.755e-16
# 63.908 40.842 100.000 ...       3.663e-17       4.015e-17       3.328e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.211e+00 1.566e-02                nan nan  False
# amplitude 1.348e-12 3.518e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.934e-11       8.955e-11       8.913e-11
#  0.121  0.077   0.190 ...       7.884e-12       7.927e-12       7.842e-12
#  0.297  0.190   0.464 ...       1.098e-12       1.110e-12       1.086e-12
#  0.726  0.464   1.136 ...       1.603e-13       1.627e-13       1.578e-13
#  1.778  1.136   2.783 ...       2.451e-14       2.496e-14       2.407e-14
#  4.354  2.783   6.813 ...       3.504e-15       3.581e-15       3.427e-15
# 10.661  6.813  16.681 ...       8.758e-16       9.078e-16       8.444e-16
# 26.102 16.681  40.842 ...       1.772e-16       1.895e-16       1.653e-16
# 63.908 40.842 100.000 ...       3.961e-17       4.310e-17       3.626e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.233e+00 1.596e-02                nan nan  False
# amplitude 1.318e-12 3.486e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.016e-11       9.074e-11       8.959e-11
#  0.121  0.077   0.190 ...       8.058e-12       8.113e-12       8.003e-12
#  0.297  0.190   0.464 ...       1.040e-12       1.051e-12       1.029e-12
#  0.726  0.464   1.136 ...       1.607e-13       1.632e-13       1.583e-13
#  1.778  1.136   2.783 ...       2.353e-14       2.397e-14       2.310e-14
#  4.354  2.783   6.813 ...       3.688e-15       3.790e-15       3.588e-15
# 10.661  6.813  16.681 ...       7.830e-16       8.146e-16       7.521e-16
# 26.102 16.681  40.842 ...       1.951e-16       2.078e-16       1.828e-16
# 63.908 40.842 100.000 ...       3.669e-17       4.042e-17       3.321e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.197e+00 1.583e-02                nan nan  False
# amplitude 1.342e-12 3.502e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.908e-11       8.943e-11       8.872e-11
#  0.121  0.077   0.190 ...       7.874e-12       7.875e-12       7.874e-12
#  0.297  0.190   0.464 ...       1.081e-12       1.085e-12       1.077e-12
#  0.726  0.464   1.136 ...       1.594e-13       1.618e-13       1.569e-13
#  1.778  1.136   2.783 ...       2.330e-14       2.374e-14       2.286e-14
#  4.354  2.783   6.813 ...       3.925e-15       4.018e-15       3.833e-15
# 10.661  6.813  16.681 ...       8.805e-16       9.187e-16       8.439e-16
# 26.102 16.681  40.842 ...       1.992e-16       2.121e-16       1.868e-16
# 63.908 40.842 100.000 ...       2.900e-17       3.251e-17       2.568e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.249e+00 1.604e-02                nan nan  False
# amplitude 1.286e-12 3.472e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.974e-11       9.014e-11       8.935e-11
#  0.121  0.077   0.190 ...       8.128e-12       8.186e-12       8.071e-12
#  0.297  0.190   0.464 ...       1.072e-12       1.081e-12       1.062e-12
#  0.726  0.464   1.136 ...       1.532e-13       1.558e-13       1.505e-13
#  1.778  1.136   2.783 ...       2.278e-14       2.325e-14       2.232e-14
#  4.354  2.783   6.813 ...       3.778e-15       3.870e-15       3.688e-15
# 10.661  6.813  16.681 ...       7.703e-16       8.058e-16       7.361e-16
# 26.102 16.681  40.842 ...       1.685e-16       1.824e-16       1.555e-16
# 63.908 40.842 100.000 ...       3.515e-17       3.891e-17       3.166e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.203e+00 1.679e-02                nan nan  False
# amplitude 1.254e-12 3.404e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.046e-11       9.090e-11       9.003e-11
#  0.121  0.077   0.190 ...       7.747e-12       7.795e-12       7.699e-12
#  0.297  0.190   0.464 ...       1.049e-12       1.060e-12       1.038e-12
#  0.726  0.464   1.136 ...       1.521e-13       1.546e-13       1.496e-13
#  1.778  1.136   2.783 ...       2.248e-14       2.292e-14       2.204e-14
#  4.354  2.783   6.813 ...       3.866e-15       3.986e-15       3.751e-15
# 10.661  6.813  16.681 ...       8.051e-16       8.394e-16       7.718e-16
# 26.102 16.681  40.842 ...       2.092e-16       2.217e-16       1.970e-16
# 63.908 40.842 100.000 ...       3.692e-17       4.042e-17       3.359e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.238e+00 1.625e-02                nan nan  False
# amplitude 1.267e-12 3.438e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.945e-11       8.983e-11       8.906e-11
#  0.121  0.077   0.190 ...       8.056e-12       8.096e-12       8.016e-12
#  0.297  0.190   0.464 ...       1.070e-12       1.081e-12       1.059e-12
#  0.726  0.464   1.136 ...       1.519e-13       1.546e-13       1.492e-13
#  1.778  1.136   2.783 ...       2.259e-14       2.304e-14       2.215e-14
#  4.354  2.783   6.813 ...       3.631e-15       3.734e-15       3.530e-15
# 10.661  6.813  16.681 ...       8.042e-16       8.383e-16       7.711e-16
# 26.102 16.681  40.842 ...       1.841e-16       1.981e-16       1.709e-16
# 63.908 40.842 100.000 ...       3.525e-17       3.885e-17       3.186e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.214e+00 1.575e-02                nan nan  False
# amplitude 1.350e-12 3.515e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.939e-11       8.980e-11       8.896e-11
#  0.121  0.077   0.190 ...       8.033e-12       8.090e-12       7.977e-12
#  0.297  0.190   0.464 ...       1.060e-12       1.071e-12       1.050e-12
#  0.726  0.464   1.136 ...       1.585e-13       1.610e-13       1.560e-13
#  1.778  1.136   2.783 ...       2.301e-14       2.347e-14       2.255e-14
#  4.354  2.783   6.813 ...       3.990e-15       4.082e-15       3.899e-15
# 10.661  6.813  16.681 ...       8.338e-16       8.670e-16       8.015e-16
# 26.102 16.681  40.842 ...       1.883e-16       2.010e-16       1.761e-16
# 63.908 40.842 100.000 ...       3.959e-17       4.309e-17       3.624e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.227e+00 1.585e-02                nan nan  False
# amplitude 1.329e-12 3.502e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ...
#  0.726  0.464   1.136 ...       1.556e-13       1.580e-13       1.531e-13
#  1.778  1.136   2.783 ...       2.158e-14       2.202e-14       2.116e-14
#  4.354  2.783   6.813 ...       3.851e-15       3.943e-15       3.760e-15
# 10.661  6.813  16.681 ...       8.052e-16       8.379e-16       7.733e-16
# 26.102 16.681  40.842 ...       1.879e-16       2.005e-16       1.757e-16
# 63.908 40.842 100.000 ...       3.375e-17       3.725e-17       3.043e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.223e+00 1.586e-02                nan nan  False
# amplitude 1.305e-12 3.480e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.862e-11       8.903e-11       8.819e-11
#  0.121  0.077   0.190 ...       7.930e-12       7.984e-12       7.876e-12
#  0.297  0.190   0.464 ...       1.076e-12       1.079e-12       1.073e-12
#  0.726  0.464   1.136 ...       1.638e-13       1.665e-13       1.612e-13
#  1.778  1.136   2.783 ...       2.245e-14       2.303e-14       2.190e-14
#  4.354  2.783   6.813 ...       3.726e-15       3.829e-15       3.624e-15
# 10.661  6.813  16.681 ...       8.637e-16       8.965e-16       8.316e-16
# 26.102 16.681  40.842 ...       1.770e-16       1.895e-16       1.650e-16
# 63.908 40.842 100.000 ...       2.500e-17       2.852e-17       2.172e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.223e+00 1.596e-02                nan nan  False
# amplitude 1.322e-12 3.493e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.997e-11       8.989e-11       9.009e-11
#  0.121  0.077   0.190 ...       8.154e-12       8.229e-12       8.079e-12
#  0.297  0.190   0.464 ...       1.027e-12       1.037e-12       1.017e-12
#  0.726  0.464   1.136 ...       1.616e-13       1.641e-13       1.592e-13
#  1.778  1.136   2.783 ...       2.342e-14       2.389e-14       2.295e-14
#  4.354  2.783   6.813 ...       3.844e-15       3.939e-15       3.751e-15
# 10.661  6.813  16.681 ...       7.334e-16       7.621e-16       7.048e-16
# 26.102 16.681  40.842 ...       2.055e-16       2.180e-16       1.933e-16
# 63.908 40.842 100.000 ...       4.083e-17       4.430e-17       3.750e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.228e+00 1.602e-02                nan nan  False
# amplitude 1.308e-12 3.486e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.984e-11       9.026e-11       8.943e-11
#  0.121  0.077   0.190 ...       8.070e-12       8.090e-12       8.050e-12
#  0.297  0.190   0.464 ...       1.079e-12       1.090e-12       1.068e-12
#  0.726  0.464   1.136 ...       1.530e-13       1.560e-13       1.502e-13
#  1.778  1.136   2.783 ...       2.319e-14       2.365e-14       2.273e-14
#  4.354  2.783   6.813 ...       3.682e-15       3.795e-15       3.572e-15
# 10.661  6.813  16.681 ...       8.287e-16       8.607e-16       7.974e-16
# 26.102 16.681  40.842 ...       1.807e-16       1.934e-16       1.685e-16
# 63.908 40.842 100.000 ...       4.326e-17       4.674e-17       3.993e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.237e+00 1.613e-02                nan nan  False
# amplitude 1.287e-12 3.465e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.023e-11       9.051e-11       8.995e-11
#  0.121  0.077   0.190 ...       8.001e-12       8.053e-12       7.948e-12
#  0.297  0.190   0.464 ...       1.061e-12       1.071e-12       1.050e-12
#  0.726  0.464   1.136 ...       1.595e-13       1.620e-13       1.571e-13
#  1.778  1.136   2.783 ...       2.297e-14       2.348e-14       2.247e-14
#  4.354  2.783   6.813 ...       3.740e-15       3.835e-15       3.647e-15
# 10.661  6.813  16.681 ...       7.291e-16       7.590e-16       6.996e-16
# 26.102 16.681  40.842 ...       1.607e-16       1.732e-16       1.486e-16
# 63.908 40.842 100.000 ...       4.438e-17       4.786e-17       4.104e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.226e+00 1.667e-02                nan nan  False
# amplitude 1.244e-12 3.401e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.942e-11       8.964e-11       8.920e-11
#  0.121  0.077   0.190 ...       8.123e-12       8.216e-12       8.031e-12
#  0.297  0.190   0.464 ...       1.008e-12       1.017e-12       9.991e-13
#  0.726  0.464   1.136 ...       1.560e-13       1.585e-13       1.536e-13
#  1.778  1.136   2.783 ...       2.122e-14       2.165e-14       2.080e-14
#  4.354  2.783   6.813 ...       3.900e-15       3.995e-15       3.807e-15
# 10.661  6.813  16.681 ...       8.687e-16       9.039e-16       8.346e-16
# 26.102 16.681  40.842 ...       1.691e-16       1.815e-16       1.571e-16
# 63.908 40.842 100.000 ...       3.060e-17       3.410e-17       2.730e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.219e+00 1.683e-02                nan nan  False
# amplitude 1.209e-12 3.363e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.845e-11       8.878e-11       8.812e-11
#  0.121  0.077   0.190 ...       7.964e-12       8.022e-12       7.906e-12
#  0.297  0.190   0.464 ...       1.011e-12       1.022e-12       1.001e-12
#  0.726  0.464   1.136 ...       1.612e-13       1.640e-13       1.585e-13
#  1.778  1.136   2.783 ...       2.169e-14       2.223e-14       2.116e-14
#  4.354  2.783   6.813 ...       3.702e-15       3.805e-15       3.601e-15
# 10.661  6.813  16.681 ...       6.560e-16       6.881e-16       6.248e-16
# 26.102 16.681  40.842 ...       2.121e-16       2.246e-16       1.999e-16
# 63.908 40.842 100.000 ...       3.682e-17       4.032e-17       3.349e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.217e+00 1.591e-02                nan nan  False
# amplitude 1.337e-12 3.502e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.012e-11       9.062e-11       8.962e-11
#  0.121  0.077   0.190 ...       8.028e-12       8.070e-12       7.987e-12
#  0.297  0.190   0.464 ...       1.050e-12       1.055e-12       1.044e-12
#  0.726  0.464   1.136 ...       1.576e-13       1.601e-13       1.550e-13
#  1.778  1.136   2.783 ...       2.355e-14       2.405e-14       2.306e-14
#  4.354  2.783   6.813 ...       3.807e-15       3.905e-15       3.712e-15
# 10.661  6.813  16.681 ...       8.856e-16       9.182e-16       8.536e-16
# 26.102 16.681  40.842 ...       1.918e-16       2.047e-16       1.795e-16
# 63.908 40.842 100.000 ...       3.231e-17       3.580e-17       2.899e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.236e+00 1.635e-02                nan nan  False
# amplitude 1.266e-12 3.426e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       9.002e-11       9.050e-11       8.955e-11
#  0.121  0.077   0.190 ...       7.956e-12       8.012e-12       7.901e-12
#  0.297  0.190   0.464 ...       1.071e-12       1.077e-12       1.065e-12
#  0.726  0.464   1.136 ...       1.494e-13       1.526e-13       1.463e-13
#  1.778  1.136   2.783 ...       2.190e-14       2.245e-14       2.136e-14
#  4.354  2.783   6.813 ...       3.886e-15       3.982e-15       3.793e-15
# 10.661  6.813  16.681 ...       7.942e-16       8.262e-16       7.629e-16
# 26.102 16.681  40.842 ...       1.728e-16       1.862e-16       1.601e-16
# 63.908 40.842 100.000 ...       3.672e-17       4.021e-17       3.339e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.232e+00 1.629e-02                nan nan  False
# amplitude 1.273e-12 3.436e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.964e-11       8.944e-11       8.986e-11
#  0.121  0.077   0.190 ...       7.991e-12       8.037e-12       7.946e-12
#  0.297  0.190   0.464 ...       1.058e-12       1.069e-12       1.047e-12
#  0.726  0.464   1.136 ...       1.555e-13       1.579e-13       1.530e-13
#  1.778  1.136   2.783 ...       2.239e-14       2.283e-14       2.195e-14
#  4.354  2.783   6.813 ...       3.810e-15       3.936e-15       3.690e-15
# 10.661  6.813  16.681 ...       7.875e-16       8.206e-16       7.552e-16
# 26.102 16.681  40.842 ...       1.880e-16       2.006e-16       1.759e-16
# 63.908 40.842 100.000 ...       2.883e-17       3.232e-17       2.554e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.217e+00 1.598e-02                nan nan  False
# amplitude 1.311e-12 3.478e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.882e-11       8.926e-11       8.838e-11
#  0.121  0.077   0.190 ...       7.934e-12       7.968e-12       7.901e-12
#  0.297  0.190   0.464 ...       1.060e-12       1.071e-12       1.049e-12
#  0.726  0.464   1.136 ...       1.580e-13       1.605e-13       1.556e-13
#  1.778  1.136   2.783 ...       2.429e-14       2.474e-14       2.384e-14
#  4.354  2.783   6.813 ...       3.692e-15       3.817e-15       3.572e-15
# 10.661  6.813  16.681 ...       8.004e-16       8.320e-16       7.694e-16
# 26.102 16.681  40.842 ...       1.693e-16       1.814e-16       1.575e-16
# 63.908 40.842 100.000 ...       3.816e-17       4.203e-17       3.458e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.229e+00 1.674e-02                nan nan  False
# amplitude 1.228e-12 3.400e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.983e-11       9.031e-11       8.934e-11
#  0.121  0.077   0.190 ...       7.965e-12       8.018e-12       7.913e-12
#  0.297  0.190   0.464 ...       1.050e-12       1.059e-12       1.041e-12
#  0.726  0.464   1.136 ...       1.575e-13       1.600e-13       1.551e-13
#  1.778  1.136   2.783 ...       2.195e-14       2.246e-14       2.145e-14
#  4.354  2.783   6.813 ...       3.742e-15       3.858e-15       3.630e-15
# 10.661  6.813  16.681 ...       7.385e-16       7.701e-16       7.075e-16
# 26.102 16.681  40.842 ...       1.881e-16       2.007e-16       1.759e-16
# 63.908 40.842 100.000 ...       3.676e-17       4.026e-17       3.343e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.235e+00 1.625e-02                nan nan  False
# amplitude 1.274e-12 3.446e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.994e-11       8.976e-11       9.013e-11
#  0.121  0.077   0.190 ...       7.957e-12       8.010e-12       7.904e-12
#  0.297  0.190   0.464 ...       1.072e-12       1.077e-12       1.067e-12
#  0.726  0.464   1.136 ...       1.572e-13       1.597e-13       1.548e-13
#  1.778  1.136   2.783 ...       2.230e-14       2.275e-14       2.186e-14
#  4.354  2.783   6.813 ...       3.754e-15       3.850e-15       3.659e-15
# 10.661  6.813  16.681 ...       7.933e-16       8.252e-16       7.620e-16
# 26.102 16.681  40.842 ...       1.649e-16       1.772e-16       1.530e-16
# 63.908 40.842 100.000 ...       3.672e-17       4.021e-17       3.340e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.210e+00 1.651e-02                nan nan  False
# amplitude 1.254e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.049  0.032   0.077 ...       8.904e-11       8.945e-11       8.861e-11
#  0.121  0.077   0.190 ...       7.891e-12       7.946e-12       7.836e-12
#  0.297  0.190   0.464 ...       1.053e-12       1.063e-12       1.043e-12
#  0.726  0.464   1.136 ...       1.586e-13       1.610e-13       1.562e-13
#  1.778  1.136   2.783 ...       2.221e-14       2.272e-14       2.172e-14
#  4.354  2.783   6.813 ...       3.816e-15       3.922e-15       3.712e-15
# 10.661  6.813  16.681 ...       7.888e-16       8.205e-16       7.578e-16
# 26.102 16.681  40.842 ...       1.810e-16       1.941e-16       1.685e-16
# 63.908 40.842 100.000 ...       3.827e-17       4.177e-17       3.493e-17
# CPU times: user 1min 39s, sys: 248 ms, total: 1min 39s
# Wall time: 1min 39s

# %%
index = np.array([_["index"] for _ in results])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.xlabel('Index')
plt.ylabel('Number of observations')
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.220852816179499 += 0.016172109015838997

# %%
amplitude = np.array([_["amplitude"] for _ in results])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.xlabel('Amplitude')
plt.ylabel('Number of observations')
print(f"amplitude: {amplitude.mean()} += {amplitude.std()}")
# Out:
# amplitude: 1.2855551328222816e-12 += 3.4620322478409695e-14

# %%
reference = np.array([_["reference"] for _ in results])
x = np.array([index, amplitude, reference])
covar=np.cov(x)
print(covar)
# Out:
# [[ 2.63646280e-04 -1.45497159e-16  0.00000000e+00]
#  [-1.45497159e-16  1.20823259e-27  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
simu = PowerLawSpectralModel(
    index=index.mean(),
    amplitude=amplitude.mean() * u.Unit("cm-2 s-1 TeV-1"),
    reference=1 * u.TeV,
)
print(simu)
# Out:
# PowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.221e+00   nan                nan nan  False
# amplitude 1.286e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True

# %%
i = 0
fpes[i].table_formatted
# Out:
# <Table length=9>
#  e_ref   e_min   e_max  ...    dnde_errp       dnde_errn    is_ul
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64      bool
# ------- ------- ------- ... --------------- --------------- -----
#   0.049   0.032   0.077 ...       8.852e-11       8.829e-11 False
#   0.121   0.077   0.190 ...       7.931e-12       7.854e-12 False
#   0.297   0.190   0.464 ...       1.065e-12       1.044e-12 False
#   0.726   0.464   1.136 ...       1.586e-13       1.535e-13 False
#   1.778   1.136   2.783 ...       2.487e-14       2.396e-14 False
#   4.354   2.783   6.813 ...       4.001e-15       3.809e-15 False
#  10.661   6.813  16.681 ...       8.577e-16       7.861e-16 False
#  26.102  16.681  40.842 ...       1.605e-16       1.359e-16 False
#  63.908  40.842 100.000 ...       3.896e-17       3.218e-17 False

# %%
plt.figure(figsize=(16, 8))
fpes[i].table["is_ul"] = fpes[i].table["ts"] < 4
ax = fpes[i].plot(
    energy_power=2, flux_unit="erg-1 cm-2 s-1", color="darkorange"
)
fpes[i].to_sed_type("e2dnde").plot_ts_profiles(ax=ax)

# %%
flux_points_dataset = FluxPointsDataset(
    data=fpes[i], models=model_best_joints[i]
)

# %%
plt.figure(figsize=(16, 8))
flux_points_dataset.peek();

# %%
energy_range = [0.03, 100] * u.TeV
plt.figure(figsize=[16,8])
fpes[i].plot(energy_power=2)
simu.plot(energy_range=energy_range, energy_power=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['dnde'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['dnde'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['dnde'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['counts'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['counts'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['counts'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
x = ['ref_dnde','ref_flux','ref_eflux','ref_e2dnde','norm','stat','norm_err','counts','norm_errp','norm_errn','norm_ul','sqrt_ts','ts','norm_scan','stat_scan','dnde','dnde_ul','dnde_err','dnde_errp','dnde_errn']

# %%
flux_points_mean = fpe.run()
flux_points_mean.table_formatted
# Out:
# <Table length=9>
#  e_ref   e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64         float64
# ------- ------- ------- ... --------------- --------------- ---------------
#   0.049   0.032   0.077 ...       8.903e-11       8.945e-11       8.861e-11
#   0.121   0.077   0.190 ...       7.891e-12       7.946e-12       7.836e-12
#   0.297   0.190   0.464 ...       1.053e-12       1.063e-12       1.043e-12
#   0.726   0.464   1.136 ...       1.586e-13       1.610e-13       1.562e-13
#   1.778   1.136   2.783 ...       2.221e-14       2.272e-14       2.172e-14
#   4.354   2.783   6.813 ...       3.816e-15       3.922e-15       3.712e-15
#  10.661   6.813  16.681 ...       7.888e-16       8.205e-16       7.578e-16
#  26.102  16.681  40.842 ...       1.810e-16       1.941e-16       1.685e-16
#  63.908  40.842 100.000 ...       3.827e-17       4.177e-17       3.493e-17

# %%
for _ in x:
    y = 0
    for bin in fpes:
        y = y + bin.table[_]
    y = y/len(fpes)
    flux_points_mean.table[_] = y

# %%
flux_points_mean.table_formatted
# Out:
# <Table length=9>
#  e_ref   e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64         float64
# ------- ------- ------- ... --------------- --------------- ---------------
#   0.049   0.032   0.077 ...       8.936e-11       8.969e-11       8.904e-11
#   0.121   0.077   0.190 ...       7.969e-12       8.011e-12       7.927e-12
#   0.297   0.190   0.464 ...       1.055e-12       1.065e-12       1.046e-12
#   0.726   0.464   1.136 ...       1.576e-13       1.601e-13       1.550e-13
#   1.778   1.136   2.783 ...       2.271e-14       2.318e-14       2.224e-14
#   4.354   2.783   6.813 ...       3.771e-15       3.870e-15       3.675e-15
#  10.661   6.813  16.681 ...       8.130e-16       8.457e-16       7.810e-16
#  26.102  16.681  40.842 ...       1.815e-16       1.941e-16       1.693e-16
#  63.908  40.842 100.000 ...       3.584e-17       3.935e-17       3.250e-17

# %%
plt.figure(figsize=(16, 8))
flux_points_mean.table["is_ul"] = flux_points_mean.table["ts"] < 4
ax = flux_points_mean.plot(
    energy_power=2, flux_unit="erg-1 cm-2 s-1", color="darkorange"
)
flux_points_mean.to_sed_type("e2dnde").plot_ts_profiles(ax=ax)

# %%
flux_points_dataset = FluxPointsDataset(
    data=flux_points_mean, models=model_best_joints[124]
)

# %%
plt.figure(figsize=(16, 8))
flux_points_dataset.peek();

# %%
plt.figure(figsize=[16,8])
flux_points_mean.plot(energy_power=2)
simu.plot(energy_range=energy_range, energy_power=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
