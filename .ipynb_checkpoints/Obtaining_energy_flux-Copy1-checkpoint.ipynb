# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from regions import CircleSkyRegion
from gammapy.spectrum import (
    SpectrumDatasetOnOff,
    SpectrumDataset,
    SpectrumDatasetMaker,
    FluxPointsEstimator,
    FluxPointsDataset,
    ReflectedRegionsBackgroundMaker,
    plot_spectrum_datasets_off_regions,
)
from gammapy.modeling import Fit, Parameter
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SpectralModel,
    SkyModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis
from itertools import combinations

# %%
import scipy.stats as stats
import math
import statistics

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)

# %%
livetime = 8 * u.h
n_obs = 125
pointing = SkyCoord(0, 0, unit="deg", frame="galactic")
offset = 0.5 * u.deg
# Reconstructed and true energy axis
energy_axis = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 15), unit="TeV", name="energy", interp="log"
)
energy_axis_true = MapAxis.from_edges(
    np.logspace(-1.5, 2.0, 10), unit="TeV", name="energy", interp="log"
)

on_region_radius = Angle("0.11 deg")
on_region = CircleSkyRegion(center=pointing, radius=on_region_radius)

# %%
# Define spectral model - a simple Power Law in this case
model_simu = PowerLawSpectralModel(
    index=2.22,
    amplitude=1.289e-12 * u.Unit("cm-2 s-1 TeV-1"),
    reference=1 * u.TeV,
)
print(model_simu)
# we set the sky model used in the dataset
model = SkyModel(spectral_model=model_simu)
# Out:
# PowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.289e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True

# %%
obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
print(obs)
# Out:
# Info for OBS_ID = 1
# - Pointing pos: RA 266.40 deg / Dec -28.94 deg
# - Livetime duration: 28800.0 s
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]

# %%
# Make the SpectrumDataset
dataset_empty = SpectrumDataset.create(
    e_reco=energy_axis.edges, e_true=energy_axis_true.edges, region=on_region
)
maker = SpectrumDatasetMaker(selection=["aeff", "edisp", "background"])
dataset = maker.run(dataset_empty, obs)

# %%
# Set the model on the dataset, and fake
dataset.model = model
dataset.fake(random_state=42)
print(dataset)
# Out:
# SpectrumDataset
#
#     Name                            : 1
#
#     Total counts                    : 3453
#     Total predicted counts          : nan
#     Total background counts         : 3469.05
#
#     Effective area min              : 5.09e+04 m2
#     Effective area max              : 5.15e+06 m2
#
#     Livetime                        : 2.88e+04 s
#
#     Number of total bins            : 14
#     Number of fit bins              : 14
#
#     Fit statistic type              : cash
#     Fit statistic value (-2 log(L)) : nan
#
#     Number of parameters            : 0
#     Number of free parameters       : 0

# %%
dataset_onoff = SpectrumDatasetOnOff(
    aeff=dataset.aeff,
    edisp=dataset.edisp,
    models=model,
    livetime=livetime,
    acceptance=1,
    acceptance_off=5,
)
dataset_onoff.fake(background_model=dataset.background)
print(dataset_onoff)
# Out:
# SpectrumDatasetOnOff
#
#     Name                            :
#
#     Total counts                    : 6483
#     Total predicted counts          : 6402.93
#     Total off counts                : 17254.00
#
#     Total background counts         : 3450.80
#
#     Effective area min              : 5.09e+04 m2
#     Effective area max              : 5.15e+06 m2
#
#     Livetime                        : 8.00e+00 h
#
#     Number of total bins            : 14
#     Number of fit bins              : 14
#
#     Fit statistic type              : wstat
#     Fit statistic value (-2 log(L)) : 9.03
#
#     Number of parameters            : 3
#     Number of free parameters       : 2
#
#     Model type                      : SkyModels
#     Acceptance mean:                : 1.0

# %%
# %%time

datasets = []

for idx in range(n_obs):
    dataset_onoff.fake(random_state=idx, background_model=dataset.background)
    dataset_onoff.name = f"obs_{idx}"
    datasets.append(dataset_onoff.copy())
# Out:
# CPU times: user 1.12 s, sys: 8.04 ms, total: 1.12 s
# Wall time: 1.18 s

# %%
n_on = [dataset.counts.data.sum() for dataset in datasets]
n_off = [dataset.counts_off.data.sum() for dataset in datasets]
excess = [dataset.excess.data.sum() for dataset in datasets]

fix, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].hist(n_on)
axes[0].set_xlabel("no. of counts\nn_on")
axes[0].set_ylabel("No. of observations")
axes[1].hist(n_off)
axes[1].set_xlabel("no. of counts\nn_off")
axes[1].set_ylabel("No. of observations")
axes[2].hist(excess)
axes[2].set_xlabel("no. of counts\nexcess");
axes[2].set_ylabel("No. of observations")
# Out:
# Text(0, 0.5, 'No. of observations')

# %%
# %%time
results = []
fpes = []
e_edges = np.logspace(-1.5, 2.0, 10) * u.TeV
model_best_joints = []
for dataset in datasets:
    dataset.models = model.copy()
    fit = Fit([dataset])
    result = fit.run()
    results.append(
        {
            "index": result.parameters["index"].value,
            "amplitude": result.parameters["amplitude"].value,
            "reference":result.parameters["reference"].value,
        }
    )
    print(result.parameters.to_table())
    fpe = FluxPointsEstimator(datasets=[dataset], e_edges=e_edges)
    flux_points = fpe.run()
    print(flux_points.table_formatted)
    fpes.append(flux_points)
    model_best_joint = model.copy()
    model_best_joint.spectral_model.parameters.covariance = (result.parameters.covariance)
    model_best_joints.append(model_best_joint)
# Out:
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.225e+00 1.564e-02                nan nan  False
# amplitude 1.285e-12 3.409e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.190e-11       4.218e-11       4.163e-11
#  0.133  0.100   0.178 ...       7.064e-12       7.124e-12       7.005e-12
#  0.237  0.178   0.316 ...       1.869e-12       1.889e-12       1.849e-12
#  0.422  0.316   0.562 ...       8.040e-13       8.180e-13       7.903e-13
#  0.750  0.562   1.000 ...       1.409e-13       1.437e-13       1.383e-13
#  1.334  1.000   1.778 ...       6.061e-14       6.222e-14       5.902e-14
#  2.371  1.778   3.162 ...       1.531e-14       1.574e-14       1.489e-14
#  4.217  3.162   5.623 ...       4.169e-15       4.270e-15       4.069e-15
#  7.499  5.623  10.000 ...       2.527e-15       2.676e-15       2.384e-15
# 13.335 10.000  17.783 ...       5.668e-16       6.009e-16       5.336e-16
# 23.714 17.783  31.623 ...       2.256e-16       2.411e-16       2.109e-16
# 42.170 31.623  56.234 ...       1.340e-16       1.571e-16       1.127e-16
# 74.989 56.234 100.000 ...       3.753e-17       4.159e-17       3.368e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.211e+00 1.641e-02                nan nan  False
# amplitude 1.213e-12 3.313e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.197e-11       4.227e-11       4.167e-11
#  0.133  0.100   0.178 ...       6.964e-12       7.023e-12       6.906e-12
#  0.237  0.178   0.316 ...       1.841e-12       1.862e-12       1.821e-12
#  0.422  0.316   0.562 ...       7.429e-13       7.528e-13       7.329e-13
#  0.750  0.562   1.000 ...       1.360e-13       1.384e-13       1.336e-13
#  1.334  1.000   1.778 ...       6.030e-14       6.186e-14       5.876e-14
#  2.371  1.778   3.162 ...       1.597e-14       1.657e-14       1.539e-14
#  4.217  3.162   5.623 ...       3.996e-15       4.108e-15       3.887e-15
#  7.499  5.623  10.000 ...       2.146e-15       2.276e-15       2.021e-15
# 13.335 10.000  17.783 ...       5.688e-16       6.032e-16       5.355e-16
# 23.714 17.783  31.623 ...       2.712e-16       2.860e-16       2.569e-16
# 42.170 31.623  56.234 ...       1.337e-16       1.568e-16       1.125e-16
# 74.989 56.234 100.000 ...       3.573e-17       3.980e-17       3.187e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.222e+00 1.582e-02                nan nan  False
# amplitude 1.283e-12 3.394e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.160e-11       4.186e-11       4.135e-11
#  0.133  0.100   0.178 ...       7.159e-12       7.163e-12       7.154e-12
#  0.237  0.178   0.316 ...       1.871e-12       1.890e-12       1.853e-12
#  0.422  0.316   0.562 ...       7.431e-13       7.532e-13       7.330e-13
#  0.750  0.562   1.000 ...       1.393e-13       1.417e-13       1.369e-13
#  1.334  1.000   1.778 ...       5.827e-14       6.036e-14       5.627e-14
#  2.371  1.778   3.162 ...       1.577e-14       1.622e-14       1.534e-14
#  4.217  3.162   5.623 ...       4.233e-15       4.336e-15       4.132e-15
#  7.499  5.623  10.000 ...       2.715e-15       2.854e-15       2.579e-15
# 13.335 10.000  17.783 ...       6.522e-16       6.863e-16       6.190e-16
# 23.714 17.783  31.623 ...       2.171e-16       2.324e-16       2.026e-16
# 42.170 31.623  56.234 ...       1.160e-16       1.393e-16       9.482e-17
# 74.989 56.234 100.000 ...       3.141e-17       3.555e-17       2.754e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.221e+00 1.618e-02                nan nan  False
# amplitude 1.246e-12 3.361e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.201e-11       4.226e-11       4.177e-11
#  0.133  0.100   0.178 ...       7.141e-12       7.182e-12       7.099e-12
#  0.237  0.178   0.316 ...       1.838e-12       1.859e-12       1.817e-12
#  0.422  0.316   0.562 ...       7.188e-13       7.312e-13       7.066e-13
#  0.750  0.562   1.000 ...       1.396e-13       1.423e-13       1.369e-13
#  1.334  1.000   1.778 ...       6.275e-14       6.432e-14       6.119e-14
#  2.371  1.778   3.162 ...       1.625e-14       1.675e-14       1.576e-14
#  4.217  3.162   5.623 ...       3.968e-15       4.069e-15       3.868e-15
#  7.499  5.623  10.000 ...       2.440e-15       2.590e-15       2.297e-15
# 13.335 10.000  17.783 ...       6.510e-16       6.872e-16       6.161e-16
# 23.714 17.783  31.623 ...       2.083e-16       2.230e-16       1.942e-16
# 42.170 31.623  56.234 ...       1.771e-16       2.001e-16       1.555e-16
# 74.989 56.234 100.000 ...       3.143e-17       3.553e-17       2.759e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.240e+00 1.555e-02                nan nan  False
# amplitude 1.313e-12 3.445e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.358e-11       4.389e-11       4.328e-11
#  0.133  0.100   0.178 ...       7.072e-12       7.130e-12       7.014e-12
#  0.237  0.178   0.316 ...       1.949e-12       1.954e-12       1.943e-12
#  0.422  0.316   0.562 ...       7.249e-13       7.369e-13       7.131e-13
#  0.750  0.562   1.000 ...       1.373e-13       1.397e-13       1.350e-13
#  1.334  1.000   1.778 ...       5.925e-14       6.082e-14       5.771e-14
#  2.371  1.778   3.162 ...       1.684e-14       1.731e-14       1.638e-14
#  4.217  3.162   5.623 ...       4.157e-15       4.257e-15       4.059e-15
#  7.499  5.623  10.000 ...       2.598e-15       2.739e-15       2.462e-15
# 13.335 10.000  17.783 ...       6.479e-16       6.824e-16       6.143e-16
# 23.714 17.783  31.623 ...       1.943e-16       2.091e-16       1.801e-16
# 42.170 31.623  56.234 ...       1.777e-16       2.008e-16       1.560e-16
# 74.989 56.234 100.000 ...       3.547e-17       3.952e-17       3.164e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.237e+00 1.569e-02                nan nan  False
# amplitude 1.286e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.236e-11       4.241e-11       4.232e-11
#  0.133  0.100   0.178 ...       7.218e-12       7.290e-12       7.147e-12
#  0.237  0.178   0.316 ...       1.876e-12       1.888e-12       1.865e-12
#  0.422  0.316   0.562 ...       7.190e-13       7.309e-13       7.073e-13
#  0.750  0.562   1.000 ...       1.378e-13       1.402e-13       1.354e-13
#  1.334  1.000   1.778 ...       6.413e-14       6.574e-14       6.255e-14
#  2.371  1.778   3.162 ...       1.667e-14       1.712e-14       1.623e-14
#  4.217  3.162   5.623 ...       4.070e-15       4.192e-15       3.952e-15
#  7.499  5.623  10.000 ...       2.597e-15       2.738e-15       2.460e-15
# 13.335 10.000  17.783 ...       6.077e-16       6.416e-16       5.747e-16
# 23.714 17.783  31.623 ...       2.128e-16       2.280e-16       1.983e-16
# 42.170 31.623  56.234 ...       1.340e-16       1.582e-16       1.121e-16
# 74.989 56.234 100.000 ...       2.646e-17       3.055e-17       2.267e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.196e+00 1.566e-02                nan nan  False
# amplitude 1.314e-12 3.408e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.181e-11       4.205e-11       4.159e-11
#  0.133  0.100   0.178 ...       7.062e-12       7.123e-12       7.002e-12
#  0.237  0.178   0.316 ...       1.883e-12       1.904e-12       1.863e-12
#  0.422  0.316   0.562 ...       7.550e-13       7.670e-13       7.432e-13
#  0.750  0.562   1.000 ...       1.388e-13       1.410e-13       1.366e-13
#  1.334  1.000   1.778 ...       6.058e-14       6.228e-14       5.893e-14
#  2.371  1.778   3.162 ...       1.778e-14       1.824e-14       1.732e-14
#  4.217  3.162   5.623 ...       4.226e-15       4.351e-15       4.105e-15
#  7.499  5.623  10.000 ...       2.087e-15       2.225e-15       1.954e-15
# 13.335 10.000  17.783 ...       7.104e-16       7.450e-16       6.766e-16
# 23.714 17.783  31.623 ...       2.378e-16       2.530e-16       2.231e-16
# 42.170 31.623  56.234 ...       1.334e-16       1.565e-16       1.121e-16
# 74.989 56.234 100.000 ...       3.964e-17       4.372e-17       3.575e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.196e+00 1.585e-02                nan nan  False
# amplitude 1.286e-12 3.380e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.210e-11       4.240e-11       4.180e-11
#  0.133  0.100   0.178 ...       7.034e-12       7.087e-12       6.981e-12
#  0.237  0.178   0.316 ...       1.872e-12       1.889e-12       1.855e-12
#  0.422  0.316   0.562 ...       7.769e-13       7.902e-13       7.639e-13
#  0.750  0.562   1.000 ...       1.372e-13       1.396e-13       1.349e-13
#  1.334  1.000   1.778 ...       5.800e-14       5.955e-14       5.647e-14
#  2.371  1.778   3.162 ...       1.647e-14       1.700e-14       1.596e-14
#  4.217  3.162   5.623 ...       4.304e-15       4.405e-15       4.204e-15
#  7.499  5.623  10.000 ...       2.321e-15       2.453e-15       2.193e-15
# 13.335 10.000  17.783 ...       7.244e-16       7.600e-16       6.898e-16
# 23.714 17.783  31.623 ...       2.255e-16       2.410e-16       2.107e-16
# 42.170 31.623  56.234 ...       1.491e-16       1.723e-16       1.276e-16
# 74.989 56.234 100.000 ...       3.580e-17       4.017e-17       3.177e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.229e+00 1.590e-02                nan nan  False
# amplitude 1.256e-12 3.365e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.198e-11       4.227e-11       4.169e-11
#  0.133  0.100   0.178 ...       6.959e-12       6.989e-12       6.930e-12
#  0.237  0.178   0.316 ...       1.869e-12       1.874e-12       1.863e-12
#  0.422  0.316   0.562 ...       7.517e-13       7.633e-13       7.402e-13
#  0.750  0.562   1.000 ...       1.410e-13       1.433e-13       1.388e-13
#  1.334  1.000   1.778 ...       6.191e-14       6.371e-14       6.015e-14
#  2.371  1.778   3.162 ...       1.635e-14       1.680e-14       1.590e-14
#  4.217  3.162   5.623 ...       3.870e-15       3.995e-15       3.750e-15
#  7.499  5.623  10.000 ...       2.265e-15       2.400e-15       2.134e-15
# 13.335 10.000  17.783 ...       6.254e-16       6.602e-16       5.916e-16
# 23.714 17.783  31.623 ...       2.128e-16       2.280e-16       1.982e-16
# 42.170 31.623  56.234 ...       1.642e-16       1.873e-16       1.427e-16
# 74.989 56.234 100.000 ...       3.137e-17       3.544e-17       2.755e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.173e+00 1.555e-02                nan nan  False
# amplitude 1.336e-12 3.416e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.105e-11       4.135e-11       4.076e-11
#  0.133  0.100   0.178 ...       7.027e-12       7.090e-12       6.966e-12
#  0.237  0.178   0.316 ...       1.824e-12       1.844e-12       1.804e-12
#  0.422  0.316   0.562 ...       7.456e-13       7.562e-13       7.351e-13
#  0.750  0.562   1.000 ...       1.467e-13       1.490e-13       1.444e-13
#  1.334  1.000   1.778 ...       6.093e-14       6.254e-14       5.935e-14
#  2.371  1.778   3.162 ...       1.803e-14       1.863e-14       1.746e-14
#  4.217  3.162   5.623 ...       4.062e-15       4.160e-15       3.966e-15
#  7.499  5.623  10.000 ...       2.452e-15       2.584e-15       2.323e-15
# 13.335 10.000  17.783 ...       7.081e-16       7.429e-16       6.742e-16
# 23.714 17.783  31.623 ...       2.813e-16       2.960e-16       2.670e-16
# 42.170 31.623  56.234 ...       1.757e-16       1.987e-16       1.542e-16
# 74.989 56.234 100.000 ...       3.399e-17       3.808e-17       3.013e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.223e+00 1.562e-02                nan nan  False
# amplitude 1.311e-12 3.426e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.271e-11       4.302e-11       4.240e-11
#  0.133  0.100   0.178 ...       7.125e-12       7.185e-12       7.065e-12
#  0.237  0.178   0.316 ...       1.896e-12       1.914e-12       1.877e-12
#  0.422  0.316   0.562 ...       7.228e-13       7.348e-13       7.109e-13
#  0.750  0.562   1.000 ...       1.400e-13       1.424e-13       1.377e-13
#  1.334  1.000   1.778 ...       6.261e-14       6.427e-14       6.098e-14
#  2.371  1.778   3.162 ...       1.766e-14       1.812e-14       1.721e-14
#  4.217  3.162   5.623 ...       4.029e-15       4.130e-15       3.929e-15
#  7.499  5.623  10.000 ...       2.476e-15       2.632e-15       2.328e-15
# 13.335 10.000  17.783 ...       6.346e-16       6.722e-16       5.986e-16
# 23.714 17.783  31.623 ...       2.297e-16       2.456e-16       2.146e-16
# 42.170 31.623  56.234 ...       1.641e-16       1.871e-16       1.425e-16
# 74.989 56.234 100.000 ...       2.655e-17       3.065e-17       2.275e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.212e+00 1.534e-02                nan nan  False
# amplitude 1.311e-12 3.425e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.128e-11       4.157e-11       4.099e-11
#  0.133  0.100   0.178 ...       7.135e-12       7.191e-12       7.079e-12
#  0.237  0.178   0.316 ...       1.969e-12       1.992e-12       1.946e-12
#  0.422  0.316   0.562 ...       7.740e-13       7.836e-13       7.644e-13
#  0.750  0.562   1.000 ...       1.417e-13       1.447e-13       1.387e-13
#  1.334  1.000   1.778 ...       5.903e-14       6.059e-14       5.749e-14
#  2.371  1.778   3.162 ...       1.669e-14       1.717e-14       1.621e-14
#  4.217  3.162   5.623 ...       4.163e-15       4.273e-15       4.055e-15
#  7.499  5.623  10.000 ...       2.400e-15       2.536e-15       2.267e-15
# 13.335 10.000  17.783 ...       5.774e-16       6.118e-16       5.440e-16
# 23.714 17.783  31.623 ...       2.379e-16       2.527e-16       2.236e-16
# 42.170 31.623  56.234 ...       1.337e-16       1.569e-16       1.124e-16
# 74.989 56.234 100.000 ...       3.367e-17       3.776e-17       2.982e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.212e+00 1.567e-02                nan nan  False
# amplitude 1.286e-12 3.397e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.213e-11       4.229e-11       4.197e-11
#  0.133  0.100   0.178 ...       7.160e-12       7.187e-12       7.133e-12
#  0.237  0.178   0.316 ...       1.921e-12       1.943e-12       1.900e-12
#  0.422  0.316   0.562 ...       7.459e-13       7.550e-13       7.368e-13
#  0.750  0.562   1.000 ...       1.391e-13       1.414e-13       1.368e-13
#  1.334  1.000   1.778 ...       6.157e-14       6.335e-14       5.984e-14
#  2.371  1.778   3.162 ...       1.754e-14       1.815e-14       1.696e-14
#  4.217  3.162   5.623 ...       3.850e-15       3.947e-15       3.754e-15
#  7.499  5.623  10.000 ...       2.469e-15       2.630e-15       2.318e-15
# 13.335 10.000  17.783 ...       6.451e-16       6.812e-16       6.104e-16
# 23.714 17.783  31.623 ...       2.083e-16       2.228e-16       1.943e-16
# 42.170 31.623  56.234 ...       2.006e-16       2.234e-16       1.789e-16
# 74.989 56.234 100.000 ...       3.571e-17       3.982e-17       3.184e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.229e+00 1.613e-02                nan nan  False
# amplitude 1.248e-12 3.359e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.240e-11       4.270e-11       4.210e-11
#  0.133  0.100   0.178 ...       7.127e-12       7.192e-12       7.064e-12
#  0.237  0.178   0.316 ...       1.786e-12       1.805e-12       1.768e-12
#  0.422  0.316   0.562 ...       7.384e-13       7.461e-13       7.306e-13
#  0.750  0.562   1.000 ...       1.375e-13       1.401e-13       1.349e-13
#  1.334  1.000   1.778 ...       6.530e-14       6.697e-14       6.367e-14
#  2.371  1.778   3.162 ...       1.635e-14       1.680e-14       1.591e-14
#  4.217  3.162   5.623 ...       3.575e-15       3.658e-15       3.492e-15
#  7.499  5.623  10.000 ...       2.664e-15       2.810e-15       2.523e-15
# 13.335 10.000  17.783 ...       7.030e-16       7.371e-16       6.696e-16
# 23.714 17.783  31.623 ...       2.339e-16       2.490e-16       2.194e-16
# 42.170 31.623  56.234 ...       9.481e-17       1.184e-16       7.390e-17
# 74.989 56.234 100.000 ...       3.353e-17       3.761e-17       2.969e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.193e+00 1.552e-02                nan nan  False
# amplitude 1.336e-12 3.436e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.281e-11       4.312e-11       4.251e-11
#  0.133  0.100   0.178 ...       6.932e-12       6.991e-12       6.874e-12
#  0.237  0.178   0.316 ...       1.892e-12       1.914e-12       1.872e-12
#  0.422  0.316   0.562 ...       7.890e-13       8.025e-13       7.757e-13
#  0.750  0.562   1.000 ...       1.407e-13       1.430e-13       1.385e-13
#  1.334  1.000   1.778 ...       6.037e-14       6.230e-14       5.850e-14
#  2.371  1.778   3.162 ...       1.726e-14       1.771e-14       1.680e-14
#  4.217  3.162   5.623 ...       4.292e-15       4.420e-15       4.168e-15
#  7.499  5.623  10.000 ...       2.719e-15       2.868e-15       2.576e-15
# 13.335 10.000  17.783 ...       7.178e-16       7.525e-16       6.839e-16
# 23.714 17.783  31.623 ...       2.082e-16       2.230e-16       1.940e-16
# 42.170 31.623  56.234 ...       1.488e-16       1.727e-16       1.270e-16
# 74.989 56.234 100.000 ...       3.379e-17       3.807e-17       2.982e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.210e+00 1.576e-02                nan nan  False
# amplitude 1.271e-12 3.378e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.058e-11       4.087e-11       4.029e-11
#  0.133  0.100   0.178 ...       7.074e-12       7.136e-12       7.013e-12
#  0.237  0.178   0.316 ...       1.879e-12       1.900e-12       1.858e-12
#  0.422  0.316   0.562 ...       7.335e-13       7.461e-13       7.212e-13
#  0.750  0.562   1.000 ...       1.433e-13       1.456e-13       1.411e-13
#  1.334  1.000   1.778 ...       6.294e-14       6.506e-14       6.090e-14
#  2.371  1.778   3.162 ...       1.731e-14       1.792e-14       1.672e-14
#  4.217  3.162   5.623 ...       3.907e-15       4.006e-15       3.809e-15
#  7.499  5.623  10.000 ...       1.937e-15       2.053e-15       1.823e-15
# 13.335 10.000  17.783 ...       6.986e-16       7.340e-16       6.642e-16
# 23.714 17.783  31.623 ...       2.214e-16       2.364e-16       2.070e-16
# 42.170 31.623  56.234 ...       9.452e-17       1.180e-16       7.368e-17
# 74.989 56.234 100.000 ...       3.572e-17       3.983e-17       3.185e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.218e+00 1.583e-02                nan nan  False
# amplitude 1.273e-12 3.392e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.163e-11       4.192e-11       4.133e-11
#  0.133  0.100   0.178 ...       7.021e-12       7.028e-12       7.014e-12
#  0.237  0.178   0.316 ...       1.890e-12       1.912e-12       1.869e-12
#  0.422  0.316   0.562 ...       7.532e-13       7.641e-13       7.424e-13
#  0.750  0.562   1.000 ...       1.408e-13       1.440e-13       1.376e-13
#  1.334  1.000   1.778 ...       6.013e-14       6.176e-14       5.852e-14
#  2.371  1.778   3.162 ...       1.739e-14       1.799e-14       1.681e-14
#  4.217  3.162   5.623 ...       3.890e-15       3.988e-15       3.794e-15
#  7.499  5.623  10.000 ...       2.542e-15       2.681e-15       2.407e-15
# 13.335 10.000  17.783 ...       6.278e-16       6.676e-16       5.902e-16
# 23.714 17.783  31.623 ...       2.379e-16       2.529e-16       2.234e-16
# 42.170 31.623  56.234 ...       1.339e-16       1.570e-16       1.126e-16
# 74.989 56.234 100.000 ...       2.912e-17       3.321e-17       2.530e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.229e+00 1.539e-02                nan nan  False
# amplitude 1.323e-12 3.456e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.173e-11       4.203e-11       4.144e-11
#  0.133  0.100   0.178 ...       7.194e-12       7.246e-12       7.142e-12
#  0.237  0.178   0.316 ...       1.917e-12       1.938e-12       1.897e-12
#  0.422  0.316   0.562 ...       7.272e-13       7.386e-13       7.159e-13
#  0.750  0.562   1.000 ...       1.456e-13       1.479e-13       1.433e-13
#  1.334  1.000   1.778 ...       6.486e-14       6.645e-14       6.330e-14
#  2.371  1.778   3.162 ...       1.681e-14       1.727e-14       1.637e-14
#  4.217  3.162   5.623 ...       3.995e-15       4.109e-15       3.884e-15
#  7.499  5.623  10.000 ...       2.558e-15       2.703e-15       2.420e-15
# 13.335 10.000  17.783 ...       6.271e-16       6.609e-16       5.942e-16
# 23.714 17.783  31.623 ...       2.171e-16       2.326e-16       2.024e-16
# 42.170 31.623  56.234 ...       6.703e-17       9.103e-17       4.680e-17
# 74.989 56.234 100.000 ...       3.136e-17       3.550e-17       2.749e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.235e+00 1.562e-02                nan nan  False
# amplitude 1.293e-12 3.426e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.159e-11       4.189e-11       4.129e-11
#  0.133  0.100   0.178 ...       7.065e-12       7.110e-12       7.020e-12
#  0.237  0.178   0.316 ...       1.892e-12       1.914e-12       1.871e-12
#  0.422  0.316   0.562 ...       7.646e-13       7.773e-13       7.522e-13
#  0.750  0.562   1.000 ...       1.395e-13       1.418e-13       1.373e-13
#  1.334  1.000   1.778 ...       5.880e-14       6.037e-14       5.727e-14
#  2.371  1.778   3.162 ...       1.714e-14       1.775e-14       1.657e-14
#  4.217  3.162   5.623 ...       3.903e-15       4.029e-15       3.782e-15
#  7.499  5.623  10.000 ...       2.632e-15       2.774e-15       2.495e-15
# 13.335 10.000  17.783 ...       6.948e-16       7.298e-16       6.608e-16
# 23.714 17.783  31.623 ...       2.215e-16       2.366e-16       2.070e-16
# 42.170 31.623  56.234 ...       1.339e-16       1.584e-16       1.120e-16
# 74.989 56.234 100.000 ...       3.132e-17       3.539e-17       2.751e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.210e+00 1.595e-02                nan nan  False
# amplitude 1.257e-12 3.351e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.093e-11       4.122e-11       4.063e-11
#  0.133  0.100   0.178 ...       7.073e-12       7.073e-12       7.074e-12
#  0.237  0.178   0.316 ...       1.899e-12       1.921e-12       1.877e-12
#  0.422  0.316   0.562 ...       7.423e-13       7.542e-13       7.305e-13
#  0.750  0.562   1.000 ...       1.371e-13       1.395e-13       1.346e-13
#  1.334  1.000   1.778 ...       5.915e-14       6.081e-14       5.753e-14
#  2.371  1.778   3.162 ...       1.618e-14       1.674e-14       1.564e-14
#  4.217  3.162   5.623 ...       3.973e-15       4.075e-15       3.873e-15
#  7.499  5.623  10.000 ...       2.509e-15       2.657e-15       2.368e-15
# 13.335 10.000  17.783 ...       7.009e-16       7.355e-16       6.672e-16
# 23.714 17.783  31.623 ...       2.297e-16       2.455e-16       2.146e-16
# 42.170 31.623  56.234 ...       1.337e-16       1.567e-16       1.125e-16
# 74.989 56.234 100.000 ...       2.918e-17       3.328e-17       2.535e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.221e+00 1.570e-02                nan nan  False
# amplitude 1.295e-12 3.420e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.259e-11       4.277e-11       4.241e-11
#  0.133  0.100   0.178 ...       7.059e-12       7.109e-12       7.010e-12
#  0.237  0.178   0.316 ...       1.885e-12       1.899e-12       1.870e-12
#  0.422  0.316   0.562 ...       7.386e-13       7.514e-13       7.259e-13
#  0.750  0.562   1.000 ...       1.423e-13       1.451e-13       1.395e-13
#  1.334  1.000   1.778 ...       6.341e-14       6.513e-14       6.173e-14
#  2.371  1.778   3.162 ...       1.585e-14       1.629e-14       1.541e-14
#  4.217  3.162   5.623 ...       3.944e-15       4.043e-15       3.847e-15
#  7.499  5.623  10.000 ...       2.612e-15       2.757e-15       2.472e-15
# 13.335 10.000  17.783 ...       6.976e-16       7.324e-16       6.638e-16
# 23.714 17.783  31.623 ...       2.297e-16       2.457e-16       2.145e-16
# 42.170 31.623  56.234 ...       1.496e-16       1.730e-16       1.281e-16
# 74.989 56.234 100.000 ...       3.357e-17       3.778e-17       2.965e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.207e+00 1.590e-02                nan nan  False
# amplitude 1.277e-12 3.382e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.244e-11       4.274e-11       4.214e-11
#  0.133  0.100   0.178 ...       7.024e-12       7.083e-12       6.965e-12
#  0.237  0.178   0.316 ...       1.901e-12       1.923e-12       1.879e-12
#  0.422  0.316   0.562 ...       7.683e-13       7.793e-13       7.574e-13
#  0.750  0.562   1.000 ...       1.323e-13       1.345e-13       1.301e-13
#  1.334  1.000   1.778 ...       5.886e-14       6.062e-14       5.714e-14
#  2.371  1.778   3.162 ...       1.711e-14       1.761e-14       1.662e-14
#  4.217  3.162   5.623 ...       4.143e-15       4.258e-15       4.031e-15
#  7.499  5.623  10.000 ...       2.541e-15       2.685e-15       2.401e-15
# 13.335 10.000  17.783 ...       6.223e-16       6.561e-16       5.893e-16
# 23.714 17.783  31.623 ...       2.569e-16       2.717e-16       2.426e-16
# 42.170 31.623  56.234 ...       1.157e-16       1.390e-16       9.459e-17
# 74.989 56.234 100.000 ...       3.769e-17       4.177e-17       3.383e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.197e+00 1.600e-02                nan nan  False
# amplitude 1.273e-12 3.368e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.270e-11       4.300e-11       4.240e-11
#  0.133  0.100   0.178 ...       6.942e-12       6.998e-12       6.887e-12
#  0.237  0.178   0.316 ...       1.856e-12       1.871e-12       1.840e-12
#  0.422  0.316   0.562 ...       7.525e-13       7.653e-13       7.399e-13
#  0.750  0.562   1.000 ...       1.408e-13       1.441e-13       1.377e-13
#  1.334  1.000   1.778 ...       5.872e-14       6.080e-14       5.673e-14
#  2.371  1.778   3.162 ...       1.728e-14       1.783e-14       1.675e-14
#  4.217  3.162   5.623 ...       4.153e-15       4.271e-15       4.038e-15
#  7.499  5.623  10.000 ...       2.469e-15       2.605e-15       2.337e-15
# 13.335 10.000  17.783 ...       6.472e-16       6.851e-16       6.110e-16
# 23.714 17.783  31.623 ...       2.338e-16       2.490e-16       2.191e-16
# 42.170 31.623  56.234 ...       1.491e-16       1.722e-16       1.277e-16
# 74.989 56.234 100.000 ...       3.162e-17       3.570e-17       2.778e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.204e+00 1.535e-02                nan nan  False
# amplitude 1.333e-12 3.439e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.236e-11       4.270e-11       4.203e-11
#  0.133  0.100   0.178 ...       7.022e-12       7.076e-12       6.968e-12
#  0.237  0.178   0.316 ...       1.893e-12       1.914e-12       1.872e-12
#  0.422  0.316   0.562 ...       7.769e-13       7.899e-13       7.640e-13
#  0.750  0.562   1.000 ...       1.419e-13       1.444e-13       1.395e-13
#  1.334  1.000   1.778 ...       6.342e-14       6.520e-14       6.168e-14
#  2.371  1.778   3.162 ...       1.641e-14       1.685e-14       1.596e-14
#  4.217  3.162   5.623 ...       4.195e-15       4.301e-15       4.091e-15
#  7.499  5.623  10.000 ...       2.209e-15       2.348e-15       2.076e-15
# 13.335 10.000  17.783 ...       7.440e-16       7.806e-16       7.087e-16
# 23.714 17.783  31.623 ...       2.172e-16       2.317e-16       2.031e-16
# 42.170 31.623  56.234 ...       1.635e-16       1.866e-16       1.420e-16
# 74.989 56.234 100.000 ...       3.373e-17       3.785e-17       2.986e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.199e+00 1.535e-02                nan nan  False
# amplitude 1.350e-12 3.455e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.192e-11       4.219e-11       4.165e-11
#  0.133  0.100   0.178 ...       7.075e-12       7.123e-12       7.028e-12
#  0.237  0.178   0.316 ...       1.912e-12       1.926e-12       1.897e-12
#  0.422  0.316   0.562 ...       7.483e-13       7.610e-13       7.357e-13
#  0.750  0.562   1.000 ...       1.427e-13       1.450e-13       1.405e-13
#  1.334  1.000   1.778 ...       6.096e-14       6.272e-14       5.925e-14
#  2.371  1.778   3.162 ...       1.780e-14       1.842e-14       1.720e-14
#  4.217  3.162   5.623 ...       4.078e-15       4.177e-15       3.980e-15
#  7.499  5.623  10.000 ...       2.908e-15       3.051e-15       2.769e-15
# 13.335 10.000  17.783 ...       6.630e-16       7.021e-16       6.257e-16
# 23.714 17.783  31.623 ...       2.214e-16       2.360e-16       2.073e-16
# 42.170 31.623  56.234 ...       1.887e-16       2.116e-16       1.671e-16
# 74.989 56.234 100.000 ...       3.776e-17       4.188e-17       3.386e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.244e+00 1.560e-02                nan nan  False
# amplitude 1.286e-12 3.415e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.180e-11       4.209e-11       4.150e-11
#  0.133  0.100   0.178 ...       7.111e-12       7.149e-12       7.074e-12
#  0.237  0.178   0.316 ...       1.908e-12       1.928e-12       1.887e-12
#  0.422  0.316   0.562 ...       7.555e-13       7.672e-13       7.439e-13
#  0.750  0.562   1.000 ...       1.380e-13       1.402e-13       1.357e-13
#  1.334  1.000   1.778 ...       6.049e-14       6.208e-14       5.894e-14
#  2.371  1.778   3.162 ...       1.611e-14       1.667e-14       1.557e-14
#  4.217  3.162   5.623 ...       3.914e-15       4.021e-15       3.809e-15
#  7.499  5.623  10.000 ...       2.525e-15       2.667e-15       2.388e-15
# 13.335 10.000  17.783 ...       6.474e-16       6.835e-16       6.126e-16
# 23.714 17.783  31.623 ...       2.214e-16       2.376e-16       2.061e-16
# 42.170 31.623  56.234 ...       1.164e-16       1.398e-16       9.515e-17
# 74.989 56.234 100.000 ...       3.736e-17       4.140e-17       3.353e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.214e+00 1.616e-02                nan nan  False
# amplitude 1.261e-12 3.365e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.200e-11       4.229e-11       4.170e-11
#  0.133  0.100   0.178 ...       7.098e-12       7.162e-12       7.035e-12
#  0.237  0.178   0.316 ...       1.856e-12       1.877e-12       1.834e-12
#  0.422  0.316   0.562 ...       7.513e-13       7.632e-13       7.394e-13
#  0.750  0.562   1.000 ...       1.333e-13       1.362e-13       1.304e-13
#  1.334  1.000   1.778 ...       5.822e-14       6.018e-14       5.632e-14
#  2.371  1.778   3.162 ...       1.646e-14       1.694e-14       1.599e-14
#  4.217  3.162   5.623 ...       4.075e-15       4.186e-15       3.967e-15
#  7.499  5.623  10.000 ...       2.706e-15       2.846e-15       2.571e-15
# 13.335 10.000  17.783 ...       6.847e-16       7.191e-16       6.513e-16
# 23.714 17.783  31.623 ...       2.297e-16       2.459e-16       2.142e-16
# 42.170 31.623  56.234 ...       1.769e-16       1.999e-16       1.554e-16
# 74.989 56.234 100.000 ...       3.569e-17       3.981e-17       3.180e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.251e+00 1.549e-02                nan nan  False
# amplitude 1.296e-12 3.457e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.271e-11       4.301e-11       4.241e-11
#  0.133  0.100   0.178 ...       6.984e-12       7.038e-12       6.931e-12
#  0.237  0.178   0.316 ...       1.970e-12       1.993e-12       1.949e-12
#  0.422  0.316   0.562 ...       7.650e-13       7.776e-13       7.526e-13
#  0.750  0.562   1.000 ...       1.422e-13       1.451e-13       1.394e-13
#  1.334  1.000   1.778 ...       6.255e-14       6.413e-14       6.099e-14
#  2.371  1.778   3.162 ...       1.614e-14       1.672e-14       1.559e-14
#  4.217  3.162   5.623 ...       3.939e-15       4.044e-15       3.837e-15
#  7.499  5.623  10.000 ...       2.277e-15       2.414e-15       2.144e-15
# 13.335 10.000  17.783 ...       5.525e-16       5.865e-16       5.195e-16
# 23.714 17.783  31.623 ...       2.420e-16       2.567e-16       2.276e-16
# 42.170 31.623  56.234 ...       1.165e-16       1.399e-16       9.526e-17
# 74.989 56.234 100.000 ...       3.730e-17       4.133e-17       3.347e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.234e+00 1.580e-02                nan nan  False
# amplitude 1.278e-12 3.400e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.228e-11       4.258e-11       4.198e-11
#  0.133  0.100   0.178 ...       7.144e-12       7.195e-12       7.093e-12
#  0.237  0.178   0.316 ...       1.884e-12       1.893e-12       1.875e-12
#  0.422  0.316   0.562 ...       7.584e-13       7.700e-13       7.468e-13
#  0.750  0.562   1.000 ...       1.372e-13       1.395e-13       1.350e-13
#  1.334  1.000   1.778 ...       5.929e-14       6.108e-14       5.755e-14
#  2.371  1.778   3.162 ...       1.644e-14       1.690e-14       1.600e-14
#  4.217  3.162   5.623 ...       4.168e-15       4.270e-15       4.068e-15
#  7.499  5.623  10.000 ...       2.483e-15       2.625e-15       2.347e-15
# 13.335 10.000  17.783 ...       6.949e-16       7.303e-16       6.605e-16
# 23.714 17.783  31.623 ...       1.791e-16       1.939e-16       1.650e-16
# 42.170 31.623  56.234 ...       1.497e-16       1.742e-16       1.275e-16
# 74.989 56.234 100.000 ...       2.648e-17       3.057e-17       2.269e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.230e+00 1.589e-02                nan nan  False
# amplitude 1.279e-12 3.404e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.208e-11       4.237e-11       4.179e-11
#  0.133  0.100   0.178 ...       6.986e-12       7.036e-12       6.937e-12
#  0.237  0.178   0.316 ...       1.917e-12       1.930e-12       1.904e-12
#  0.422  0.316   0.562 ...       7.704e-13       7.833e-13       7.577e-13
#  0.750  0.562   1.000 ...       1.384e-13       1.407e-13       1.362e-13
#  1.334  1.000   1.778 ...       5.618e-14       5.771e-14       5.467e-14
#  2.371  1.778   3.162 ...       1.680e-14       1.728e-14       1.633e-14
#  4.217  3.162   5.623 ...       3.906e-15       4.031e-15       3.784e-15
#  7.499  5.623  10.000 ...       2.774e-15       2.924e-15       2.631e-15
# 13.335 10.000  17.783 ...       6.433e-16       6.775e-16       6.100e-16
# 23.714 17.783  31.623 ...       2.379e-16       2.531e-16       2.233e-16
# 42.170 31.623  56.234 ...       1.642e-16       1.873e-16       1.427e-16
# 74.989 56.234 100.000 ...       3.556e-17       3.962e-17       3.172e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.223e+00 1.525e-02                nan nan  False
# amplitude 1.348e-12 3.461e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.188e-11       4.218e-11       4.158e-11
#  0.133  0.100   0.178 ...       7.264e-12       7.334e-12       7.195e-12
#  0.237  0.178   0.316 ...       1.921e-12       1.943e-12       1.900e-12
#  0.422  0.316   0.562 ...       7.253e-13       7.372e-13       7.136e-13
#  0.750  0.562   1.000 ...       1.393e-13       1.416e-13       1.370e-13
#  1.334  1.000   1.778 ...       6.519e-14       6.679e-14       6.361e-14
#  2.371  1.778   3.162 ...       1.620e-14       1.664e-14       1.576e-14
#  4.217  3.162   5.623 ...       4.095e-15       4.195e-15       3.996e-15
#  7.499  5.623  10.000 ...       2.615e-15       2.754e-15       2.480e-15
# 13.335 10.000  17.783 ...       7.252e-16       7.618e-16       6.898e-16
# 23.714 17.783  31.623 ...       2.257e-16       2.405e-16       2.115e-16
# 42.170 31.623  56.234 ...       1.160e-16       1.393e-16       9.483e-17
# 74.989 56.234 100.000 ...       3.358e-17       3.769e-17       2.972e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.228e+00 1.652e-02                nan nan  False
# amplitude 1.204e-12 3.313e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.292e-11       4.322e-11       4.262e-11
#  0.133  0.100   0.178 ...       6.937e-12       6.955e-12       6.918e-12
#  0.237  0.178   0.316 ...       1.835e-12       1.846e-12       1.824e-12
#  0.422  0.316   0.562 ...       7.478e-13       7.573e-13       7.384e-13
#  0.750  0.562   1.000 ...       1.293e-13       1.315e-13       1.271e-13
#  1.334  1.000   1.778 ...       6.131e-14       6.333e-14       5.936e-14
#  2.371  1.778   3.162 ...       1.647e-14       1.699e-14       1.598e-14
#  4.217  3.162   5.623 ...       3.997e-15       4.125e-15       3.873e-15
#  7.499  5.623  10.000 ...       2.526e-15       2.664e-15       2.392e-15
# 13.335 10.000  17.783 ...       5.922e-16       6.262e-16       5.592e-16
# 23.714 17.783  31.623 ...       2.339e-16       2.492e-16       2.191e-16
# 42.170 31.623  56.234 ...       1.161e-16       1.394e-16       9.491e-17
# 74.989 56.234 100.000 ...       2.054e-17       2.467e-17       1.679e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.228e+00 1.562e-02                nan nan  False
# amplitude 1.304e-12 3.421e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ...
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.298e-11       4.328e-11       4.268e-11
#  0.133  0.100   0.178 ...       7.151e-12       7.217e-12       7.085e-12
#  0.237  0.178   0.316 ...       1.844e-12       1.865e-12       1.824e-12
#  0.422  0.316   0.562 ...       7.607e-13       7.729e-13       7.486e-13
#  0.750  0.562   1.000 ...       1.377e-13       1.399e-13       1.355e-13
#  1.334  1.000   1.778 ...       6.159e-14       6.322e-14       5.999e-14
#  2.371  1.778   3.162 ...       1.562e-14       1.606e-14       1.518e-14
#  4.217  3.162   5.623 ...       3.989e-15       4.099e-15       3.880e-15
#  7.499  5.623  10.000 ...       2.867e-15       3.013e-15       2.726e-15
# 13.335 10.000  17.783 ...       6.980e-16       7.327e-16       6.642e-16
# 23.714 17.783  31.623 ...       2.215e-16       2.363e-16       2.072e-16
# 42.170 31.623  56.234 ...       1.640e-16       1.870e-16       1.425e-16
# 74.989 56.234 100.000 ...       3.141e-17       3.559e-17       2.753e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.223e+00 1.566e-02                nan nan  False
# amplitude 1.302e-12 3.421e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.211e-11       4.244e-11       4.179e-11
#  0.133  0.100   0.178 ...       7.184e-12       7.247e-12       7.121e-12
#  0.237  0.178   0.316 ...       1.891e-12       1.911e-12       1.872e-12
#  0.422  0.316   0.562 ...       7.466e-13       7.591e-13       7.342e-13
#  0.750  0.562   1.000 ...       1.390e-13       1.412e-13       1.368e-13
#  1.334  1.000   1.778 ...       5.826e-14       5.981e-14       5.673e-14
#  2.371  1.778   3.162 ...       1.590e-14       1.634e-14       1.546e-14
#  4.217  3.162   5.623 ...       4.324e-15       4.433e-15       4.218e-15
#  7.499  5.623  10.000 ...       2.584e-15       2.723e-15       2.450e-15
# 13.335 10.000  17.783 ...       6.751e-16       7.122e-16       6.394e-16
# 23.714 17.783  31.623 ...       2.418e-16       2.569e-16       2.272e-16
# 42.170 31.623  56.234 ...       9.471e-17       1.182e-16       7.382e-17
# 74.989 56.234 100.000 ...       2.909e-17       3.318e-17       2.527e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.200e+00 1.618e-02                nan nan  False
# amplitude 1.244e-12 3.347e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.224e-11       4.258e-11       4.190e-11
#  0.133  0.100   0.178 ...       6.941e-12       6.948e-12       6.935e-12
#  0.237  0.178   0.316 ...       1.877e-12       1.883e-12       1.871e-12
#  0.422  0.316   0.562 ...       7.601e-13       7.728e-13       7.475e-13
#  0.750  0.562   1.000 ...       1.320e-13       1.342e-13       1.298e-13
#  1.334  1.000   1.778 ...       6.392e-14       6.550e-14       6.236e-14
#  2.371  1.778   3.162 ...       1.743e-14       1.789e-14       1.697e-14
#  4.217  3.162   5.623 ...       3.957e-15       4.074e-15       3.843e-15
#  7.499  5.623  10.000 ...       2.357e-15       2.493e-15       2.225e-15
# 13.335 10.000  17.783 ...       6.639e-16       6.984e-16       6.303e-16
# 23.714 17.783  31.623 ...       2.418e-16       2.567e-16       2.273e-16
# 42.170 31.623  56.234 ...       9.436e-17       1.178e-16       7.355e-17
# 74.989 56.234 100.000 ...       3.152e-17       3.595e-17       2.749e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.222e+00 1.614e-02                nan nan  False
# amplitude 1.243e-12 3.351e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.135e-11       4.164e-11       4.107e-11
#  0.133  0.100   0.178 ...       7.009e-12       7.065e-12       6.954e-12
#  0.237  0.178   0.316 ...       1.916e-12       1.939e-12       1.894e-12
#  0.422  0.316   0.562 ...       7.157e-13       7.268e-13       7.046e-13
#  0.750  0.562   1.000 ...       1.369e-13       1.392e-13       1.346e-13
#  1.334  1.000   1.778 ...       5.403e-14       5.553e-14       5.255e-14
#  2.371  1.778   3.162 ...       1.583e-14       1.628e-14       1.538e-14
#  4.217  3.162   5.623 ...       4.163e-15       4.264e-15       4.064e-15
#  7.499  5.623  10.000 ...       2.927e-15       3.067e-15       2.791e-15
# 13.335 10.000  17.783 ...       6.670e-16       7.013e-16       6.335e-16
# 23.714 17.783  31.623 ...       1.843e-16       1.991e-16       1.701e-16
# 42.170 31.623  56.234 ...       1.160e-16       1.393e-16       9.482e-17
# 74.989 56.234 100.000 ...       3.563e-17       3.970e-17       3.179e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.236e+00 1.539e-02                nan nan  False
# amplitude 1.331e-12 3.462e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.254e-11       4.266e-11       4.242e-11
#  0.133  0.100   0.178 ...       6.991e-12       7.047e-12       6.936e-12
#  0.237  0.178   0.316 ...       1.931e-12       1.953e-12       1.909e-12
#  0.422  0.316   0.562 ...       7.679e-13       7.805e-13       7.555e-13
#  0.750  0.562   1.000 ...       1.388e-13       1.411e-13       1.365e-13
#  1.334  1.000   1.778 ...       6.405e-14       6.599e-14       6.217e-14
#  2.371  1.778   3.162 ...       1.710e-14       1.757e-14       1.663e-14
#  4.217  3.162   5.623 ...       3.948e-15       4.078e-15       3.822e-15
#  7.499  5.623  10.000 ...       2.492e-15       2.650e-15       2.343e-15
# 13.335 10.000  17.783 ...       6.786e-16       7.131e-16       6.450e-16
# 23.714 17.783  31.623 ...       2.458e-16       2.605e-16       2.315e-16
# 42.170 31.623  56.234 ...       9.491e-17       1.185e-16       7.398e-17
# 74.989 56.234 100.000 ...       2.900e-17       3.304e-17       2.522e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.222e+00 1.621e-02                nan nan  False
# amplitude 1.246e-12 3.361e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.215e-11       4.220e-11       4.210e-11
#  0.133  0.100   0.178 ...       7.059e-12       7.122e-12       6.997e-12
#  0.237  0.178   0.316 ...       1.809e-12       1.828e-12       1.790e-12
#  0.422  0.316   0.562 ...       7.362e-13       7.467e-13       7.257e-13
#  0.750  0.562   1.000 ...       1.395e-13       1.417e-13       1.373e-13
#  1.334  1.000   1.778 ...       5.891e-14       6.078e-14       5.710e-14
#  2.371  1.778   3.162 ...       1.654e-14       1.699e-14       1.609e-14
#  4.217  3.162   5.623 ...       4.012e-15       4.112e-15       3.913e-15
#  7.499  5.623  10.000 ...       2.560e-15       2.699e-15       2.425e-15
# 13.335 10.000  17.783 ...       6.970e-16       7.328e-16       6.624e-16
# 23.714 17.783  31.623 ...       2.255e-16       2.418e-16       2.102e-16
# 42.170 31.623  56.234 ...       1.160e-16       1.393e-16       9.482e-17
# 74.989 56.234 100.000 ...       2.910e-17       3.316e-17       2.530e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.241e+00 1.603e-02                nan nan  False
# amplitude 1.255e-12 3.386e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.262e-11       4.292e-11       4.232e-11
#  0.133  0.100   0.178 ...       7.009e-12       7.068e-12       6.951e-12
#  0.237  0.178   0.316 ...       1.890e-12       1.906e-12       1.874e-12
#  0.422  0.316   0.562 ...       7.136e-13       7.257e-13       7.017e-13
#  0.750  0.562   1.000 ...       1.392e-13       1.418e-13       1.366e-13
#  1.334  1.000   1.778 ...       6.121e-14       6.280e-14       5.966e-14
#  2.371  1.778   3.162 ...       1.663e-14       1.711e-14       1.617e-14
#  4.217  3.162   5.623 ...       3.855e-15       3.965e-15       3.748e-15
#  7.499  5.623  10.000 ...       2.596e-15       2.749e-15       2.450e-15
# 13.335 10.000  17.783 ...       6.473e-16       6.863e-16       6.102e-16
# 23.714 17.783  31.623 ...       2.301e-16       2.450e-16       2.156e-16
# 42.170 31.623  56.234 ...       9.498e-17       1.186e-16       7.404e-17
# 74.989 56.234 100.000 ...       2.644e-17       3.052e-17       2.265e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.206e+00 1.524e-02                nan nan  False
# amplitude 1.337e-12 3.450e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.155e-11       4.181e-11       4.129e-11
#  0.133  0.100   0.178 ...       7.137e-12       7.138e-12       7.136e-12
#  0.237  0.178   0.316 ...       1.922e-12       1.936e-12       1.909e-12
#  0.422  0.316   0.562 ...       8.116e-13       8.261e-13       7.972e-13
#  0.750  0.562   1.000 ...       1.398e-13       1.421e-13       1.375e-13
#  1.334  1.000   1.778 ...       5.880e-14       6.036e-14       5.726e-14
#  2.371  1.778   3.162 ...       1.685e-14       1.739e-14       1.632e-14
#  4.217  3.162   5.623 ...       3.921e-15       4.016e-15       3.826e-15
#  7.499  5.623  10.000 ...       2.887e-15       3.029e-15       2.750e-15
# 13.335 10.000  17.783 ...       7.510e-16       7.878e-16       7.155e-16
# 23.714 17.783  31.623 ...       2.339e-16       2.487e-16       2.195e-16
# 42.170 31.623  56.234 ...       1.493e-16       1.725e-16       1.278e-16
# 74.989 56.234 100.000 ...       3.372e-17       3.782e-17       2.986e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.221e+00 1.557e-02                nan nan  False
# amplitude 1.276e-12 3.390e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.144e-11       4.174e-11       4.114e-11
#  0.133  0.100   0.178 ...       7.084e-12       7.138e-12       7.030e-12
#  0.237  0.178   0.316 ...       1.936e-12       1.959e-12       1.914e-12
#  0.422  0.316   0.562 ...       7.677e-13       7.806e-13       7.550e-13
#  0.750  0.562   1.000 ...       1.389e-13       1.413e-13       1.365e-13
#  1.334  1.000   1.778 ...       5.897e-14       6.089e-14       5.711e-14
#  2.371  1.778   3.162 ...       1.671e-14       1.716e-14       1.626e-14
#  4.217  3.162   5.623 ...       4.035e-15       4.145e-15       3.928e-15
#  7.499  5.623  10.000 ...       2.747e-15       2.887e-15       2.611e-15
# 13.335 10.000  17.783 ...       6.186e-16       6.527e-16       5.854e-16
# 23.714 17.783  31.623 ...       2.038e-16       2.182e-16       1.898e-16
# 42.170 31.623  56.234 ...       6.695e-17       9.092e-17       4.674e-17
# 74.989 56.234 100.000 ...       2.376e-17       2.787e-17       1.997e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.213e+00 1.582e-02                nan nan  False
# amplitude 1.289e-12 3.391e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.243e-11       4.279e-11       4.208e-11
#  0.133  0.100   0.178 ...       7.135e-12       7.194e-12       7.076e-12
#  0.237  0.178   0.316 ...       1.893e-12       1.913e-12       1.872e-12
#  0.422  0.316   0.562 ...       7.352e-13       7.478e-13       7.227e-13
#  0.750  0.562   1.000 ...       1.382e-13       1.404e-13       1.360e-13
#  1.334  1.000   1.778 ...       5.986e-14       6.162e-14       5.815e-14
#  2.371  1.778   3.162 ...       1.620e-14       1.680e-14       1.562e-14
#  4.217  3.162   5.623 ...       4.041e-15       4.140e-15       3.943e-15
#  7.499  5.623  10.000 ...       2.642e-15       2.787e-15       2.503e-15
# 13.335 10.000  17.783 ...       6.833e-16       7.179e-16       6.496e-16
# 23.714 17.783  31.623 ...       2.379e-16       2.527e-16       2.235e-16
# 42.170 31.623  56.234 ...       1.338e-16       1.568e-16       1.126e-16
# 74.989 56.234 100.000 ...       3.763e-17       4.171e-17       3.377e-17
#    name     value     error        unit      min max frozen
# --------- --------- --------- -------------- --- --- ------
#     index 2.222e+00 1.542e-02                nan nan  False
# amplitude 1.316e-12 3.429e-14 cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00 0.000e+00            TeV nan nan   True
# e_ref  e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#  TeV    TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# ------ ------ ------- ... --------------- --------------- ---------------
#  0.075  0.056   0.100 ...       4.280e-11       4.310e-11       4.251e-11
#  0.133  0.100   0.178 ...       7.076e-12       7.137e-12       7.016e-12
#  0.237  0.178   0.316 ...       1.915e-12       1.929e-12       1.900e-12
#  0.422  0.316   0.562 ...       7.570e-13       7.687e-13       7.455e-13
#  0.750  0.562   1.000 ...       1.394e-13       1.417e-13       1.372e-13
#  1.334  1.000   1.778 ...       6.017e-14       6.201e-14       5.838e-14
#  2.371  1.778   3.162 ...       1.664e-14       1.714e-14       1.614e-14
#  4.217  3.162   5.623 ...       4.104e-15       4.209e-15       4.001e-15
#  7.499  5.623  10.000 ...       2.677e-15       2.838e-15       2.524e-15
# 13.335 10.000  17.783 ...       6.656e-16       7.027e-16       6.299e-16
# 23.714 17.783  31.623 ...       1.943e-16       2.091e-16       1.800e-16
# 42.170 31.623  56.234 ...       1.640e-16       1.871e-16       1.425e-16
# 74.989 56.234 100.000 ...       3.562e-17       3.973e-17       3.175e-17
# CPU times: user 2min 24s, sys: 196 ms, total: 2min 25s
# Wall time: 2min 25s

# %%
index = np.array([_["index"] for _ in results])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.xlabel('Index')
plt.ylabel('Number of observations')
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.2201646403325443 += 0.017352799463650988

# %%
amplitude = np.array([_["amplitude"] for _ in results])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.xlabel('Amplitude')
plt.ylabel('Number of observations')
print(f"amplitude: {amplitude.mean()} += {amplitude.std()}")
# Out:
# amplitude: 1.2875016021510996e-12 += 3.1236910793988005e-14

# %%
reference = np.array([_["reference"] for _ in results])
x = np.array([index, amplitude, reference])
covar=np.cov(x)
print(covar)
# Out:
# [[ 3.03548033e-04 -1.33818961e-16  0.00000000e+00]
#  [-1.33818961e-16  9.83613504e-28  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
simu = PowerLawSpectralModel(
    index=index.mean(),
    amplitude=amplitude.mean() * u.Unit("cm-2 s-1 TeV-1"),
    reference=1 * u.TeV,
)
print(simu)
# Out:
# PowerLawSpectralModel
#
#    name     value   error      unit      min max frozen
# --------- --------- ----- -------------- --- --- ------
#     index 2.220e+00   nan                nan nan  False
# amplitude 1.288e-12   nan cm-2 s-1 TeV-1 nan nan  False
# reference 1.000e+00   nan            TeV nan nan   True

# %%
i = 0
fpes[i].table_formatted
# Out:
# <Table length=13>
#  e_ref   e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64         float64
# ------- ------- ------- ... --------------- --------------- ---------------
#   0.075   0.056   0.100 ...       4.190e-11       4.218e-11       4.163e-11
#   0.133   0.100   0.178 ...       7.064e-12       7.124e-12       7.005e-12
#   0.237   0.178   0.316 ...       1.869e-12       1.889e-12       1.849e-12
#   0.422   0.316   0.562 ...       8.040e-13       8.180e-13       7.903e-13
#   0.750   0.562   1.000 ...       1.409e-13       1.437e-13       1.383e-13
#   1.334   1.000   1.778 ...       6.061e-14       6.222e-14       5.902e-14
#   2.371   1.778   3.162 ...       1.531e-14       1.574e-14       1.489e-14
#   4.217   3.162   5.623 ...       4.169e-15       4.270e-15       4.069e-15
#   7.499   5.623  10.000 ...       2.527e-15       2.676e-15       2.384e-15
#  13.335  10.000  17.783 ...       5.668e-16       6.009e-16       5.336e-16
#  23.714  17.783  31.623 ...       2.256e-16       2.411e-16       2.109e-16
#  42.170  31.623  56.234 ...       1.340e-16       1.571e-16       1.127e-16
#  74.989  56.234 100.000 ...       3.753e-17       4.159e-17       3.368e-17

# %%
plt.figure(figsize=(16, 8))
fpes[i].table["is_ul"] = fpes[i].table["ts"] < 4
ax = fpes[i].plot(
    energy_power=2, flux_unit="erg-1 cm-2 s-1", color="darkorange"
)
fpes[i].to_sed_type("e2dnde").plot_ts_profiles(ax=ax)

# %%
flux_points_dataset = FluxPointsDataset(
    data=fpes[i], models=model_best_joints[i]
)

# %%
plt.figure(figsize=(16, 8))
flux_points_dataset.peek();

# %%
energy_range = [0.03, 100] * u.TeV
plt.figure(figsize=[16,8])
fpes[i].plot(energy_power=2)
simu.plot(energy_range=energy_range, energy_power=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['ref_e2dnde'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'ref_e2dnde\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['dnde'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['dnde'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['dnde'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'dnde\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
fig = plt.figure(figsize=[20,16],constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    e_ref_first = np.array([_.table['counts'][n] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+1}')
    plt.ylabel('Number of observations')
    
gs2 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[1])
for n in range(3):
    ax = fig.add_subplot(gs2[n])
    e_ref_first = np.array([_.table['counts'][n+3] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+4}')
    plt.ylabel('Number of observations')

gs3 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[2])
for n in range(3):
    ax = fig.add_subplot(gs3[n])
    e_ref_first = np.array([_.table['counts'][n+6] for _ in fpes])
    plt.hist(e_ref_first, bins=10, alpha=0.5)
    plt.xlabel(f'counts\nbin no:{n+7}')
    plt.ylabel('Number of observations')

plt.show()

# %%
x = ['ref_dnde','ref_flux','ref_eflux','ref_e2dnde','norm','stat','norm_err','norm_errp','norm_errn','norm_ul','sqrt_ts','ts','norm_scan','stat_scan','dnde','dnde_ul','dnde_err','dnde_errp','dnde_errn']

# %%
flux_points_mean = fpe.run()
flux_points_mean.table_formatted
# Out:
# <Table length=14>
#  e_ref   e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64         float64
# ------- ------- ------- ... --------------- --------------- ---------------
#   0.042   0.032   0.056 ...       1.604e-10       1.614e-10       1.595e-10
#   0.075   0.056   0.100 ...       4.280e-11       4.310e-11       4.251e-11
#   0.133   0.100   0.178 ...       7.076e-12       7.137e-12       7.016e-12
#   0.237   0.178   0.316 ...       1.915e-12       1.929e-12       1.900e-12
#   0.422   0.316   0.562 ...       7.571e-13       7.687e-13       7.455e-13
#   0.750   0.562   1.000 ...       1.394e-13       1.417e-13       1.372e-13
#   1.334   1.000   1.778 ...       6.017e-14       6.201e-14       5.838e-14
#   2.371   1.778   3.162 ...       1.664e-14       1.714e-14       1.614e-14
#   4.217   3.162   5.623 ...       4.104e-15       4.209e-15       4.001e-15
#   7.499   5.623  10.000 ...       2.677e-15       2.838e-15       2.524e-15
#  13.335  10.000  17.783 ...       6.656e-16       7.027e-16       6.299e-16
#  23.714  17.783  31.623 ...       1.943e-16       2.091e-16       1.800e-16
#  42.170  31.623  56.234 ...       1.640e-16       1.871e-16       1.425e-16
#  74.989  56.234 100.000 ...       3.562e-17       3.973e-17       3.175e-17

# %%
for _ in x:
    y = 0
    for bin in fpes:
        y = y + bin.table[_]
    y = y/len(fpes)
    flux_points_mean.table[_] = y
    
y = 0
for bin in fpes:
    y = y + bin.table['counts']
y = y/len(fpes)
flux_points_mean.table['counts'] = y

# %%
flux_points_mean.table_formatted
# Out:
# <Table length=14>
#  e_ref   e_min   e_max  ...     dnde_err       dnde_errp       dnde_errn
#   TeV     TeV     TeV   ... 1 / (cm2 s TeV) 1 / (cm2 s TeV) 1 / (cm2 s TeV)
# float64 float64 float64 ...     float64         float64         float64
# ------- ------- ------- ... --------------- --------------- ---------------
#   0.042   0.032   0.056 ...       1.613e-10       1.621e-10       1.604e-10
#   0.075   0.056   0.100 ...       4.215e-11       4.241e-11       4.189e-11
#   0.133   0.100   0.178 ...       7.072e-12       7.120e-12       7.024e-12
#   0.237   0.178   0.316 ...       1.891e-12       1.909e-12       1.873e-12
#   0.422   0.316   0.562 ...       7.542e-13       7.659e-13       7.426e-13
#   0.750   0.562   1.000 ...       1.382e-13       1.407e-13       1.358e-13
#   1.334   1.000   1.778 ...       6.082e-14       6.252e-14       5.917e-14
#   2.371   1.778   3.162 ...       1.674e-14       1.723e-14       1.625e-14
#   4.217   3.162   5.623 ...       4.039e-15       4.145e-15       3.934e-15
#   7.499   5.623  10.000 ...       2.556e-15       2.699e-15       2.419e-15
#  13.335  10.000  17.783 ...       6.512e-16       6.862e-16       6.172e-16
#  23.714  17.783  31.623 ...       2.243e-16       2.394e-16       2.097e-16
#  42.170  31.623  56.234 ...       1.407e-16       1.641e-16       1.195e-16
#  74.989  56.234 100.000 ...       3.160e-17       3.571e-17       2.775e-17

# %%
plt.figure(figsize=(16, 8))
flux_points_mean.table["is_ul"] = flux_points_mean.table["ts"] < 4
ax = flux_points_mean.plot(
    energy_power=2, flux_unit="erg-1 cm-2 s-1", color="darkorange"
)
flux_points_mean.to_sed_type("e2dnde").plot_ts_profiles(ax=ax)

# %%
flux_points_dataset = FluxPointsDataset(
    data=flux_points_mean, models=model_best_joints[124]
)

# %%
plt.figure(figsize=(16, 8))
flux_points_dataset.peek();

# %%
plt.figure(figsize=[16,8])
flux_points_mean.plot(energy_power=2)
simu.plot(energy_range=energy_range, energy_power=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
