# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.5
coord = SkyCoord(233.738, 23.503, unit="deg", frame="icrs")
pointing = coord.galactic

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(coord.galactic.l.deg, coord.galactic.b.deg),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model = ExpCutoffPowerLawSpectralModel(
    index=2.351, amplitude="2.956e-14 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.351
#     amplitude               :   2.96e-14  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.500  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   :  36.627  deg
#     lat_0                   :  53.029  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, energy_true, livetime, irfs, pointing, geom, models,rand):
    model = models.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(rand) #random state
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model[0].copy()
    models_fit_1 = model[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result_1 = fit.run()
    print(result_1)
    TS1 = result_1.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result_2 = fit.run()
    print(result_2)
    TS2 = result_2.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit, result_1, result_2

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [100.0,250.0,500.0,750.0,1000.0] * u.hr
y1 = []

# %%
# %%time
for i in range(len(x)):
    for j in range(100):
        y1.append(FoV(energy_reco, energy_true, x[i], irfs, pointing, geom, models,j))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 72
# 	total stat : -13340766.07
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 312
# 	total stat : -13340766.24
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 148
# 	total stat : -13336993.04
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 306
# 	total stat : -13336993.60
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 174
# 	total stat : -13335249.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 237
# 	total stat : -13335249.96
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 150
# 	total stat : -13355965.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 210
# 	total stat : -13355965.79
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 100
# 	total stat : -13336879.70
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 355
# 	total stat : -13336880.04
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/gammapy/modeling/models/core.py:95: RuntimeWarning: invalid value encountered in sqrt
#   par.error = np.sqrt(variance)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 121
# 	total stat : -13353708.24
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/gammapy/modeling/models/core.py:95: RuntimeWarning: invalid value encountered in sqrt
#   par.error = np.sqrt(variance)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 146
# 	total stat : -13353708.15
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 252
# 	total stat : -13336013.55
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 183
# 	total stat : -13336012.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 123
# 	total stat : -13362641.26
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 174
# 	total stat : -13362642.13
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 164
# 	total stat : -13327310.77
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 313
# 	total stat : -13327312.28
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 126
# 	total stat : -13355167.09
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 149
# 	total stat : -13355167.06
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 129
# 	total stat : -13348707.04
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 222
# 	total stat : -13348706.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 151
# 	total stat : -13361302.46
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 432
# 	total stat : -13361302.91
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 331
# 	total stat : -13345422.63
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 184
# 	total stat : -13345423.05
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 123
# 	total stat : -13360265.36
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 384
# 	total stat : -13360268.74
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 136
# 	total stat : -13339934.08
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 229
# 	total stat : -13339936.44
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 178
# 	total stat : -13349110.07
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 169
# 	total stat : -13349110.17
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 233
# 	total stat : -13350135.82
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 125
# 	total stat : -13350135.81
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 174
# 	total stat : -13332085.68
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 174
# 	total stat : -13332086.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 192
# 	total stat : -13350952.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 636
# 	total stat : -13350956.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 221
# 	total stat : -13341471.67
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 1061
# 	total stat : -13341472.30
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 150
# 	total stat : -13354266.80
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 302
# 	total stat : -13354266.44
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 140
# 	total stat : -13352270.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 682
# 	total stat : -13352270.59
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 235
# 	total stat : -13359890.66
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 155
# 	total stat : -13359891.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 195
# 	total stat : -13342868.14
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 212
# 	total stat : -13342867.59
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 107
# 	total stat : -13342621.47
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 131
# 	total stat : -13342621.39
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 137
# 	total stat : -13353144.33
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 130
# 	total stat : -13353143.84
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 219
# 	total stat : -13350623.38
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 229
# 	total stat : -13350623.76
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       :