# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.5
coord = SkyCoord(141.409467, 40.566962, unit="deg", frame="icrs")
pointing = coord.galactic

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(coord.galactic.l.deg, coord.galactic.b.deg),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model = ExpCutoffPowerLawSpectralModel(
    index=2.495, amplitude="2.72e-13 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.495
#     amplitude               :   2.72e-13  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.500  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 181.512  deg
#     lat_0                   :  45.879  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
spatial_model_1 = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model_1 = ExpCutoffPowerLawSpectralModel(
    index=3, amplitude="1e-12 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=0 * u.Unit("TeV-1"), alpha = 1
)
model_simu_1 = SkyModel(
    spatial_model=spatial_model_1,
    spectral_model=spectral_model_1,
    name="model-simu",
)

bkg_model_1 = FoVBackgroundModel(dataset_name="dataset-simu")

models_1 = Models([model_simu_1, bkg_model_1])
print(models_1)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   3.000
#     amplitude               :   1.00e-12  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.000  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 181.512  deg
#     lat_0                   :  45.879  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, energy_true, livetime, irfs, pointing, geom, models, models_1,rand):
    model = models.copy()
    model_1 = models_1.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(rand)
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = dataset1.to_spectrum_dataset(on_region=regions)
    dataset2 = dataset2.to_spectrum_dataset(on_region=regions)
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model_1[0].copy()
    models_fit_1 = model_1[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result_1 = fit.run()
    print(result_1)
    TS1 = result_1.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result_2 = fit.run()
    print(result_2)
    TS2 = result_2.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit, result_1, result_2

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [5.0,10.0,25.0,50.0,100.0] * u.hr
y1 = []

# %%
# %%time
for i in range(len(x)):
    for j in range(100):
        y1.append(FoV(energy_reco, energy_true, x[i], irfs, pointing, geom, models, models_1,j))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -22729.72
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 582
# 	total stat : -22734.80
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -24230.32
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 149
# 	total stat : -24231.71
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 86
# 	total stat : -23347.86
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 604
# 	total stat : -23357.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -22700.86
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 314
# 	total stat : -22703.35
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 77
# 	total stat : -23826.92
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -23826.95
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -22668.98
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 233
# 	total stat : -22672.41
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -24152.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 235
# 	total stat : -24162.31
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -23499.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 177
# 	total stat : -23501.27
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -23556.50
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 178
# 	total stat : -23560.34
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -23966.27
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 163
# 	total stat : -23966.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 113
# 	total stat : -23257.55
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 122
# 	total stat : -23257.88
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 77
# 	total stat : -24319.80
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 164
# 	total stat : -24322.85
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -24596.92
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 94
# 	total stat : -24597.42
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -24623.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 149
# 	total stat : -24623.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -23262.64
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 110
# 	total stat : -23262.62
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -24072.98
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 234
# 	total stat : -24076.12
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 68
# 	total stat : -24603.34
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 164
# 	total stat : -24605.56
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -23992.01
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 154
# 	total stat : -23992.48
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -23159.48
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 96
# 	total stat : -23159.65
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -23930.09
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 195
# 	total stat : -23932.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 105
# 	total stat : -23767.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 122
# 	total stat : -23767.90
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 98
# 	total stat : -23893.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 177
# 	total stat : -23894.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 68
# 	total stat : -22367.50
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 239
# 	total stat : -22369.05
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 96
# 	total stat : -23092.42
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 138
# 	total stat : -23092.70
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 68
# 	total stat : -23407.07
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 95
# 	total stat : -23407.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -22725.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 464
# 	total stat : -22730.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -24560.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 93
# 	total stat : -24561.44
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 99
# 	total stat : -24407.38
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 156
# 	total stat : -24408.16
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -23703.02
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 248
# 	total stat : -23705.62
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -23597.36
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 291
# 	total stat : -23601.54
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 76
# 	total stat : -23639.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 183
# 	total stat : -23643.40
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 98
# 	total stat : -25031.22
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 223
# 	total stat : -25034.94
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 68
# 	total stat : -23047.51
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 251
# 	total stat : -23050.92
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 77
# 	total stat : -23623.65
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 114
# 	total stat : -23623.71
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 68
# 	total stat : -24230.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 151
# 	total stat : -24231.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -24878.97
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 109
# 	total stat : -24879.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 86
# 	total stat : -25262.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 161
# 	total stat : -25262.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat :
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -738695.69
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 205
# 	total stat : -738701.19
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -747340.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 200
# 	total stat : -747367.06
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 80
# 	total stat : -738366.88
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 229
# 	total stat : -738386.31
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 89
# 	total stat : -734409.09
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 189
# 	total stat : -734423.13
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -744892.95
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 179
# 	total stat : -744897.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 80
# 	total stat : -740133.34
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 176
# 	total stat : -740145.07
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -733226.04
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 183
# 	total stat : -733233.23
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 77
# 	total stat : -735628.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 205
# 	total stat : -735646.50
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -744265.69
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 187
# 	total stat : -744280.70
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -740262.35
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 208
# 	total stat : -740273.85
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 89
# 	total stat : -738262.05
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 176
# 	total stat : -738269.94
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 89
# 	total stat : -742304.46
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 253
# 	total stat : -742310.67
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -739057.81
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 194
# 	total stat : -739065.43
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -737884.44
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 319
# 	total stat : -737903.91
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 89
# 	total stat : -736372.98
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 324
# 	total stat : -736397.81
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 70
# 	total stat : -738244.32
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 172
# 	total stat : -738255.63
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 89
# 	total stat : -740152.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 315
# 	total stat : -740178.57
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -739562.72
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 188
# 	total stat : -739578.61
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 90
# 	total stat : -742479.20
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 176
# 	total stat : -742486.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -741435.93
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 216
# 	total stat : -741482.29
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 79
# 	total stat : -737453.07
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 252
# 	total stat : -737462.30
#
# CPU times: user 30min 8s, sys: 13.1 s, total: 30min 21s
# Wall time: 30min 18s

# %%
del_TS_ = []
del_TS_1 = []
del_TS_2 = []
dataset_ = []
model_ = []
significance_ = []
excess_ = []
dataset_1 = []
model_1 = []
result_1 = []
result_2 = []
for i in range(len(x)):
    for j in range(100):
        del_TS_.append(y1[100*i+j][0])
        dataset_.append(y1[100*i+j][1])
        model_.append(y1[100*i+j][2])
        del_TS_1.append(y1[100*i+j][3])
        del_TS_2.append(y1[100*i+j][4])
        significance_.append(y1[100*i+j][5])
        excess_.append(y1[100*i+j][6])
        dataset_1.append(y1[100*i+j][7])
        model_1.append(y1[100*i+j][8])
        result_1.append(y1[100*i+j][9])
        result_2.append(y1[100*i+j][10])
        
index_ = []
amplitude_ = []
for k in range(500):
    index_.append(model_[k].spectral_model.index.value)
    amplitude_.append(model_[k].spectral_model.amplitude.value)

# %%
index = np.array(index_[0:100])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 5hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.333046634798587 += 0.6722665946699976

# %%
index = np.array(index_[100:200])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 10hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.391190013596543 += 0.3796085599174252

# %%
index = np.array(index_[200:300])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 25hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.4581213521691434 += 0.2438050506829269

# %%
index = np.array(index_[300:400])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 50hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.4515107767800823 += 0.14801851903635738

# %%
index = np.array(index_[400:500])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 100hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.480912314101112 += 0.10567610005831996

# %%
amplitude = np.array(amplitude_[0:100])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 5hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.245079701441676e-12 += 1.1740137373062902e-11

# %%
amplitude = np.array(amplitude_[100:200])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 10hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 4.206370200170134e-13 += 3.816766248685509e-13

# %%
amplitude = np.array(amplitude_[200:300])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 25hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 3.161827203111672e-13 += 1.495589579816957e-13

# %%
amplitude = np.array(amplitude_[300:400])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 50hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.9428154434375353e-13 += 8.020899863378009e-14

# %%
amplitude = np.array(amplitude_[400:500])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 100hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.7922161098290175e-13 += 6.144175604883485e-14

# %%
print(np.average(del_TS_1[0:100]))
print(np.average(del_TS_1[100:200]))
print(np.average(del_TS_1[200:300]))
print(np.average(del_TS_1[300:400]))
print(np.average(del_TS_1[400:500]))
# Out:
# 1.9697093785636388
# 3.3467296397533937
# 5.563275906296039
# 10.360550022008248
# 18.26812406771467

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[0:100])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 5hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 5hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[100:200])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 10hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 10hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[200:300])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 25hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 25hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[300:400])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 50hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 50hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[400:500])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 100hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 100hrs')

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_1[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate for fixed parameter lambda for different livetime: {True_rate}")
# Out:
# True success rate for fixed parameter lambda for different livetime: [87, 84, 89, 86, 87]

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_2[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate for free parameter lambda for different livetime: {True_rate}")
# Out:
# True success rate for free parameter lambda for different livetime: [65, 73, 99, 97, 100]

# %%
excess_maps(significance_[0], excess_[0])
excess_maps(significance_[100], excess_[100])
excess_maps(significance_[200], excess_[200])
excess_maps(significance_[300], excess_[300])
excess_maps(significance_[400], excess_[400])

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_2[(100*j)+i].success==1 and result_1[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate different livetime: {True_rate}")
# Out:
# True success rate different livetime: [56, 60, 88, 86, 87]
