# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z20_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.05
coord = SkyCoord(141.409467, 40.566962, unit="deg", frame="icrs")
pointing = coord.galactic

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(coord.galactic.l.deg, coord.galactic.b.deg),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model = ExpCutoffPowerLawSpectralModel(
    index=2.495, amplitude="2.72e-13 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.495
#     amplitude               :   2.72e-13  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.050  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 181.512  deg
#     lat_0                   :  45.879  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
spatial_model_1 = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model_1 = ExpCutoffPowerLawSpectralModel(
    index=3, amplitude="1e-12 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=0 * u.Unit("TeV-1"), alpha = 1
)
model_simu_1 = SkyModel(
    spatial_model=spatial_model_1,
    spectral_model=spectral_model_1,
    name="model-simu",
)

bkg_model_1 = FoVBackgroundModel(dataset_name="dataset-simu")

models_1 = Models([model_simu_1, bkg_model_1])
print(models_1)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   3.000
#     amplitude               :   1.00e-12  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.000  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 181.512  deg
#     lat_0                   :  45.879  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, energy_true, livetime, irfs, pointing, geom, models, models_1,rand):
    model = models.copy()
    model_1 = models_1.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(rand)
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = dataset1.to_spectrum_dataset(on_region=regions)
    dataset2 = dataset2.to_spectrum_dataset(on_region=regions)
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model_1[0].copy()
    models_fit_1 = model_1[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result_1 = fit.run()
    print(result_1)
    TS1 = result_1.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result_2 = fit.run()
    print(result_2)
    TS2 = result_2.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit, result_1, result_2

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [5.0,10.0,25.0,50.0,100.0] * u.hr
y1 = []

# %%
# %%time
for i in range(len(x)):
    for j in range(100):
        y1.append(FoV(energy_reco, energy_true, x[i], irfs, pointing, geom, models, models_1,j))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -22654.77
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 198
# 	total stat : -22656.21
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 96
# 	total stat : -24383.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 149
# 	total stat : -24383.85
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 98
# 	total stat : -23673.12
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 157
# 	total stat : -23674.67
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 99
# 	total stat : -23726.65
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 140
# 	total stat : -23727.17
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -24235.27
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 136
# 	total stat : -24235.47
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 106
# 	total stat : -23376.87
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 171
# 	total stat : -23380.43
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 96
# 	total stat : -24238.37
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 162
# 	total stat : -24238.38
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 86
# 	total stat : -24166.05
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 201
# 	total stat : -24168.47
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 98
# 	total stat : -23965.52
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 177
# 	total stat : -23967.18
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -24407.42
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 172
# 	total stat : -24408.08
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -23807.38
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 160
# 	total stat : -23808.24
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -25045.87
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 160
# 	total stat : -25047.03
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -25217.79
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 150
# 	total stat : -25218.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -24895.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 95
# 	total stat : -24895.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 95
# 	total stat : -24252.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 154
# 	total stat : -24253.28
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 80
# 	total stat : -23936.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 149
# 	total stat : -23936.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -25536.40
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 146
# 	total stat : -25536.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -24326.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 160
# 	total stat : -24327.02
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 96
# 	total stat : -24169.61
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 173
# 	total stat : -24169.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -24286.72
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 166
# 	total stat : -24287.96
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 80
# 	total stat : -23744.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 170
# 	total stat : -23747.63
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 88
# 	total stat : -23983.91
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 148
# 	total stat : -23984.30
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -23866.71
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 163
# 	total stat : -23867.01
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 101
# 	total stat : -23533.22
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 148
# 	total stat : -23533.25
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 96
# 	total stat : -24324.37
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 148
# 	total stat : -24325.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 90
# 	total stat : -23770.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 163
# 	total stat : -23770.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 95
# 	total stat : -24539.49
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 148
# 	total stat : -24539.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 85
# 	total stat : -25515.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 160
# 	total stat : -25516.50
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 98
# 	total stat : -24144.25
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 153
# 	total stat : -24144.25
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 107
# 	total stat : -23934.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       :
34
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 90
# 	total stat : -762080.56
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 168
# 	total stat : -762081.59
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -762753.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 153
# 	total stat : -762754.15
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -756062.90
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 181
# 	total stat : -756071.35
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -761132.85
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 179
# 	total stat : -761134.24
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -755006.42
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 168
# 	total stat : -755007.13
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 102
# 	total stat : -751912.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 163
# 	total stat : -751912.95
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -760348.17
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 175
# 	total stat : -760348.37
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -762318.38
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 166
# 	total stat : -762320.08
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -752396.79
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 179
# 	total stat : -752398.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -761120.68
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 168
# 	total stat : -761121.45
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 90
# 	total stat : -763598.74
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 166
# 	total stat : -763598.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -756925.71
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 178
# 	total stat : -756926.93
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -755684.64
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 179
# 	total stat : -755685.73
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -759965.17
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 160
# 	total stat : -759965.25
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -759357.69
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 178
# 	total stat : -759358.18
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -757225.58
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 189
# 	total stat : -757227.03
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 102
# 	total stat : -752211.28
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 184
# 	total stat : -752215.12
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -755158.32
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 178
# 	total stat : -755160.46
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -759928.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 164
# 	total stat : -759935.91
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 100
# 	total stat : -760360.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 177
# 	total stat : -760361.22
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -757252.04
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 176
# 	total stat : -757255.01
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 91
# 	total stat : -757966.63
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 164
# 	total stat : -757971.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 99
# 	total stat : -746430.21
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 167
# 	total stat : -746430.21
#
# CPU times: user 28min 26s, sys: 12.6 s, total: 28min 39s
# Wall time: 28min 36s

# %%
del_TS_ = []
del_TS_1 = []
del_TS_2 = []
dataset_ = []
model_ = []
significance_ = []
excess_ = []
dataset_1 = []
model_1 = []
result_1 = []
result_2 = []
for i in range(len(x)):
    for j in range(100):
        del_TS_.append(y1[100*i+j][0])
        dataset_.append(y1[100*i+j][1])
        model_.append(y1[100*i+j][2])
        del_TS_1.append(y1[100*i+j][3])
        del_TS_2.append(y1[100*i+j][4])
        significance_.append(y1[100*i+j][5])
        excess_.append(y1[100*i+j][6])
        dataset_1.append(y1[100*i+j][7])
        model_1.append(y1[100*i+j][8])
        result_1.append(y1[100*i+j][9])
        result_2.append(y1[100*i+j][10])
        
index_ = []
amplitude_ = []
for k in range(500):
    index_.append(model_[k].spectral_model.index.value)
    amplitude_.append(model_[k].spectral_model.amplitude.value)

# %%
index = np.array(index_[0:100])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 5hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.476304101153046 += 0.28341632551710216

# %%
index = np.array(index_[100:200])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 10hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.4711786367884985 += 0.14855966926645908

# %%
index = np.array(index_[200:300])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 25hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.459198663629763 += 0.10456668053445138

# %%
index = np.array(index_[300:400])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 50hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.4696451242795185 += 0.07426133026350135

# %%
index = np.array(index_[400:500])
plt.hist(index, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["index"].value, color="red")
plt.title("Livetime = 100hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {index.mean()} += {index.std()}")
# Out:
# index: 2.4797143739038234 += 0.05645581501461226

# %%
amplitude = np.array(amplitude_[0:100])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 5hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.839588240364445e-13 += 1.0245084391362792e-13

# %%
amplitude = np.array(amplitude_[100:200])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 10hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.7911877464514055e-13 += 6.416881813850123e-14

# %%
amplitude = np.array(amplitude_[200:300])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 25hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.8933506447965423e-13 += 4.755885572240336e-14

# %%
amplitude = np.array(amplitude_[300:400])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 50hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.7809470010441057e-13 += 3.035860670446024e-14

# %%
amplitude = np.array(amplitude_[400:500])
plt.hist(amplitude, bins=10, alpha=0.5)
plt.axvline(x=model_simu.parameters["amplitude"].value, color="red")
plt.title("Livetime = 100hrs")
plt.ylabel("Value")
plt.xlabel("No. of Observations")
print(f"index: {amplitude.mean()} += {amplitude.std()}")
# Out:
# index: 2.747873816802571e-13 += 2.352446939950829e-14

# %%
print(np.average(del_TS_1[0:100]))
print(np.average(del_TS_1[100:200]))
print(np.average(del_TS_1[200:300]))
print(np.average(del_TS_1[300:400]))
print(np.average(del_TS_1[400:500]))
# Out:
# 0.9429150152543297
# 0.9298472708751797
# 1.762723401117546
# 2.0004004486621123
# 2.844211141077103

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[0:100])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 5hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 5hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[100:200])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 10hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 10hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[200:300])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 25hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 25hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[300:400])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 50hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 50hrs')

# %%
plt.scatter(np.linspace(0,99,100),del_TS_1[400:500])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("Observation no.")
plt.title("Livetime = 100hrs")
# Out:
# Text(0.5, 1.0, 'Livetime = 100hrs')

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_1[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate for fixed parameter lambda for different livetime: {True_rate}")
# Out:
# True success rate for fixed parameter lambda for different livetime: [100, 100, 100, 100, 100]

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_2[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate for free parameter lambda for different livetime: {True_rate}")
# Out:
# True success rate for free parameter lambda for different livetime: [98, 100, 100, 100, 100]

# %%
excess_maps(significance_[0], excess_[0])
excess_maps(significance_[100], excess_[100])
excess_maps(significance_[200], excess_[200])
excess_maps(significance_[300], excess_[300])
excess_maps(significance_[400], excess_[400])

# %%
True_rate = []
for j in range(len(x)):
    r=0
    for i in range(100):
        if result_2[(100*j)+i].success==1 and result_1[(100*j)+i].success==1:
            r = r+1
    True_rate.append(r)
print(f"True success rate different livetime: {True_rate}")
# Out:
# True success rate different livetime: [98, 100, 100, 100, 100]
