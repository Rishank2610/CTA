# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/North_z40_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.2
coord = SkyCoord(233.738, 23.503, unit="deg", frame="icrs")
pointing = coord.galactic

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(coord.galactic.l.deg, coord.galactic.b.deg),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model = ExpCutoffPowerLawSpectralModel(
    index=2.351, amplitude="2.956e-14 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.351
#     amplitude               :   2.96e-14  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.200  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   :  36.627  deg
#     lat_0                   :  53.029  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
spatial_model_1 = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model_1 = ExpCutoffPowerLawSpectralModel(
    index=2, amplitude="1e-13 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=0 * u.Unit("TeV-1"), alpha = 1
)
model_simu_1 = SkyModel(
    spatial_model=spatial_model_1,
    spectral_model=spectral_model_1,
    name="model-simu",
)

bkg_model_1 = FoVBackgroundModel(dataset_name="dataset-simu")

models_1 = Models([model_simu_1, bkg_model_1])
print(models_1)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.000
#     amplitude               :   1.00e-13  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.000  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   :  36.627  deg
#     lat_0                   :  53.029  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, energy_true, livetime, irfs, pointing, geom, models, models_1):
    model = models.copy()
    model_1 = models_1.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(random_state=42)
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = dataset1.to_spectrum_dataset(on_region=regions)
    dataset2 = dataset2.to_spectrum_dataset(on_region=regions)
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model_1[0].copy()
    models_fit_1 = model_1[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result = fit.run()
    print(result)
    TS1 = result.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result = fit.run()
    print(result)
    TS2 = result.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [100.0,250.0,500.0,750.0,1000.0] * u.hr
y1 = []

# %%
for i in range(len(x)):
    y1.append(FoV(energy_reco, energy_true, x[i], irfs, pointing, geom, models, models_1))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 77
# 	total stat : -763410.39
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 224
# 	total stat : -763412.59
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 87
# 	total stat : -2131419.52
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 1402
# 	total stat : -2131419.83
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 78
# 	total stat : -4568629.22
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 281
# 	total stat : -4568629.40
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 83
# 	total stat : -7151347.43
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 632
# 	total stat : -7151348.12
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 94
# 	total stat : -9782155.41
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 319
# 	total stat : -9782158.95

# %%
del_TS_ = []
del_TS_1 = []
del_TS_2 = []
dataset_ = []
model_ = []
significance_ = []
excess_ = []
dataset_1 = []
model_1 = []
for i in range(len(x)):
    del_TS_.append(y1[i][0])
    dataset_.append(y1[i][1])
    model_.append(y1[i][2])
    del_TS_1.append(y1[i][3])
    del_TS_2.append(y1[i][4])
    significance_.append(y1[i][5])
    excess_.append(y1[i][6])
    dataset_1.append(y1[i][7])
    model_1.append(y1[i][8])

# %%
print(del_TS_[0:5])
print(del_TS_1[0:5])
print(del_TS_2[0:5])
# Out:
# [6.470152387046255, 20.492519576102495, 28.81844824180007, 59.64566002879292, 81.88421198353171]
# [2.2075097921770066, 0.3070080131292343, 0.17556145135313272, 0.6890945071354508, 3.541895627975464]
# [8.677662179223262, 20.79952758923173, 28.994009693153203, 60.33475453592837, 85.42610761150718]

# %%
plt.scatter(x,del_TS_[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_1[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_2[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
def flux_plt(model, dataset):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])

# %%
print(model_[0].spectral_model.parameters.to_table())
print(model_[1].spectral_model.parameters.to_table())
print(model_[2].spectral_model.parameters.to_table())
print(model_[3].spectral_model.parameters.to_table())
print(model_[4].spectral_model.parameters.to_table())
# Out:
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 1.1522e+00                nan nan  False       nan
# amplitude 5.7533e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 6.8015e-01          TeV-1 nan nan  False       nan
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 1.5823e+00                nan nan  False 1.842e-01
# amplitude 1.0392e-13 cm-2 s-1 TeV-1 nan nan  False 6.011e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 1.2378e+00          TeV-1 nan nan  False 6.561e-01
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name      value         unit      min max frozen   error
# --------- ----------- -------------- --- --- ------ ---------
#     index  2.4959e+00                nan nan  False 2.026e-01
# amplitude  1.7495e-14 cm-2 s-1 TeV-1 nan nan  False 4.666e-15
# reference  1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ -3.2442e-02          TeV-1 nan nan  False 7.525e-02
#     alpha  1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.4425e+00                nan nan  False 9.084e-01
# amplitude 2.7085e-14 cm-2 s-1 TeV-1 nan nan  False 2.743e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 1.5754e-01          TeV-1 nan nan  False 3.549e-01
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.0403e+00                nan nan  False       nan
# amplitude 5.1723e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 6.0488e-01          TeV-1 nan nan  False       nan
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
excess_maps(significance_[0], excess_[0])
excess_maps(significance_[1], excess_[1])
excess_maps(significance_[2], excess_[2])
excess_maps(significance_[3], excess_[3])
excess_maps(significance_[4], excess_[4])

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_1[0],dataset_1[0])
plt.subplot(322)
flux_plt(model_1[1],dataset_1[1])
plt.subplot(323)
flux_plt(model_1[2],dataset_1[2])
plt.subplot(324)
flux_plt(model_1[3],dataset_1[3])
plt.subplot(325)
flux_plt(model_1[4],dataset_1[4])

# %%
print(model_1[0].spectral_model.parameters.to_table())
print(model_1[1].spectral_model.parameters.to_table())
print(model_1[2].spectral_model.parameters.to_table())
print(model_1[3].spectral_model.parameters.to_table())
print(model_1[4].spectral_model.parameters.to_table())
# Out:
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.2195e+00                nan nan  False       nan
# amplitude 1.9312e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.5484e+00                nan nan  False       nan
# amplitude 2.1794e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.4604e+00                nan nan  False 1.646e-01
# amplitude 1.8687e-14 cm-2 s-1 TeV-1 nan nan  False 3.573e-15
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.6190e+00                nan nan  False       nan
# amplitude 2.0705e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.5829e+00                nan nan  False       nan
# amplitude 2.1508e-14 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
fig = plt.figure(figsize = [13,13], tight_layout=True)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
flux_plt(model_1[0],dataset_1[0])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
flux_plt(model_1[1],dataset_1[1])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
flux_plt(model_1[2],dataset_1[2])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
flux_plt(model_1[3],dataset_1[3])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])
flux_plt(model_1[4],dataset_1[4])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
# Out:
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc07c0ba8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabcf8f22b0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabcf89f1d0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2b90e48> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2b4d208> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2a94c88> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2a84240> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2bcf048> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabcf8972e8> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7fabc2bcf4a8> has a label of '_nolegend_' which cannot be automatically added to the legend.

# %%
def flux_plt_1(model, dataset, simu):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    simu.spectral_model.plot(energy_range=energy_range, energy_power=2)
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    plt.legend(['input model','best fit'])
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_[0],dataset_[0], model_simu)
plt.subplot(322)
flux_plt_1(model_[1],dataset_[1], model_simu)
plt.subplot(323)
flux_plt_1(model_[2],dataset_[2], model_simu)
plt.subplot(324)
flux_plt_1(model_[3],dataset_[3], model_simu)
plt.subplot(325)
flux_plt_1(model_[4],dataset_[4], model_simu)

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_1[0],dataset_1[0], model_simu)
plt.subplot(322)
flux_plt_1(model_1[1],dataset_1[1], model_simu)
plt.subplot(323)
flux_plt_1(model_1[2],dataset_1[2], model_simu)
plt.subplot(324)
flux_plt_1(model_1[3],dataset_1[3], model_simu)
plt.subplot(325)
flux_plt_1(model_1[4],dataset_1[4], model_simu)
