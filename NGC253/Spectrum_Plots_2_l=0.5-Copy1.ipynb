# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/South_z40_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.5
coord = SkyCoord(148.97, 69.679, unit="deg", frame="icrs")
pointing = coord.galactic

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(coord.galactic.l.deg, coord.galactic.b.deg),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model = ExpCutoffPowerLawSpectralModel(
    index=2.39, amplitude="1.34e-13 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=spectral_model,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   2.390
#     amplitude               :   1.34e-13  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.500  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 141.410  deg
#     lat_0                   :  40.568  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
spatial_model_1 = PointSpatialModel(
    lon_0=coord.galactic.l, lat_0=coord.galactic.b, frame="galactic"
)
spectral_model_1 = ExpCutoffPowerLawSpectralModel(
    index=3, amplitude="1e-12 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=0 * u.Unit("TeV-1"), alpha = 1
)
model_simu_1 = SkyModel(
    spatial_model=spatial_model_1,
    spectral_model=spectral_model_1,
    name="model-simu",
)

bkg_model_1 = FoVBackgroundModel(dataset_name="dataset-simu")

models_1 = Models([model_simu_1, bkg_model_1])
print(models_1)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   3.000
#     amplitude               :   1.00e-12  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.000  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 141.410  deg
#     lat_0                   :  40.568  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, energy_true, livetime, irfs, pointing, geom, models, models_1):
    model = models.copy()
    model_1 = models_1.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(random_state=50)
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = dataset1.to_spectrum_dataset(on_region=regions)
    dataset2 = dataset2.to_spectrum_dataset(on_region=regions)
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model_1[0].copy()
    models_fit_1 = model_1[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result = fit.run()
    print(result)
    TS1 = result.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result = fit.run()
    print(result)
    TS2 = result.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [10.0,25.0,50.0,100.0,200.0] * u.hr
y1 = []

# %%
for i in range(len(x)):
    y1.append(FoV(energy_reco, energy_true, x[i], irfs, pointing, geom, models, models_1))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 87
# 	total stat : -61090.44
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 330
# 	total stat : -61092.79
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 90
# 	total stat : -178893.90
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed.
# 	nfev       : 313
# 	total stat : -178902.87
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 92
# 	total stat : -388948.60
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 442
# 	total stat : -388952.32
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 104
# 	total stat : -851634.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 243
# 	total stat : -851637.09
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 104
# 	total stat : -1853127.52
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 205
# 	total stat : -1853134.41

# %%
del_TS_ = []
del_TS_1 = []
del_TS_2 = []
dataset_ = []
model_ = []
significance_ = []
excess_ = []
dataset_1 = []
model_1 = []
for i in range(len(x)):
    del_TS_.append(y1[i][0])
    dataset_.append(y1[i][1])
    model_.append(y1[i][2])
    del_TS_1.append(y1[i][3])
    del_TS_2.append(y1[i][4])
    significance_.append(y1[i][5])
    excess_.append(y1[i][6])
    dataset_1.append(y1[i][7])
    model_1.append(y1[i][8])

# %%
print(del_TS_[0:5])
print(del_TS_1[0:5])
print(del_TS_2[0:5])
# Out:
# [9.727507159041124, 47.60598692132044, 80.65285225230036, 160.03260910953395, 391.4859406927135]
# [2.356429632214713, 8.971468778967392, 3.718411846086383, 2.9950243757339194, 6.894202031195164]
# [12.083936791255837, 56.57745570028783, 84.37126409838675, 163.02763348526787, 398.38014272390865]

# %%
plt.scatter(x,del_TS_[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_1[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.axhline(y = 9, color = 'r', linestyle = '--')
plt.axhline(y = 16, color = 'r', linestyle = '--')
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_2[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
def flux_plt(model, dataset):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])

# %%
print(model_[0].spectral_model.parameters.to_table())
print(model_[1].spectral_model.parameters.to_table())
print(model_[2].spectral_model.parameters.to_table())
print(model_[3].spectral_model.parameters.to_table())
print(model_[4].spectral_model.parameters.to_table())
# Out:
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 1.4913e+00                nan nan  False 1.110e+00
# amplitude 4.0348e-13 cm-2 s-1 TeV-1 nan nan  False 5.420e-13
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 1.3834e+00          TeV-1 nan nan  False 1.071e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 1.8443e+00                nan nan  False       nan
# amplitude 4.0013e-13 cm-2 s-1 TeV-1 nan nan  False       nan
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 1.1963e+00          TeV-1 nan nan  False       nan
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.1808e+00                nan nan  False 4.014e-01
# amplitude 1.7900e-13 cm-2 s-1 TeV-1 nan nan  False 1.294e-13
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 5.8690e-01          TeV-1 nan nan  False 5.936e-01
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.4745e+00                nan nan  False 2.002e-01
# amplitude 1.1762e-13 cm-2 s-1 TeV-1 nan nan  False 4.125e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 3.1705e-01          TeV-1 nan nan  False 2.598e-01
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.5233e+00                nan nan  False 9.846e-02
# amplitude 1.2010e-13 cm-2 s-1 TeV-1 nan nan  False 1.525e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 2.5650e-01          TeV-1 nan nan  False 9.597e-02
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
excess_maps(significance_[0], excess_[0])
excess_maps(significance_[1], excess_[1])
excess_maps(significance_[2], excess_[2])
excess_maps(significance_[3], excess_[3])
excess_maps(significance_[4], excess_[4])

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_1[0],dataset_1[0])
plt.subplot(322)
flux_plt(model_1[1],dataset_1[1])
plt.subplot(323)
flux_plt(model_1[2],dataset_1[2])
plt.subplot(324)
flux_plt(model_1[3],dataset_1[3])
plt.subplot(325)
flux_plt(model_1[4],dataset_1[4])

# %%
print(model_1[0].spectral_model.parameters.to_table())
print(model_1[1].spectral_model.parameters.to_table())
print(model_1[2].spectral_model.parameters.to_table())
print(model_1[3].spectral_model.parameters.to_table())
print(model_1[4].spectral_model.parameters.to_table())
# Out:
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.7715e+00                nan nan  False 2.661e-01
# amplitude 5.6170e-14 cm-2 s-1 TeV-1 nan nan  False 2.207e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.8546e+00                nan nan  False 1.272e-01
# amplitude 7.3497e-14 cm-2 s-1 TeV-1 nan nan  False 1.415e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.6832e+00                nan nan  False 9.787e-02
# amplitude 7.7228e-14 cm-2 s-1 TeV-1 nan nan  False 1.121e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.7651e+00                nan nan  False 7.167e-02
# amplitude 7.2684e-14 cm-2 s-1 TeV-1 nan nan  False 7.190e-15
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.7684e+00                nan nan  False 4.727e-02
# amplitude 8.0293e-14 cm-2 s-1 TeV-1 nan nan  False 5.144e-15
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
fig = plt.figure(figsize = [13,13], tight_layout=True)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
flux_plt(model_1[0],dataset_1[0])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
flux_plt(model_1[1],dataset_1[1])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
flux_plt(model_1[2],dataset_1[2])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
flux_plt(model_1[3],dataset_1[3])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])
flux_plt(model_1[4],dataset_1[4])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
# Out:
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f77232ddcf8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723360eb8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723368978> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723318710> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723669630> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723536e80> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f772356fdd8> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f7723542d30> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f77236c1898> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7f77236ec9b0> has a label of '_nolegend_' which cannot be automatically added to the legend.

# %%
def flux_plt_1(model, dataset, simu):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    simu.spectral_model.plot(energy_range=energy_range, energy_power=2)
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    plt.legend(['input model','best fit'])
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_[0],dataset_[0], model_simu)
plt.subplot(322)
flux_plt_1(model_[1],dataset_[1], model_simu)
plt.subplot(323)
flux_plt_1(model_[2],dataset_[2], model_simu)
plt.subplot(324)
flux_plt_1(model_[3],dataset_[3], model_simu)
plt.subplot(325)
flux_plt_1(model_[4],dataset_[4], model_simu)

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_1[0],dataset_1[0], model_simu)
plt.subplot(322)
flux_plt_1(model_1[1],dataset_1[1], model_simu)
plt.subplot(323)
flux_plt_1(model_1[2],dataset_1[2], model_simu)
plt.subplot(324)
flux_plt_1(model_1[3],dataset_1[3], model_simu)
plt.subplot(325)
flux_plt_1(model_1[4],dataset_1[4], model_simu)
