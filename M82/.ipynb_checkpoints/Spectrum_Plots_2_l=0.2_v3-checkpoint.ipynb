# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from regions import CircleSkyRegion
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    PointSpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel,
    TemplateSpectralModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, RingBackgroundMaker, FoVBackgroundMaker
from gammapy.modeling import Fit
from gammapy.maps import Map
from scipy.stats import norm
from gammapy.data import Observation
from gammapy.datasets import MapDataset, MapDatasetOnOff
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator

# %%
import scipy.stats as stats
import math
import statistics
import os

# %%
os.environ['CALDB'] = '/home/rishank/anaconda2/envs/cta/share/caldb/'
# !echo $CALDB
# !ls $CALDB
# Out:
# /home/rishank/anaconda2/envs/cta/share/caldb/
# data

# %%
irfs = load_cta_irfs(
    "$CALDB/data/cta/prod3b-v2/bcf/North_z40_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 1.0 * u.hr
l = 0.2
pointing = SkyCoord(141.409467, 40.566962, unit="deg", frame="galactic")

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(141.409467, 40.566962),
    binsz=0.02,
    width=(3, 3),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
#energy_true = MapAxis.from_edges(
#    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
#)

empty = MapDataset.create(geom, name="dataset-simu")

# %%
lines = []
with open('M82_spectrum.txt') as f:
    lines = f.readlines()

# %%
en = []
fl = []
for line in lines:
    line = line.strip()
    columns = line.split()
    en.append(float(columns[0]))
    fl.append(float(columns[1]))

# %%
energy = np.array(en) * u.GeV
values = np.array(fl)/(np.array(en)**2) * u.Unit("GeV-1 s-1 cm-2")
template = TemplateSpectralModel(energy=energy, values=values)
template.plot(energy_range=[0.1, 1.5e5] * u.GeV, energy_power=2)
plt.grid(which="both")

# %%
# Define sky model to used simulate the data.
# Here we use a Point spatial model and a Exponential Cut Power Law spectral model.
spatial_model = PointSpatialModel(
    lon_0="141.409467 deg", lat_0="40.566962 deg", frame="galactic"
)
#spectral_model = ExpCutoffPowerLawSpectralModel(
#    index=2.495, amplitude="2.72e-13 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=l * u.Unit("TeV-1"), alpha = 1
#)
model_simu = SkyModel(
    spatial_model=spatial_model,
    spectral_model=template,
    name="model-simu",
)

bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")

models = Models([model_simu, bkg_model])
print(models)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : TemplateSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     lon_0                   : 141.409  deg
#     lat_0                   :  40.567  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
spatial_model_1 = PointSpatialModel(
    lon_0="141.409467 deg", lat_0="40.566962 deg", frame="galactic"
)
spectral_model_1 = ExpCutoffPowerLawSpectralModel(
    index=3, amplitude="1e-12 cm-2 s-1 TeV-1", reference="1 TeV", lambda_=0 * u.Unit("TeV-1"), alpha = 1
)
model_simu_1 = SkyModel(
    spatial_model=spatial_model_1,
    spectral_model=spectral_model_1,
    name="model-simu",
)

bkg_model_1 = FoVBackgroundModel(dataset_name="dataset-simu")

models_1 = Models([model_simu_1, bkg_model_1])
print(models_1)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : model-simu
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :   3.000
#     amplitude               :   1.00e-12  1 / (cm2 s TeV)
#     reference    (frozen)   :   1.000  TeV
#     lambda_                 :   0.000  1 / TeV
#     alpha        (frozen)   :   1.000
#     lon_0                   : 141.409  deg
#     lat_0                   :  40.567  deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset-simu-bkg
#   Datasets names            : ['dataset-simu']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :   1.000
#     tilt         (frozen)   :   0.000
#     reference    (frozen)   :   1.000  TeV

# %%
def FoV(energy_reco, livetime, irfs, pointing, geom, models, models_1):
    model = models.copy()
    model_1 = models_1.copy()
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])
    maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=3.5 * u.deg)
    dataset = maker.run(empty, obs)
    dataset = maker_safe_mask.run(dataset, obs)
    dataset.models = model
    dataset.fake(random_state=42)
    
    dataset1 = dataset.copy()
    dataset1.models = bkg_model
    
    dataset2 = dataset.copy()
    dataset2.models = bkg_model
    
    estimator = ExcessMapEstimator(0.04 * u.deg, selection_optional=[])
    lima_maps = estimator.run(dataset1)
    significance_map = lima_maps["sqrt_ts"]
    excess_map = lima_maps["excess"]
    
    geom_image = geom.to_image().to_cube([energy_reco.squash()])
    regions = CircleSkyRegion(center=pointing, radius=0.2 * u.deg)
    exclusion_mask = Map.from_geom(geom_image)
    exclusion_mask.data = geom_image.region_mask([regions], inside=False)
    maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)
    
    ## original code
    dataset1 = dataset1.to_spectrum_dataset(on_region=regions)
    dataset2 = dataset2.to_spectrum_dataset(on_region=regions)
    dataset1 = maker_fov.run(dataset1)
    dataset2 = maker_fov.run(dataset2)
    
    TS0 = dataset1.stat_sum()
    models_fit = model_1[0].copy()
    models_fit_1 = model_1[0].copy()
    dataset1.models = models_fit
    dataset2.models = models_fit_1
    
    dataset1.models.parameters['lambda_'].frozen = True
    fit = Fit([dataset1])
    result = fit.run()
    print(result)
    TS1 = result.total_stat
    del_TS = TS0 - TS1
    
    dataset2.models.parameters['lambda_'].frozen = False
    fit = Fit([dataset2])
    result = fit.run()
    print(result)
    TS2 = result.total_stat
    del_TS_1 = TS1 - TS2
    del_TS_2 = TS0 - TS2
    
    return del_TS, dataset2, models_fit_1, del_TS_1, del_TS_2, significance_map, excess_map, dataset1, models_fit

# %%
def excess_maps(significance_map, excess_map):
    plt.figure(figsize=(10, 10))
    ax1 = plt.subplot(221, projection=significance_map.geom.wcs)
    ax2 = plt.subplot(222, projection=excess_map.geom.wcs)
    
    ax1.set_title("Significance map")
    significance_map.plot(ax=ax1, add_cbar=True)

    ax2.set_title("Excess map")
    excess_map.plot(ax=ax2, add_cbar=True)
    return

# %%
x = [5.0,10.0,25.0,50.0,100.0] * u.hr
y1 = []

# %%
for i in range(len(x)):
    y1.append(FoV(energy_reco, x[i], irfs, pointing, geom, models, models_1))
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 103
# 	total stat : -25953.84
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 184
# 	total stat : -25954.00
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 97
# 	total stat : -61693.70
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 164
# 	total stat : -61693.70
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 121
# 	total stat : -173719.53
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 206
# 	total stat : -173720.89
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 106
# 	total stat : -381042.96
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 240
# 	total stat : -381046.47
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 112
# 	total stat : -828874.75
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : minuit
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 212
# 	total stat : -828875.91

# %%
del_TS_ = []
del_TS_1 = []
del_TS_2 = []
dataset_ = []
model_ = []
significance_ = []
excess_ = []
dataset_1 = []
model_1 = []
for i in range(len(x)):
    del_TS_.append(y1[i][0])
    dataset_.append(y1[i][1])
    model_.append(y1[i][2])
    del_TS_1.append(y1[i][3])
    del_TS_2.append(y1[i][4])
    significance_.append(y1[i][5])
    excess_.append(y1[i][6])
    dataset_1.append(y1[i][7])
    model_1.append(y1[i][8])

# %%
print(del_TS_[0:5])
print(del_TS_1[0:5])
print(del_TS_2[0:5])
# Out:
# [49.995190798970725, 109.28277785946557, 263.9639464218926, 444.5721441693022, 933.885370617616]
# [0.1589697268755117, 0.001172853990283329, 1.3600534602301195, 3.501882634998765, 1.1643032643478364]
# [50.15416052584624, 109.28395071345585, 265.32399988212273, 448.07402680430096, 935.0496738819638]

# %%
plt.scatter(x,del_TS_[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_1[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.axhline(y = 9, color = 'r', linestyle = '--')
plt.axhline(y = 16, color = 'r', linestyle = '--')
plt.axhline(y = 25, color = 'r', linestyle = '--')
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
plt.scatter(x,del_TS_2[0:5])
#plt.xscale("log")
#plt.legend(["FoV_Background"])
plt.ylabel("Del_TS")
plt.xlabel("LiveTime (hrs)")
#plt.title("Original code")
# Out:
# Text(0.5, 0, 'LiveTime (hrs)')

# %%
def flux_plt(model, dataset):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])

# %%
print(model_[0].spectral_model.parameters.to_table())
print(model_[1].spectral_model.parameters.to_table())
print(model_[2].spectral_model.parameters.to_table())
print(model_[3].spectral_model.parameters.to_table())
print(model_[4].spectral_model.parameters.to_table())
# Out:
#    name      value         unit      min max frozen   error
# --------- ----------- -------------- --- --- ------ ---------
#     index  2.1569e+00                nan nan  False 3.179e-01
# amplitude  2.1833e-13 cm-2 s-1 TeV-1 nan nan  False 7.882e-14
# reference  1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ -6.5390e-02          TeV-1 nan nan  False 1.603e-01
#     alpha  1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.3896e+00                nan nan  False 1.810e-01
# amplitude 2.8379e-13 cm-2 s-1 TeV-1 nan nan  False 7.069e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 5.6081e-03          TeV-1 nan nan  False 1.206e-01
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.1396e+00                nan nan  False 1.300e-01
# amplitude 3.2690e-13 cm-2 s-1 TeV-1 nan nan  False 4.922e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 9.1852e-02          TeV-1 nan nan  False 7.993e-02
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.1555e+00                nan nan  False 1.043e-01
# amplitude 3.1216e-13 cm-2 s-1 TeV-1 nan nan  False 3.954e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 1.1758e-01          TeV-1 nan nan  False 6.821e-02
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.2100e+00                nan nan  False 7.225e-02
# amplitude 2.8148e-13 cm-2 s-1 TeV-1 nan nan  False 2.407e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 4.5804e-02          TeV-1 nan nan  False 4.339e-02
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
excess_maps(significance_[0], excess_[0])
excess_maps(significance_[1], excess_[1])
excess_maps(significance_[2], excess_[2])
excess_maps(significance_[3], excess_[3])
excess_maps(significance_[4], excess_[4])

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt(model_1[0],dataset_1[0])
plt.subplot(322)
flux_plt(model_1[1],dataset_1[1])
plt.subplot(323)
flux_plt(model_1[2],dataset_1[2])
plt.subplot(324)
flux_plt(model_1[3],dataset_1[3])
plt.subplot(325)
flux_plt(model_1[4],dataset_1[4])

# %%
print(model_1[0].spectral_model.parameters.to_table())
print(model_1[1].spectral_model.parameters.to_table())
print(model_1[2].spectral_model.parameters.to_table())
print(model_1[3].spectral_model.parameters.to_table())
print(model_1[4].spectral_model.parameters.to_table())
# Out:
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.0463e+00                nan nan  False 1.591e-01
# amplitude 2.4694e-13 cm-2 s-1 TeV-1 nan nan  False 4.618e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.3971e+00                nan nan  False 9.700e-02
# amplitude 2.8107e-13 cm-2 s-1 TeV-1 nan nan  False 3.232e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.2699e+00                nan nan  False 6.356e-02
# amplitude 2.7849e-13 cm-2 s-1 TeV-1 nan nan  False 2.021e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.3176e+00                nan nan  False 4.785e-02
# amplitude 2.5445e-13 cm-2 s-1 TeV-1 nan nan  False 1.420e-14
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00
#    name     value         unit      min max frozen   error
# --------- ---------- -------------- --- --- ------ ---------
#     index 2.2766e+00                nan nan  False 3.401e-02
# amplitude 2.5954e-13 cm-2 s-1 TeV-1 nan nan  False 9.993e-15
# reference 1.0000e+00            TeV nan nan   True 0.000e+00
#   lambda_ 0.0000e+00          TeV-1 nan nan   True 0.000e+00
#     alpha 1.0000e+00                nan nan   True 0.000e+00

# %%
fig = plt.figure(figsize = [13,13], tight_layout=True)
plt.subplot(321)
flux_plt(model_[0],dataset_[0])
flux_plt(model_1[0],dataset_1[0])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(322)
flux_plt(model_[1],dataset_[1])
flux_plt(model_1[1],dataset_1[1])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(323)
flux_plt(model_[2],dataset_[2])
flux_plt(model_1[2],dataset_1[2])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(324)
flux_plt(model_[3],dataset_[3])
flux_plt(model_1[3],dataset_1[3])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
plt.subplot(325)
flux_plt(model_[4],dataset_[4])
flux_plt(model_1[4],dataset_1[4])
plt.legend(['ExponentialCut_PowerLaw','PowerLaw','_nolegend_','_nolegend_','flux points for ExponentialCut_PowerLaw','flux points for PowerLaw'])
# Out:
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e40c0f0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e79bc18> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   """
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e878cc0> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e81be48> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   if __name__ == '__main__':
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e55aac8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e7109e8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   del sys.path[0]
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e290be0> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e90cef0> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff51e891b38> has a label of '_nolegend_' which cannot be automatically added to the legend.
# /home/rishank/anaconda2/envs/gammapy-0.18.2/lib/python3.7/site-packages/ipykernel_launcher.py:21: UserWarning: The handle <matplotlib.collections.PolyCollection object at 0x7ff5318ede80> has a label of '_nolegend_' which cannot be automatically added to the legend.

# %%
def flux_plt_1(model, dataset, simu):
    spec = model.spectral_model
    energy_edges = np.logspace(-1.0, 1.0, 5) * u.TeV
    fpe = FluxPointsEstimator(energy_edges=energy_edges)
    flux_points = fpe.run(datasets=[dataset])
    energy_range = [0.1, 10] * u.TeV
    simu.spectral_model.plot(energy_range=energy_range, energy_power=2)
    spec.plot(energy_range=energy_range, energy_power=2)
    ax = spec.plot_error(energy_range=energy_range, energy_power=2)
    flux_points.plot(ax=ax, energy_power=2)
    plt.title("Livetime = "+str(dataset.gti.time_delta.to(u.hr)))#, fontsize='15')
    plt.legend(['input model','best fit'])
    return

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_[0],dataset_[0], model_simu)
plt.subplot(322)
flux_plt_1(model_[1],dataset_[1], model_simu)
plt.subplot(323)
flux_plt_1(model_[2],dataset_[2], model_simu)
plt.subplot(324)
flux_plt_1(model_[3],dataset_[3], model_simu)
plt.subplot(325)
flux_plt_1(model_[4],dataset_[4], model_simu)

# %%
fig = plt.figure(figsize = [10,10], tight_layout=True)
#fig.suptitle('FoV Background', verticalalignment = 'baseline', fontsize = 15)
plt.subplot(321)
flux_plt_1(model_1[0],dataset_1[0], model_simu)
plt.subplot(322)
flux_plt_1(model_1[1],dataset_1[1], model_simu)
plt.subplot(323)
flux_plt_1(model_1[2],dataset_1[2], model_simu)
plt.subplot(324)
flux_plt_1(model_1[3],dataset_1[3], model_simu)
plt.subplot(325)
flux_plt_1(model_1[4],dataset_1[4], model_simu)
